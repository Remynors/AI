# %%
import torch
print(torch.__version__)
# Out:
# 0.3.1.post2

# %%
import torch
print(torch.__version__)
# Out:
# 0.3.1.post2

# %%
import sys, fastai
print(sys.modules['fastai'])
# Out:
# <module 'fastai' from '/home/norvilr/anaconda3/envs/fastai07/lib/python3.6/site-packages/fastai/__init__.py'>

# %%
torch.cuda.is_available()
# Out:
# True

# %%
devID=torch.cuda.current_device()
devID, torch.cuda.get_device_name(devID)
# Out:
# (0, 'GeForce GTX 1080 Ti')

# %%
PATH ='data/'
# !ls data
# Out:
# models	tmdb_5000_credits.csv  tmdb_5000_movies.csv  tmp

# %%
import pandas as pd 
import numpy as np 
import json

#movies = pd.read_csv(PATH+'tmdb_5000_movies.csv')
#credits = pd.read_csv(PATH+'tmdb_5000_credits.csv')

# %%
def load_tmdb_movies(path):
    df = pd.read_csv(path)
    df['release_date'] = pd.to_datetime(df['release_date']).apply(lambda x: x.date())
    json_columns = ['genres', 'keywords', 'production_countries', 'production_companies', 'spoken_languages']
    for column in json_columns:
        df[column] = df[column].apply(json.loads)  #needed to make json objects lists rahter than strings
    return df

def load_tmdb_credits(path):
    df = pd.read_csv(path)
    json_columns = ['cast', 'crew']
    for column in json_columns:
        df[column] = df[column].apply(json.loads)
    return df

# %%
movies = load_tmdb_movies(PATH+'tmdb_5000_movies.csv')
credits = load_tmdb_credits(PATH+'tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1  300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  250000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4  260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{'id': 1463, 'name': 'culture clash'}, {'id':...                en
# 1  [{'id': 270, 'name': 'ocean'}, {'id': 726, 'na...                en
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4  [{'cast_id': 5, 'character': 'John Carter', 'c...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# ...

# %%
credits.columns = ['id','title2','cast','crew']
credits.head()
# Out:
#        id                                    title2  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4  [{'cast_id': 5, 'character': 'John Carter', 'c...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...

# %%
df = movies.merge(credits,how='inner',on='id')
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1  300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  250000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4  260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{'id': 1463, 'name': 'culture clash'}, {'id':...                en
# 1  [{'id': 270, 'name': 'ocean'}, {'id': 726, 'na...                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# ...

# %%
df.shape
# Out:
# (4803, 23)

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
def pipe_flatten_names(keywords):
    return '|'.join([x['name'] for x in keywords])

# %%
#tmdb_movies['genres'] = tmdb_movies['genres'].apply(pipe_flatten_names)

# %%
def splitJsonToList(obj, column):
    fullDict = []
    for i in obj[column]:
    #    dictLine = json.loads(i)
        localDict = []
        for items in i:
            localDict.append(items['name'])
    #    print(localDict)
        fullDict.append(localDict)
    return fullDict

# %%
# this would run if we didn't load csv files with json.load 
# fullDict = []
# for i in movies['genres']:
#     dictLine = json.loads(i)
#     localDict = []
#     for items in dictLine:
#         localDict.append(items['name'])
#     print(localDict)
#     fullDict.append(localDict)

# %%
df['genres'][0]
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
df['keywords'][0]
# Out:
# [{'id': 1463, 'name': 'culture clash'},
#  {'id': 2964, 'name': 'future'},
#  {'id': 3386, 'name': 'space war'},
#  {'id': 3388, 'name': 'space colony'},
#  {'id': 3679, 'name': 'society'},
#  {'id': 3801, 'name': 'space travel'},
#  {'id': 9685, 'name': 'futuristic'},
#  {'id': 9840, 'name': 'romance'},
#  {'id': 9882, 'name': 'space'},
#  {'id': 9951, 'name': 'alien'},
#  {'id': 10148, 'name': 'tribe'},
#  {'id': 10158, 'name': 'alien planet'},
#  {'id': 10987, 'name': 'cgi'},
#  {'id': 11399, 'name': 'marine'},
#  {'id': 13065, 'name': 'soldier'},
#  {'id': 14643, 'name': 'battle'},
#  {'id': 14720, 'name': 'love affair'},
#  {'id': 165431, 'name': 'anti war'},
#  {'id': 193554, 'name': 'power relations'},
#  {'id': 206690, 'name': 'mind and soul'},
#  {'id': 209714, 'name': '3d'}]

# %%
df['production_companies'][0]
# Out:
# [{'name': 'Ingenious Film Partners', 'id': 289},
#  {'name': 'Twentieth Century Fox Film Corporation', 'id': 306},
#  {'name': 'Dune Entertainment', 'id': 444},
#  {'name': 'Lightstorm Entertainment', 'id': 574}]

# %%
df['production_countries'][0]
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'}]

# %%
df['spoken_languages'][0]
# Out:
# [{'iso_639_1': 'en', 'name': 'English'},
#  {'iso_639_1': 'es', 'name': 'Español'}]

# %%
df['cast'][0]
# Out:
# [{'cast_id': 242,
#   'character': 'Jake Sully',
#   'credit_id': '5602a8a7c3a3685532001c9a',
#   'gender': 2,
#   'id': 65731,
#   'name': 'Sam Worthington',
#   'order': 0},
#  {'cast_id': 3,
#   'character': 'Neytiri',
#   'credit_id': '52fe48009251416c750ac9cb',
#   'gender': 1,
#   'id': 8691,
#   'name': 'Zoe Saldana',
#   'order': 1},
#  {'cast_id': 25,
#   'character': 'Dr. Grace Augustine',
#   'credit_id': '52fe48009251416c750aca39',
#   'gender': 1,
#   'id': 10205,
#   'name': 'Sigourney Weaver',
#   'order': 2},
#  {'cast_id': 4,
#   'character': 'Col. Quaritch',
#   'credit_id': '52fe48009251416c750ac9cf',
#   'gender': 2,
#   'id': 32747,
#   'name': 'Stephen Lang',
#   'order': 3},
#  {'cast_id': 5,
#   'character': 'Trudy Chacon',
#   'credit_id': '52fe48009251416c750ac9d3',
#   'gender': 1,
#   'id': 17647,
#   'name': 'Michelle Rodriguez',
#   'order': 4},
#  {'cast_id': 8,
#   'character': 'Selfridge',
#   'credit_id': '52fe48009251416c750ac9e1',
#   'gender': 2,
# ...

# %%
df['crew'][0]
# Out:
# [{'credit_id': '52fe48009251416c750aca23',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
#  {'credit_id': '539c47ecc3a36810e3001f87',
#   'department': 'Art',
#   'gender': 2,
#   'id': 496,
#   'job': 'Production Design',
#   'name': 'Rick Carter'},
#  {'credit_id': '54491c89c3a3680fb4001cf7',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Sound Designer',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '54491cb70e0a267480001bd0',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Supervising Sound Editor',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '539c4a4cc3a36810c9002101',
#   'department': 'Production',
#   'gender': 1,
#   'id': 1262,
#   'job': 'Casting',
#   'name': 'Mali Finn'},
#  {'credit_id': '5544ee3b925141499f0008fc',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 1729,
#   'job': 'Original Music Composer',
#   'name': 'James Horner'},
# ...

# %%
df2 = df.copy()

# %%
features = ['genres', 'cast', 'crew', 'keywords','production_companies', 'production_countries', 'spoken_languages']
for column in features:
    df2[column] = splitJsonToList(df2, column)

# %%
#movies2['genres'] = splitJsonToList(movies2, 'genres')
#['id', 'budget', 'original_title', 'popularity', 'vote_average', 'vote_count']

# %%
df2.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
from fastai.learner import *
from fastai.column_data import *

# %%
#cf = CollabFilterDataset.from_csv(path, 'small_train.csv', 'msno', 'song_id', 'target')
#??CollabFilterDataset.from_data_frame

# %%
n_movies=int(df2.id.nunique())
n_movies
# Out:
# 4803

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# ...

# %%
#from sklearn.model_selection import train_test_split
#train, test = train_test_split(df2, test_size=0.2)
# print(train.shape,test.shape)

# %%
# select only few relative columns
df_small = df2[['id', 'budget', 'original_title', 'popularity', 'vote_average', 'vote_count']].copy()

# %%
df_small.head()
# Out:
#        id     budget                            original_title  popularity  \
# 0   19995  237000000                                    Avatar  150.437577
# 1     285  300000000  Pirates of the Caribbean: At World's End  139.082615
# 2  206647  245000000                                   Spectre  107.376788
# 3   49026  250000000                     The Dark Knight Rises  112.312950
# 4   49529  260000000                               John Carter   43.926995
#
#    vote_average  vote_count
# 0           7.2       11800
# 1           6.9        4500
# 2           6.3        4466
# 3           7.6        9106
# 4           6.1        2124

# %%
# we don't have to dead with nan filling, since all values valid
df_small.isnull().values.any()
# Out:
# False

# %%
# check cardinality of some variables
df_small['vote_count'].value_counts()
# Out:
# 0       62
# 1       53
# 2       46
# 4       43
# 3       41
# 6       38
# 8       37
# 10      34
# 11      32
# 9       32
# 7       31
# 5       28
# 15      26
# 19      26
# 12      26
# 13      25
# 16      24
# 22      23
# 34      23
# 31      22
# 24      22
# 18      22
# 17      21
# 25      20
# 26      20
# 23      19
# 27      19
# 66      19
# 29      19
# 47      18
#         ..
# 382      1
# 2435     1
# 2439     1
# 402      1
# 2395     1
# 4500     1
# 4524     1
# 2491     1
# 2495     1
# 8662     1
# 474      1
# 2399     1
# 4432     1
# 2143     1
# 2251     1
# 8428     1
# 1221     1
# 2199     1
# 162      1
# 170      1
# 2247     1
# 2263     1
# 4412     1
# 2271     1
# 230      1
# 2295     1
# 266      1
# 2359     1
# 314      1
# 2039     1
# Name: vote_count, Length: 1609, dtype: int64

# %%
#select which vars are continueouis and categorical, and dependant variable 
cat_vars = ['id', 'vote_average', 'vote_count']
contin_vars = ['budget']
dep = 'popularity'

# %%
# make a copy and change variable types
joined = df_small[cat_vars+contin_vars+[dep]].copy()
for v in cat_vars: joined[v] = joined[v].astype('category').cat.as_ordered()
for v in contin_vars:
    joined[v] = joined[v].fillna(0).astype('float32')
joined['popularity'] = joined['popularity'].astype('float32')

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 5 columns):
# id              4803 non-null category
# vote_average    4803 non-null category
# vote_count      4803 non-null category
# budget          4803 non-null float32
# popularity      4803 non-null float32
# dtypes: category(3), float32(2)
# memory usage: 391.6 KB

# %%
joined.T
# Out:
#                   0        1         2        3        4         5     \
# id               19995      285    206647    49026    49529       559
# vote_average       7.2      6.9       6.3      7.6      6.1       5.9
# vote_count       11800     4500      4466     9106     2124      3576
# budget        2.37e+08    3e+08  2.45e+08  2.5e+08  2.6e+08  2.58e+08
# popularity     150.438  139.083   107.377  112.313   43.927     115.7
#
#                  6        7        8        9      ...         4793      4794  \
# id              38757    99861      767   209112   ...       182291    286939
# vote_average      7.4      7.3      7.4      5.7   ...            6         0
# vote_count       3330     6767     5293     7004   ...            2         0
# budget        2.6e+08  2.8e+08  2.5e+08  2.5e+08   ...            0         0
# popularity     48.682  134.279  98.8856   155.79   ...     0.029757  0.166513
#
#                   4795     4796      4797     4798      4799     4800  \
# ...

# %%
idxs = get_cv_idxs(len(joined))  # index for validation set
wd = 2e-4 # weight decay
n_factors = 50 # n_factors i.e. 1 dimension of embeddings (random)

# %%
min_vote, max_vote = joined.vote_average.min(),joined.vote_average.max()
min_vote, max_vote
# Out:
# (0.0, 10.0)

# %% [markdown]
# ### Shallow Learning - Probabilistic Matrix Factorization
# #### Fast.ai - CollabFilterDataset

# %%
# data loader
cf = CollabFilterDataset.from_data_frame('.', joined, 'id', 'vote_average', 'popularity')

# %%
??CollabFilterDataset.from_data_frame

# %%
learn = cf.get_learner(n_factors, idxs, bs=64, opt_fn=optim.Adam)

# %%
learn.fit(1e-2, 5, wds = wd, cycle_len=1, cycle_mult=2)
# Out:
# ...
# epoch      trn_loss   val_loss
#     0      147093.81763 138502.78125
#     1      82274.078322 97614.714583
#     2      25188.191365 95532.969271
#     3      8420.161804 94020.401562
#     4      2904.469548 93556.901562
#     5      1100.073133 93443.645312
#     6      525.520358 93427.709375
#     7      330.353158 93184.739583
#     8      219.409253 92933.263542
#     9      241.91466  92795.258333
#     10     219.652122 92691.960938
#     11     205.310494 92649.058333
#     12     179.888459 92630.082292
#     13     137.57968  92612.8625
#     14     128.338918 92611.990625
#     15     119.221709 92550.243229
#     16     103.95486  92355.600521
#     17     142.733121 92135.71875
#     18     270.093612 91699.264583
#     19     329.069118 91495.879167
#     20     310.898954 91320.289583
#     21     363.053801 91292.120833
#     22     388.540937 91264.85
#     23     311.658718 91190.979167
#     24     280.571659 91196.063542
#     25     242.253714 91196.329688
# ...

# %%
joined.T
# Out:
#                   0        1         2        3        4         5     \
# id               19995      285    206647    49026    49529       559
# vote_average       7.2      6.9       6.3      7.6      6.1       5.9
# vote_count       11800     4500      4466     9106     2124      3576
# budget        2.37e+08    3e+08  2.45e+08  2.5e+08  2.6e+08  2.58e+08
# popularity     150.438  139.083   107.377  112.313   43.927     115.7
#
#                  6        7        8        9      ...         4793      4794  \
# id              38757    99861      767   209112   ...       182291    286939
# vote_average      7.4      7.3      7.4      5.7   ...            6         0
# vote_count       3330     6767     5293     7004   ...            2         0
# budget        2.6e+08  2.8e+08  2.5e+08  2.5e+08   ...            0         0
# popularity     48.682  134.279  98.8856   155.79   ...     0.029757  0.166513
#
#                   4795     4796      4797     4798      4799     4800  \
# ...

# %% [markdown]
# ## deep learning emneddings

# %%
## https://github.com/groverpr/Machine-Learning/blob/master/notebooks/02_Collaborative_Filtering.ipynb
def get_emb(ni,nf):
    e = nn.Embedding(ni, nf)
    e.weight.data.uniform_(-0.01,0.01)
    #e.weight.data.normal_(0,0.003)
    return e

# %%
x = joined.drop(['popularity'],axis=1)
y = joined['popularity'].astype(np.float32)

# %%
dx, dy, nas, mapper = proc_df(joined, 'popularity', do_scale=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-da976a192266> in <module>
#       1
# ----> 2 dx, dy, nas, mapper = proc_df(joined, 'popularity', do_scale=True)
#
# NameError: name 'proc_df' is not defined

# %%
train_ratio = 0.75
# train_ratio = 0.9
samp_size = len(joined)
train_size = int(samp_size * train_ratio); train_size
val_idx = list(range(train_size, len(df)))

# %%
type(val_idx[0])

# %%
data = ColumnarModelData.from_data_frame('.', val_idx, dx, dy, ['id', 'vote_average', 'vote_count'], 64)

# %%
cat_sz = [(c, len(joined[c].cat.categories)+1) for c in cat_vars]

# %%
cat_sz

# %%
emb_szs = [(c, min(50, (c+1)//2)) for _,c in cat_sz]

# %%
emb_szs

# %%
#m = data.get_learner(emb_szs, len(joined.columns)-len(cat_vars),
#                   0.04, 1, [1000,500], [0.001,0.01])
#m.summary()

# %%
data.val_dl

# %%
# wd=1e-5
# model = EmbeddingNet(n_users, n_movies)
# model = model.cuda()
# opt = optim.Adam(model.parameters(), 1e-3, weight_decay=wd) # got parameter() for free , lr = 1e-3

# %%
#m = data.get_learner(emb_szs, len(joined.columns)-len(cat_vars),0.04, 1, [1000,500], [0.001,0.01], y_range=y_range)
m = data.get_learner(emb_szs, len(joined.columns)-len(cat_vars),0.04, 1, [1000,500], [0.001,0.01])
m.summary()

# %%
# nh = dimension of hidden linear layer
# p1 = dropout1
# p2 = dropout2

class EmbeddingNet(nn.Module):
    def __init__(self, n_users, _n_movies, nh = 10, p1 = 0.05, p2= 0.5):
        super().__init__()
        (self.u, self.m, self.ub, self.mb) = [get_emb(*o) for o in [
            (n_users, n_factors), (n_movies, n_factors),
            (n_users,1), (n_movies,1)
        ]]
        
        self.lin1 = nn.Linear(n_factors*2, nh)  # bias is True by default
        self.lin2 = nn.Linear(nh, 1)
        self.drop1 = nn.Dropout(p = p1)
        self.drop2 = nn.Dropout(p = p2)
    
    def forward(self, cats, conts): # forward pass i.e.  dot product of vector from movie embedding matrixx
                                    # and vector from user embeddings matrix
        
        # torch.cat : concatenates both embedding matrix to make more columns, same rows i.e. n_factors*2, n : rows
        # u(users) is doing lookup for indexed mentioned in users
        # users has indexes to lookup in embedding matrix. 
        
        users,movies = cats[:,0],cats[:,1]
        u2,m2 = self.u(users) , self.m(movies)
       
        x = self.drop1(torch.cat([u2,m2], 1)) # drop initialized weights
        x = self.drop2(F.relu(self.lin1(x))) # drop 1st linear + nonlinear wt
        r = F.sigmoid(self.lin2(x)) * (max_rating - min_rating) + min_rating               
        return r

# %%
#??ColumnarModelData.from_data_frame

# %%
from fastai.learner import *
from fastai.column_data import *
from fastai.structured import numericalize, fix_missing, proc_df

# %%
df, y, nas, mapper = proc_df(joined, 'popularity', do_scale=True)
yl = np.log(y)
max_log_y = np.max(yl)
y_range = (0, max_log_y*1.2)
# Out:
# /home/norvilr/anaconda3/envs/fastai07/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
df.T

# %%
#??ColumnarModelData

# %%
data = ColumnarModelData.from_data_frame(PATH, idxs, df, y, cat_flds=cat_vars, bs=64)

# %%
type(data)
# Out:
# fastai.column_data.ColumnarModelData

# %%
cat_sz = [(c, len(joined[c].cat.categories)+1) for c in cat_vars]

# %%
cat_sz
# Out:
# [('id', 4804), ('vote_average', 72), ('vote_count', 1610)]

# %%
# We use the cardinality of each variable (that is, its number of unique values) 
# to decide how large to make its embeddings. Each level will be associated with a vector
# with length defined as below.
emb_szs = [(c, min(50, (c+1)//2)) for _,c in cat_sz]
emb_szs
# Out:
# [(4804, 50), (72, 36), (1610, 50)]

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 5 columns):
# id              4803 non-null category
# vote_average    4803 non-null category
# vote_count      4803 non-null category
# budget          4803 non-null float32
# popularity      4803 non-null float32
# dtypes: category(3), float32(2)
# memory usage: 391.6 KB

# %%
m = data.get_learner(emb_szs, len(joined.columns)-len(cat_vars),0.04, 1, [1000,500], [0.001,0.01], y_range=y_range)
#m = data.get_learner(emb_szs, len(joined.columns)-len(cat_vars),0.04, 1, [1000,500], [0.001,0.01])
m.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-18ba3795fea4> in <module>
#       1 m = data.get_learner(emb_szs, len(joined.columns)-len(cat_vars),0.04, 1, [1000,500], [0.001,0.01], y_range=y_range)
#       2 #m = data.get_learner(emb_szs, len(joined.columns)-len(cat_vars),0.04, 1, [1000,500], [0.001,0.01])
# ----> 3 m.summary()
#
# ~/anaconda3/envs/fastai07/lib/python3.6/site-packages/fastai/column_data.py in summary(self)
#     141     def _get_crit(self, data): return F.mse_loss if data.is_reg else F.binary_cross_entropy if data.is_multi else F.nll_loss
#     142
# --> 143     def summary(self): return model_summary(self.model, [(self.data.trn_ds.cats.shape[1], ), (self.data.trn_ds.conts.shape[1], )])
#     144
#     145
#
# ~/anaconda3/envs/fastai07/lib/python3.6/site-packages/fastai/model.py in model_summary(m, input_size)
# ...

# %%
lr = 1e-3
m.lr_find()

# %%
joined.T
# Out:
#                   0        1         2        3        4         5     \
# id               19995      285    206647    49026    49529       559
# vote_average       7.2      6.9       6.3      7.6      6.1       5.9
# vote_count       11800     4500      4466     9106     2124      3576
# budget        2.37e+08    3e+08  2.45e+08  2.5e+08  2.6e+08  2.58e+08
# popularity     150.438  139.083   107.377  112.313   43.927     115.7
#
#                  6        7        8        9      ...         4793      4794  \
# id              38757    99861      767   209112   ...       182291    286939
# vote_average      7.4      7.3      7.4      5.7   ...            6         0
# vote_count       3330     6767     5293     7004   ...            2         0
# budget        2.6e+08  2.8e+08  2.5e+08  2.5e+08   ...            0         0
# popularity     48.682  134.279  98.8856   155.79   ...     0.029757  0.166513
#
#                   4795     4796      4797     4798      4799     4800  \
# ...

# %%
min_rating,max_rating = joined.popularity.min(),joined.popularity.max()
min_rating,max_rating
# Out:
# (0.0, 875.5813)

# %%
def get_emb(ni,nf):
    e = nn.Embedding(ni, nf)
    print(e)
    e.weight.data.uniform_(-0.01,0.01)
    #e.weight.data.normal_(0,0.003)
    print(e)
    return e

# %%
class EmbeddingNet(nn.Module):
    def __init__(self, n_users, n_movies, nh=10, p1=0.05, p2=0.5):
        super().__init__()
        (self.u, self.m) = [get_emb(*o) for o in [
            (n_users, n_factors), (n_movies, n_factors)]]
        self.lin1 = nn.Linear(n_factors*2, nh)
        self.lin2 = nn.Linear(nh, 1)
        self.drop1 = nn.Dropout(p1)
        self.drop2 = nn.Dropout(p2)
        
    def forward(self, cats, conts):
        users,movies = cats[:,0],cats[:,1]
        x = self.drop1(torch.cat([self.u(users),self.m(movies)], dim=1))
        x = self.drop2(F.relu(self.lin1(x)))
        return F.sigmoid(self.lin2(x)) * (max_rating-min_rating+1) + min_rating-0.5

# %%
n_movies=int(joined.id.nunique())
n_vote=int(joined.vote_average.nunique())
n_movies, n_popularity
# Out:
# (4803, 4802)

# %%
wd=1e-5
model = EmbeddingNet(n_movies, n_vote).cuda()

# %%
model
# Out:
# EmbeddingNet(
#   (u): Embedding(4803, 50)
#   (m): Embedding(71, 50)
#   (lin1): Linear(in_features=100, out_features=10, bias=True)
#   (lin2): Linear(in_features=10, out_features=1, bias=True)
#   (drop1): Dropout(p=0.05)
#   (drop2): Dropout(p=0.5)
# )

# %%
opt = optim.SGD(model.parameters(), 1e-1, weight_decay=wd, momentum=0.9)

# %%
fit(model, data, 3, opt, F.mse_loss)
# Out:
# ...
#   0%|          | 0/61 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-88-09a5bc469dee> in <module>
# ----> 1 fit(model, data, 3, opt, F.mse_loss)
#
# ~/anaconda3/envs/fastai07/lib/python3.6/site-packages/fastai/model.py in fit(model, data, n_epochs, opt, crit, metrics, callbacks, stepper, swa_model, swa_start, swa_eval_freq, **kwargs)
#     127             batch_num += 1
#     128             for cb in callbacks: cb.on_batch_begin()
# --> 129             loss = model_stepper.step(V(x),V(y), epoch)
#     130             avg_loss = avg_loss * avg_mom + loss * (1-avg_mom)
#     131             debias_loss = avg_loss / (1 - avg_mom**batch_num)
#
# ~/anaconda3/envs/fastai07/lib/python3.6/site-packages/fastai/model.py in step(self, xs, y, epoch)
#      46     def step(self, xs, y, epoch):
#      47         xtra = []
# ...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.autograd import Variable
import torch.optim as optim


import h5py
with h5py.File('/home/sashag/supercomp/insults/dataset.h5','r') as hf:
    print('List of arrays in this file: \n', hf.keys())
    X_train = torch.from_numpy(np.array(hf.get('X_train'), dtype="int_").transpose())
    Y_train = torch.from_numpy(np.array(hf.get('Y_train'), dtype='int_'))
    X_test = torch.from_numpy(np.array(hf.get('X_test'), dtype="int_").transpose())
    Y_test = torch.from_numpy(np.array(hf.get('Y_test'), dtype='int_'))
  

maxlen = 200

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #learnable parameters
        self.one_hot_params = nn.Embedding(num_embeddings=200, embedding_dim=200)
        self.first_conv_params = nn.Conv1d(in_channels=200, out_channels=256, kernel_size=7) 
        self.first_maxpool_params = nn.MaxPool1d(kernel_size=3, stride=3)
        self.second_conv_params = nn.Conv1d(in_channels=256, out_channels=256, kernel_size=7) 
        self.second_maxpool_params = nn.MaxPool1d(kernel_size=3, stride=3)
        self.linear1_params = nn.Linear(4864, 256)
        self.linear2_params = nn.Linear(256, 1)
    
    def forward(self, x):
        x = self.one_hot_params(x).transpose(1, 2).contiguous() # .transpose(1, 2).contiguous()
        x = F.relu(self.first_maxpool_params(self.first_conv_params(x)))
        x = F.relu(self.second_maxpool_params(self.second_conv_params(x)))
        #print(x.size()[1] * x.size()[2]) #flatten to
        x = x.view(-1,4864)
        x = F.dropout(x, p=0.5)
        x = F.relu(self.linear1_params(x))
        x = F.dropout(x, p=0.5)
        x = self.linear2_params(x)
        return F.sigmoid(x)


model = Net()

inputs = Variable(X_train)
target = Variable(Y_train)
loss_fn = nn.CrossEntropyLoss()


#model.cuda()
model.cpu()
optimizer = optim.Adam(model.parameters(), lr = 0.0001)
  
for epoch in range(10): # loop over the dataset multiple times
    
    running_loss = 0.0
    #for i in range(0,inputs.size()[0]):
       # print(i)
        # zero the parameter gradients
    optimizer.zero_grad() # zero the gradient buffers
    # forward + backward + optimize
    outputs = model(inputs).view(3947) #forward
    mae = torch.mean(torch.abs(outputs - target.float()))
    print(mae)
    loss = loss_fn(outputs, target)
    print(loss)
    loss.backward()        
    optimizer.step() # does the update
