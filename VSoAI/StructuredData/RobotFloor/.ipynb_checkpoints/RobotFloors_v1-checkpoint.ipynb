# %% [markdown]
# https://www.kaggle.com/danisamba/new-in-kaggle-eda-step-by-step
# https://www.kaggle.com/jesucristo/1-smart-robots-complete-notebook-0-73/notebook
# https://www.kaggle.com/premvardhan/identify-robot-surface-careercon2019
# https://www.kaggle.com/axel81/help-humanity-by-helping-robots-fastai

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import fastai
print("fastai: ",fastai.__version__)
import torch
print("Torch: ",torch.__version__)
import torchvision
print("Torchvision: ",torchvision.__version__)
import sklearn
print("sklearn: ",sklearn.__version__)
import sys
print("Python: ",sys.version)
# Out:
# fastai:  1.0.46
# Torch:  1.0.1.post2
# Torchvision:  0.2.1
# sklearn:  0.20.2
# Python:  3.7.2 (default, Dec 29 2018, 06:19:36)
# [GCC 7.3.0]

# %%
if torch.cuda.is_available():
    devID=torch.cuda.current_device()
    print("GPU: ",torch.cuda.get_device_name(devID))
else:
    print("Torch Cuda not avaialbe")
# Out:
# GPU:  GeForce GTX 1080 Ti

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
from fastai.vision import *
from fastai.metrics import error_rate
from fastai import *

# %%
PATH = '../../../../../data/RobotFloor/'

# %%
import os
print(os.listdir(PATH))
# Out:
# ['X_train.csv', 'X_test.csv.zip', 'X_train.csv.zip', 'y_train.csv', 'sample_submission.csv', 'X_test.csv']

# %%
x_train = pd.read_csv(PATH+'X_train.csv')
x_train.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0       -0.75853       -0.63435
# 1    0_1          0                   1       -0.75853       -0.63434
# 2    0_2          0                   2       -0.75853       -0.63435
# 3    0_3          0                   3       -0.75852       -0.63436
# 4    0_4          0                   4       -0.75852       -0.63435
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.107650            0.017561
# 1       -0.10490       -0.10600            0.067851            0.029939
# 2       -0.10492       -0.10597            0.007275            0.028934
# 3       -0.10495       -0.10597           -0.013053            0.019448
# 4       -0.10495       -0.10596            0.005135            0.007652
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# ...

# %%
x_train.describe()
# Out:
#            series_id  measurement_number  orientation_X  orientation_Y  \
# count  487680.000000       487680.000000  487680.000000  487680.000000
# mean     1904.500000           63.500000      -0.018050       0.075062
# std      1099.853353           36.949327       0.685696       0.708226
# min         0.000000            0.000000      -0.989100      -0.989650
# 25%       952.000000           31.750000      -0.705120      -0.688980
# 50%      1904.500000           63.500000      -0.105960       0.237855
# 75%      2857.000000           95.250000       0.651803       0.809550
# max      3809.000000          127.000000       0.989100       0.988980
#
#        orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# count  487680.000000  487680.000000       487680.000000       487680.000000
# mean        0.012458      -0.003804            0.000178            0.008338
# std         0.105972       0.104299            0.117764            0.088677
# ...

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487680 entries, 0 to 487679
# Data columns (total 13 columns):
# row_id                   487680 non-null object
# series_id                487680 non-null int64
# measurement_number       487680 non-null int64
# orientation_X            487680 non-null float64
# orientation_Y            487680 non-null float64
# orientation_Z            487680 non-null float64
# orientation_W            487680 non-null float64
# angular_velocity_X       487680 non-null float64
# angular_velocity_Y       487680 non-null float64
# angular_velocity_Z       487680 non-null float64
# linear_acceleration_X    487680 non-null float64
# linear_acceleration_Y    487680 non-null float64
# linear_acceleration_Z    487680 non-null float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 48.4+ MB

# %%
x_train.shape
# Out:
# (487680, 13)

# %%
# Total Series 
x_train.shape[0]/128
# Out:
# 3810.0

# %%
#On average, is there any difference between the surface types? Let's see:
#x_train.groupby("target").mean()

# %%
y_train = pd.read_csv(PATH+'y_train.csv')
y_train.head()
# Out:
#    series_id  group_id        surface
# 0          0        13  fine_concrete
# 1          1        31       concrete
# 2          2        20       concrete
# 3          3        31       concrete
# 4          4        22     soft_tiles

# %%
y_train.shape
# Out:
# (3810, 3)

# %%
y_train.group_id.describe()
# Out:
# count    3810.000000
# mean       37.601312
# std        20.982743
# min         0.000000
# 25%        19.000000
# 50%        39.000000
# 75%        55.000000
# max        72.000000
# Name: group_id, dtype: float64

# %%
# total differnet values of group_id
len(y_train.group_id.value_counts())
# Out:
# 73

# %%
# total differnet values of surface
len(y_train.surface.value_counts())
# Out:
# 9

# %%
# total differnet values of series_id
len(y_train.series_id.value_counts())
# Out:
# 3810

# %%
#check if target has any missing values
y_train.surface.isnull().values.any()
# Out:
# False

# %%
y_train.isnull().sum()
# Out:
# series_id    0
# group_id     0
# surface      0
# dtype: int64

# %%
#any duplicates
y_train.duplicated().any()
# Out:
# False

# %%
# any missing in x_train
x_train.isnull().values.any()
# Out:
# False

# %%
x_train.isnull().sum()
# Out:
# row_id                   0
# series_id                0
# measurement_number       0
# orientation_X            0
# orientation_Y            0
# orientation_Z            0
# orientation_W            0
# angular_velocity_X       0
# angular_velocity_Y       0
# angular_velocity_Z       0
# linear_acceleration_X    0
# linear_acceleration_Y    0
# linear_acceleration_Z    0
# dtype: int64

# %%
#any duplicates
x_train.duplicated().any()
# Out:
# False

# %%
plt.hist(y_train.group_id)
# Out:
# (array([340., 396., 342., 283., 342., 491., 421., 352., 352., 491.]),
#  array([ 0. ,  7.2, 14.4, 21.6, 28.8, 36. , 43.2, 50.4, 57.6, 64.8, 72. ]),
#  <a list of 10 Patch objects>)

# %%
#plt.hist(y_train['surface'])

# %%
x_test = pd.read_csv(PATH+'X_test.csv')
x_test.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0      -0.025773       -0.98864
# 1    0_1          0                   1      -0.025683       -0.98862
# 2    0_2          0                   2      -0.025617       -0.98861
# 3    0_3          0                   3      -0.025566       -0.98862
# 4    0_4          0                   4      -0.025548       -0.98866
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.14801       0.003350           -0.006524           -0.001071
# 1       -0.14816       0.003439           -0.113960            0.083987
# 2       -0.14826       0.003571           -0.080518            0.114860
# 3       -0.14817       0.003609            0.070067            0.033820
# 4       -0.14792       0.003477            0.152050           -0.029016
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# ...

# %%
# any missing in Y_train
x_test.isnull().values.any()
# Out:
# False

# %%
#list missing columns counts
x_test.isnull().sum()
# Out:
# row_id                   0
# series_id                0
# measurement_number       0
# orientation_X            0
# orientation_Y            0
# orientation_Z            0
# orientation_W            0
# angular_velocity_X       0
# angular_velocity_Y       0
# angular_velocity_Z       0
# linear_acceleration_X    0
# linear_acceleration_Y    0
# linear_acceleration_Z    0
# dtype: int64

# %%
#any duplicates
x_test.duplicated().any()
# Out:
# False

# %%
x_test.describe()
# Out:
#            series_id  measurement_number  orientation_X  orientation_Y  \
# count  488448.000000       488448.000000  488448.000000  488448.000000
# mean     1907.500000           63.500000       0.031996       0.120651
# std      1101.585403           36.949327       0.671977       0.714522
# min         0.000000            0.000000      -0.989720      -0.989810
# 25%       953.750000           31.750000      -0.648130      -0.744503
# 50%      1907.500000           63.500000       0.132910       0.397860
# 75%      2861.250000           95.250000       0.575270       0.803600
# max      3815.000000          127.000000       0.989320       0.988940
#
#        orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# count  488448.000000  488448.000000       488448.000000       488448.000000
# mean        0.018735       0.004024            0.000401            0.013669
# std         0.108481       0.100957            0.114485            0.089440
# ...

# %%
plt.figure(figsize=(12,4))
sns.set()
ax=sns.countplot(x = 'surface',
              data = y_train,
              order = y_train['surface'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.show()

# %%
# Each series has 128 measurements.
# 1 serie = 128 measurements.
len(x_train.measurement_number.value_counts())
# Out:
# 128

# %%
x_train.shape[0]/y_train.shape[0]
# Out:
# 128.0

# %%
# How many recordings do we have?
y_train.shape[0], x_train.series_id.nunique()
# Out:
# (3810, 3810)

# %%
print('Number of classes: {}'.format(y_train.surface.nunique()))
print('Number of group_id: {}'.format(y_train.group_id.nunique()))
# Out:
# Number of classes: 9
# Number of group_id: 73

# %%
#Have different surfaces been measured in the same recording session?
# No, in every recording session only was tried a surface type.
y_train.groupby('group_id').surface.nunique().max()
# Out:
# 1

# %%
y_train.surface[0]
# Out:
# 'fine_concrete'

# %%
# series_id size is 128 measurements each
plt.figure(figsize=(26, 16))
for i, col in enumerate(x_train[:128].columns[3:]):
    plt.subplot(3, 4, i + 1)
    plt.plot(x_train[:128][col])
    plt.title(col)

# %%
# Plot TRAIN and TEST variable distributions

def plot_feature_distribution(df1, df2, label1, label2, features,a=2,b=5):
    i = 0
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(a,b,figsize=(17,9))

    for feature in features:
        i += 1
        plt.subplot(a,b,i)
        sns.kdeplot(df1[feature], bw=0.5,label=label1)
        sns.kdeplot(df2[feature], bw=0.5,label=label2)
        plt.xlabel(feature, fontsize=9)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=8)
        plt.tick_params(axis='y', which='major', labelsize=8)
    plt.show();

# %%
features = x_train.columns.values[3:]
plot_feature_distribution(x_train, x_test, 'train', 'test', features)

# %%
#Sorting x_train and x_test based on Series_id and measurement_number
x_train_sort = x_train.sort_values(by = ['series_id', 'measurement_number'], ascending = True)
x_train_sort.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0       -0.75853       -0.63435
# 1    0_1          0                   1       -0.75853       -0.63434
# 2    0_2          0                   2       -0.75853       -0.63435
# 3    0_3          0                   3       -0.75852       -0.63436
# 4    0_4          0                   4       -0.75852       -0.63435
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.107650            0.017561
# 1       -0.10490       -0.10600            0.067851            0.029939
# 2       -0.10492       -0.10597            0.007275            0.028934
# 3       -0.10495       -0.10597           -0.013053            0.019448
# 4       -0.10495       -0.10596            0.005135            0.007652
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# ...

# %%
#Sorting x_train and x_test based on Series_id and measurement_number
x_test_sort = x_test.sort_values(by = ['series_id', 'measurement_number'], ascending = True)
x_test_sort.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0      -0.025773       -0.98864
# 1    0_1          0                   1      -0.025683       -0.98862
# 2    0_2          0                   2      -0.025617       -0.98861
# 3    0_3          0                   3      -0.025566       -0.98862
# 4    0_4          0                   4      -0.025548       -0.98866
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.14801       0.003350           -0.006524           -0.001071
# 1       -0.14816       0.003439           -0.113960            0.083987
# 2       -0.14826       0.003571           -0.080518            0.114860
# 3       -0.14817       0.003609            0.070067            0.033820
# 4       -0.14792       0.003477            0.152050           -0.029016
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# ...
