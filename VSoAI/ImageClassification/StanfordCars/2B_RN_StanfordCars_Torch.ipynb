# %% [markdown]
# ## Stanford Cars Image classification with Convolutional Neural Networks

# %% [markdown]
# https://www.kaggle.com/jutrera/stanford-car-dataset-by-classes-folder

# %%
## Check GPU memory availability

# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Requirement already satisfied: gputil in /usr/local/lib/python3.6/dist-packages (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gputil) (1.14.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Gen RAM Free: 12.9 GB  | Proc size: 236.2 MB
# GPU RAM Free: 11430MB | Used: 11MB | Util   0% | Total 11441MB

# %%
## install and setup Fast.ai v.0.7.0, pytorch and dependencies

#!pip uninstall fastai
# !pip install Pillow==4.1.1
# !pip install "fastai==0.7.0"
# !pip install torchtext==0.2.3
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
import cv2
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
# !apt update && apt install -y libsm6 libxext6

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'
# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch
# !pip install image

# %matplotlib inline
from fastai.imports import *
# Out:
# Requirement already satisfied: Pillow==4.1.1 in /usr/local/lib/python3.6/dist-packages (4.1.1)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.1.1) (0.46)
# Requirement already satisfied: fastai==0.7.0 in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.7)
# Requirement already satisfied: pandas-summary in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.0.5)
# Requirement already satisfied: jedi in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.13.1)
# Requirement already satisfied: plotnine in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.2)
# Requirement already satisfied: feather-format in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (5.5.0)
# Requirement already satisfied: cycler in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.10.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.10.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.6.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.4.2)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.0.2)
# Requirement already satisfied: sklearn-pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.7.0)
# Requirement already satisfied: bcolz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.2.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.3.0)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.4.3.18)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.13)
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.1.0)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (17.0.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.6.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.3)
# Requirement already satisfied: simplegeneric in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.28.1)
# Requirement already satisfied: torchtext in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.3)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (7.4.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.6.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.14.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.1.1)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.5.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.10.15)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.22.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.3.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.1.0)
# Requirement already satisfied: torch<0.4 in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.3.0.post4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.1.7)
# Requirement already satisfied: widgetsnbextension in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.4.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.1)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.0.0)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.0.1)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.10)
# Requirement already satisfied: parso>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from jedi->fastai==0.7.0) (0.3.1)
# Requirement already satisfied: mizani>=0.5.2 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.5.2)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.5.1)
# Requirement already satisfied: descartes>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (1.1.0)
# Requirement already satisfied: statsmodels>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.8.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai==0.7.0) (1.11.0)
# Requirement already satisfied: pyarrow>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from feather-format->fastai==0.7.0) (0.11.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (1.0.15)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (4.6.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (40.5.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from sklearn-pandas->fastai==0.7.0) (0.19.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel->fastai==0.7.0) (5.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext->fastai==0.7.0) (2.18.4)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->fastai==0.7.0) (0.46)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension->fastai==0.7.0) (5.2.2)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (6.0.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.4.0)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (4.4.3)
# Requirement already satisfied: palettable in /usr/local/lib/python3.6/dist-packages (from mizani>=0.5.2->plotnine->fastai==0.7.0) (3.1.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (2.6)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.8.1)
# Requirement already satisfied: mistune>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (1.4.2)
# Requirement already satisfied: torchtext==0.2.3 in /usr/local/lib/python3.6/dist-packages (0.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (2.18.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (4.28.1)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2018.10.15)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (1.22)
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [83.2 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  InRelease
# Hit:3 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [248 kB]
# Ign:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  Release
# Hit:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Fetched 495 kB in 6s (80.6 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 5 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.2-1).
# libxext6 is already the newest version (2:1.3.3-1).
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.
# Requirement already satisfied: image in /usr/local/lib/python3.6/dist-packages (1.5.27)
# Requirement already satisfied: django in /usr/local/lib/python3.6/dist-packages (from image) (2.1.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from image) (4.1.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from django->image) (2018.7)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->image) (0.46)

# %%
import sys
sys.version
# Out:
# '3.6.6 (default, Sep 12 2018, 18:26:19) \n[GCC 8.0.1 20180414 (experimental) [trunk revision 259383]]'

# %%
import torch
print(torch.__version__)
# Out:
# 0.3.0.post4

# %% [markdown]
# It's important that you have a working NVidia GPU set up. The programming framework used to behind the scenes to work with NVidia GPUs is called CUDA. Therefore, you need to ensure the following line returns `True` before you proceed. If you have problems with this, please check the FAQ and ask for help on [the forums](http://forums.fast.ai).

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# In addition, NVidia provides special accelerated functions for deep learning in a package called CuDNN. Although not strictly necessary, it will improve training performance significantly, and is included by default in all supported fastai configurations. Therefore, if the following does not return `True`, you may want to look into why.

# %%
torch.backends.cudnn.enabled
# Out:
# True

# %%
#import fastai as fai
#from fastai.imports import *

# %%
#from fastai.transforms import *
#from fastai.conv_learner import *
#from fastai.model import *
#from fastai.dataset import *
#from fastai.sgdr import *
#from fastai.plots import *

# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
#%reload_ext autoreload
#%autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Loading Dataset

# %%
#The first step is install kaggle
#!pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: urllib3<1.23.0,>=1.15 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.5.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.2.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2018.10.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.18.4)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.11.0)
# Requirement already satisfied: Unidecode>=0.04.16 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.0.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.6)

# %%
#The second step is upload the credentials of the kaggle account.You should go to you kaggle account and to get there you apy key.You will get kaggle.json file.Then use
#the code bellow for upload that key on colab.

##from google.colab import files
#files.upload()
# Out:
#      <input type="file" id="files-9dfe1fa6-2b25-40c7-89fb-97e9f37908a7" name="files[]" multiple disabled />
#      <output id="result-9dfe1fa6-2b25-40c7-89fb-97e9f37908a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"remisn","key":"e9675d8658626ec9da90cbb6bba54f92"}'}

# %%
#The third step is create some folder
#before importing the dataset we sholud use this code
#The kaggle API client expects this file to be in ~/.kaggle

#!mkdir -p ~/.kaggle
#!cp kaggle.json ~/.kaggle/

#this permissions change avoids a warnong on Kaggle tool startup
#!chmod 600 ~/.kaggle/kaggle.json

# %%
#The forth step is get some dataset or competition or list it depends on you demands.My sample is this dataset
#!kaggle datasets download -d jessicali9530/stanford-cars-dataset
#!kaggle datasets download -d jutrera/stanford-car-dataset-by-classes-folder
# Out:
# Downloading stanford-car-dataset-by-classes-folder.zip to /content
# 100% 1.82G/1.82G [00:13<00:00, 148MB/s]
# 100% 1.82G/1.82G [00:13<00:00, 148MB/s]

# %%
# since kaggle API produced Server Error, use alternative method to download data set
#!curl --header 'Host: storage.googleapis.com' --user-agent 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0' --header 'Accept: text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8' --header 'Accept-Language: en-US,en;q=0.5' --referer 'https://www.kaggle.com/' --cookie '_ga=GA1.3.597929118.1540370868' --header 'Upgrade-Insecure-Requests: 1' 'https://storage.googleapis.com/kaggle-datasets/31559/46697/stanford-car-dataset-by-classes-folder.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1541595064&Signature=i2U2xOV7K5%2FOrN6TnYkemVF4bX5cpFkUQ2iLJN9Ri8%2F5pVYSK1v1utTdd2G8pxVF5oIJkmfS7nR8rH%2FORKd4GdHJMKBFegkNdiMIaYW3xqj%2Fgcr7OOc9AsCcftCnKtIezNlOTLBbVyy52sDh12DaphjbBOh%2BhAtgkxKjkXZa1SmQEzdh8OrfILrhIeZwCza%2FrzCgNbRYH7uVVMMBwErBiIV%2FNMjTfoYnS75zZAWU8w9Sgl6Wr0YPBQOFp5MjrttWWbhxtY%2BbeFv8LHu4Q9lTx5bVarbyn2dF%2BOViJZtKECaqknceXT5Ww4MZYp158gdqegaJtx5ey9oG2yso3ejYVw%3D%3D' --output 'stanford-car-dataset-by-classes-folder.zip'
# !curl --header 'Host: storage.googleapis.com' --user-agent 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0' --header 'Accept: text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8' --header 'Accept-Language: en-US,en;q=0.5' --referer 'https://www.kaggle.com/' --cookie '_ga=GA1.3.597929118.1540370868' --header 'Upgrade-Insecure-Requests: 1' 'https://storage.googleapis.com/kaggle-datasets/31559/46697/stanford-car-dataset-by-classes-folder.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1542721521&Signature=IxuMf2cYrqPLZnHwIN%2FYgqjB4AmZRlc1tic2zQvw7riMnj7iyKNL%2FTr9APeH85Pn6xPszzlYPG2l3aGPteZM0Lg8mxB%2F%2FezvHLvTWJyTa92YPcIyOsOsGl%2BVARVsCJzjDRn4p%2FoBc7sSjUwH5JLC4w7F2EDRSYV%2FC5lXY1O3ffq%2Fw9GVeccbn%2B1jEkjvt31R5kt4ElkfUo9x0vWNO78VsPnxGZgBiiT6AoIx%2FKpCuzZFeIhAO5XctdXWNlIBKnjVZ4iy0bIbBD5aabZa1S%2B4GkjSQSx6TxkGj8%2BsUHFuCtZfmsQ6eenU6l3ZVRJ%2FwbuX6IJn7T29WaV2Ui2MQXMuYg%3D%3D' --output 'stanford-car-dataset-by-classes-folder.zip'

# %%
#lets see the imported files from kaggle dataset
# !ls
# Out:
#  anno_test.csv	 'kaggle (1).json'   stanford-car-dataset-by-classes-folder.zip
#  anno_train.csv   kaggle.json	     weights
#  car_data	  names.csv	     weights.tgz
#  car_data.zip	  sample_data

# %%
#if you download zipped file you should unzip
#unzip in my case dataset
from zipfile import ZipFile
file_name = "stanford-car-dataset-by-classes-folder.zip"

with ZipFile(file_name, 'r') as zipF:
  zipF.extractall()
  print('Done')
# Out:
# Done

# %%
# !ls -l
# Out:
# total 4994644
# -rw-r--r-- 1 root root     225299 Nov 12 10:55  anno_test.csv
# -rw-r--r-- 1 root root     228214 Nov 12 10:55  anno_train.csv
# drwxr-xr-x 5 root root       4096 Nov 12 09:54  car_data
# -rw-r--r-- 1 root root 1959909765 Nov 12 10:55  car_data.zip
# -rw-r--r-- 1 root root         62 Nov 12 10:55 'kaggle (1).json'
# -rw-r--r-- 1 root root         62 Nov 12 09:51  kaggle.json
# -rw-r--r-- 1 root root       5454 Nov 12 10:55  names.csv
# drwxr-xr-x 2 root root       4096 Nov  7 20:08  sample_data
# -rw-r--r-- 1 root root 1958687182 Nov 12 10:55  stanford-car-dataset-by-classes-folder.zip
# drwxrwxr-x 2 1001 1001       4096 Nov  4  2017  weights
# -rw-r--r-- 1 root root 1195411318 Nov  4  2017  weights.tgz

# %%
file_name = "car_data.zip"

with ZipFile(file_name, 'r') as zipF:
  zipF.extractall()
  print('Done')
# Out:
# Done

# %%
# !ls car_data/test/'Acura Integra Type R 2001'
# Out:
# 00128.jpg  01176.jpg  02458.jpg  03920.jpg  05081.jpg  06031.jpg  07468.jpg
# 00130.jpg  01326.jpg  02595.jpg  04471.jpg  05181.jpg  06181.jpg  07889.jpg
# 00386.jpg  01864.jpg  02742.jpg  04481.jpg  05230.jpg  06701.jpg
# 00565.jpg  02011.jpg  02798.jpg  04741.jpg  05383.jpg  06717.jpg
# 00711.jpg  02182.jpg  03056.jpg  04795.jpg  05581.jpg  06852.jpg
# 01002.jpg  02425.jpg  03466.jpg  04933.jpg  05667.jpg  07108.jpg
# 01035.jpg  02433.jpg  03748.jpg  04951.jpg  05848.jpg  07386.jpg

# %%
# And you can delete you zipped folder cause you have unzipped
# !rm -rf stanford-car-dataset-by-classes-folder.zip

# %%
# !ls car_data/train
# Out:
# 'Acura Integra Type R 2001'
# 'Acura RL Sedan 2012'
# 'Acura TL Sedan 2012'
# 'Acura TL Type-S 2008'
# 'Acura TSX Sedan 2012'
# 'Acura ZDX Hatchback 2012'
# 'AM General Hummer SUV 2000'
# 'Aston Martin V8 Vantage Convertible 2012'
# 'Aston Martin V8 Vantage Coupe 2012'
# 'Aston Martin Virage Convertible 2012'
# 'Aston Martin Virage Coupe 2012'
# 'Audi 100 Sedan 1994'
# 'Audi 100 Wagon 1994'
# 'Audi A5 Coupe 2012'
# 'Audi R8 Coupe 2012'
# 'Audi RS 4 Convertible 2008'
# 'Audi S4 Sedan 2007'
# 'Audi S4 Sedan 2012'
# 'Audi S5 Convertible 2012'
# 'Audi S5 Coupe 2012'
# 'Audi S6 Sedan 2011'
# 'Audi TT Hatchback 2011'
# 'Audi TT RS Coupe 2012'
# 'Audi TTS Coupe 2012'
# 'Audi V8 Sedan 1994'
# 'Bentley Arnage Sedan 2009'
# 'Bentley Continental Flying Spur Sedan 2007'
# 'Bentley Continental GT Coupe 2007'
# 'Bentley Continental GT Coupe 2012'
# 'Bentley Continental Supersports Conv. Convertible 2012'
# 'Bentley Mulsanne Sedan 2011'
# 'BMW 1 Series Convertible 2012'
# 'BMW 1 Series Coupe 2012'
# 'BMW 3 Series Sedan 2012'
# 'BMW 3 Series Wagon 2012'
# 'BMW 6 Series Convertible 2007'
# 'BMW ActiveHybrid 5 Sedan 2012'
# 'BMW M3 Coupe 2012'
# 'BMW M5 Sedan 2010'
# 'BMW M6 Convertible 2010'
# 'BMW X3 SUV 2012'
# 'BMW X5 SUV 2007'
# 'BMW X6 SUV 2012'
# 'BMW Z4 Convertible 2012'
# 'Bugatti Veyron 16.4 Convertible 2009'
# 'Bugatti Veyron 16.4 Coupe 2009'
# 'Buick Enclave SUV 2012'
# 'Buick Rainier SUV 2007'
# 'Buick Regal GS 2012'
# 'Buick Verano Sedan 2012'
# 'Cadillac CTS-V Sedan 2012'
# 'Cadillac Escalade EXT Crew Cab 2007'
# 'Cadillac SRX SUV 2012'
# 'Chevrolet Avalanche Crew Cab 2012'
# 'Chevrolet Camaro Convertible 2012'
# 'Chevrolet Cobalt SS 2010'
# 'Chevrolet Corvette Convertible 2012'
# 'Chevrolet Corvette Ron Fellows Edition Z06 2007'
# 'Chevrolet Corvette ZR1 2012'
# 'Chevrolet Express Cargo Van 2007'
# 'Chevrolet Express Van 2007'
# 'Chevrolet HHR SS 2010'
# 'Chevrolet Impala Sedan 2007'
# 'Chevrolet Malibu Hybrid Sedan 2010'
# 'Chevrolet Malibu Sedan 2007'
# 'Chevrolet Monte Carlo Coupe 2007'
# 'Chevrolet Silverado 1500 Classic Extended Cab 2007'
# 'Chevrolet Silverado 1500 Extended Cab 2012'
# 'Chevrolet Silverado 1500 Hybrid Crew Cab 2012'
# 'Chevrolet Silverado 1500 Regular Cab 2012'
# 'Chevrolet Silverado 2500HD Regular Cab 2012'
# 'Chevrolet Sonic Sedan 2012'
# 'Chevrolet Tahoe Hybrid SUV 2012'
# 'Chevrolet TrailBlazer SS 2009'
# 'Chevrolet Traverse SUV 2012'
# 'Chrysler 300 SRT-8 2010'
# 'Chrysler Aspen SUV 2009'
# 'Chrysler Crossfire Convertible 2008'
# 'Chrysler PT Cruiser Convertible 2008'
# 'Chrysler Sebring Convertible 2010'
# 'Chrysler Town and Country Minivan 2012'
# 'Daewoo Nubira Wagon 2002'
# 'Dodge Caliber Wagon 2007'
# 'Dodge Caliber Wagon 2012'
# 'Dodge Caravan Minivan 1997'
# 'Dodge Challenger SRT8 2011'
# 'Dodge Charger Sedan 2012'
# 'Dodge Charger SRT-8 2009'
# 'Dodge Dakota Club Cab 2007'
# 'Dodge Dakota Crew Cab 2010'
# 'Dodge Durango SUV 2007'
# 'Dodge Durango SUV 2012'
# 'Dodge Journey SUV 2012'
# 'Dodge Magnum Wagon 2008'
# 'Dodge Ram Pickup 3500 Crew Cab 2010'
# 'Dodge Ram Pickup 3500 Quad Cab 2009'
# 'Dodge Sprinter Cargo Van 2009'
# 'Eagle Talon Hatchback 1998'
# 'Ferrari 458 Italia Convertible 2012'
# 'Ferrari 458 Italia Coupe 2012'
# 'Ferrari California Convertible 2012'
# 'Ferrari FF Coupe 2012'
# 'FIAT 500 Abarth 2012'
# 'FIAT 500 Convertible 2012'
# 'Fisker Karma Sedan 2012'
# 'Ford Edge SUV 2012'
# 'Ford E-Series Wagon Van 2012'
# 'Ford Expedition EL SUV 2009'
# 'Ford F-150 Regular Cab 2007'
# 'Ford F-150 Regular Cab 2012'
# 'Ford F-450 Super Duty Crew Cab 2012'
# 'Ford Fiesta Sedan 2012'
# 'Ford Focus Sedan 2007'
# 'Ford Freestar Minivan 2007'
# 'Ford GT Coupe 2006'
# 'Ford Mustang Convertible 2007'
# 'Ford Ranger SuperCab 2011'
# 'Geo Metro Convertible 1993'
# 'GMC Acadia SUV 2012'
# 'GMC Canyon Extended Cab 2012'
# 'GMC Savana Van 2012'
# 'GMC Terrain SUV 2012'
# 'GMC Yukon Hybrid SUV 2012'
# 'Honda Accord Coupe 2012'
# 'Honda Accord Sedan 2012'
# 'Honda Odyssey Minivan 2007'
# 'Honda Odyssey Minivan 2012'
# 'HUMMER H2 SUT Crew Cab 2009'
# 'HUMMER H3T Crew Cab 2010'
# 'Hyundai Accent Sedan 2012'
# 'Hyundai Azera Sedan 2012'
# 'Hyundai Elantra Sedan 2007'
# 'Hyundai Elantra Touring Hatchback 2012'
# 'Hyundai Genesis Sedan 2012'
# 'Hyundai Santa Fe SUV 2012'
# 'Hyundai Sonata Hybrid Sedan 2012'
# 'Hyundai Sonata Sedan 2012'
# 'Hyundai Tucson SUV 2012'
# 'Hyundai Veloster Hatchback 2012'
# 'Hyundai Veracruz SUV 2012'
# 'Infiniti G Coupe IPL 2012'
# 'Infiniti QX56 SUV 2011'
# 'Isuzu Ascender SUV 2008'
# 'Jaguar XK XKR 2012'
# 'Jeep Compass SUV 2012'
# 'Jeep Grand Cherokee SUV 2012'
# 'Jeep Liberty SUV 2012'
# 'Jeep Patriot SUV 2012'
# 'Jeep Wrangler SUV 2012'
# 'Lamborghini Aventador Coupe 2012'
# 'Lamborghini Diablo Coupe 2001'
# 'Lamborghini Gallardo LP 570-4 Superleggera 2012'
# 'Lamborghini Reventon Coupe 2008'
# 'Land Rover LR2 SUV 2012'
# 'Land Rover Range Rover SUV 2012'
# 'Lincoln Town Car Sedan 2011'
# 'Maybach Landaulet Convertible 2012'
# 'Mazda Tribute SUV 2011'
# 'McLaren MP4-12C Coupe 2012'
# 'Mercedes-Benz 300-Class Convertible 1993'
# 'Mercedes-Benz C-Class Sedan 2012'
# 'Mercedes-Benz E-Class Sedan 2012'
# 'Mercedes-Benz S-Class Sedan 2012'
# 'Mercedes-Benz SL-Class Coupe 2009'
# 'Mercedes-Benz Sprinter Van 2012'
# 'MINI Cooper Roadster Convertible 2012'
# 'Mitsubishi Lancer Sedan 2012'
# 'Nissan 240SX Coupe 1998'
# 'Nissan Juke Hatchback 2012'
# 'Nissan Leaf Hatchback 2012'
# 'Nissan NV Passenger Van 2012'
# 'Plymouth Neon Coupe 1999'
# 'Porsche Panamera Sedan 2012'
# 'Ram C-V Cargo Van Minivan 2012'
# 'Rolls-Royce Ghost Sedan 2012'
# 'Rolls-Royce Phantom Drophead Coupe Convertible 2012'
# 'Rolls-Royce Phantom Sedan 2012'
# 'Scion xD Hatchback 2012'
# 'smart fortwo Convertible 2012'
# 'Spyker C8 Convertible 2009'
# 'Spyker C8 Coupe 2009'
# 'Suzuki Aerio Sedan 2007'
# 'Suzuki Kizashi Sedan 2012'
# 'Suzuki SX4 Hatchback 2012'
# 'Suzuki SX4 Sedan 2012'
# 'Tesla Model S Sedan 2012'
# 'Toyota 4Runner SUV 2012'
# 'Toyota Camry Sedan 2012'
# 'Toyota Corolla Sedan 2012'
# 'Toyota Sequoia SUV 2012'
# 'Volkswagen Beetle Hatchback 2012'
# 'Volkswagen Golf Hatchback 1991'
# 'Volkswagen Golf Hatchback 2012'
# 'Volvo 240 Sedan 1993'
# 'Volvo C30 Hatchback 2012'
# 'Volvo XC90 SUV 2007'

# %% [markdown]
# Here we import the libraries we need. We'll learn about what each does during the course.

# %%
PATH = "car_data/"

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## First look at pictures

# %% [markdown]
# Our library will assume that you have *train* and *valid* directories. It also assumes that each dir will have subdirs for each class you wish to recognize

# %%
files = os.listdir(f'{PATH}train/Acura Integra Type R 2001')[:5]
files
# Out:
# ['02738.jpg', '02919.jpg', '04833.jpg', '01911.jpg', '03877.jpg']

# %%
img = plt.imread(f'{PATH}train/Acura Integra Type R 2001/{files[3]}')
plt.imshow(img);

# %% [markdown]
# Here is how the raw data looks like

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
img[:4,:4]
# Out:
# array([[[49, 50, 52],
#         [49, 50, 52],
#         [49, 50, 52],
#         [50, 51, 53]],
#
#        [[49, 50, 52],
#         [49, 50, 52],
#         [49, 50, 52],
#         [50, 51, 53]],
#
#        [[49, 50, 52],
#         [49, 50, 52],
#         [49, 50, 52],
#         [50, 51, 53]],
#
#        [[49, 50, 52],
#         [49, 50, 52],
#         [49, 50, 52],
#         [50, 51, 53]]], dtype=uint8)

# %%
#arch = vgg16
#arch = resnet34
#arch = resnext50
#arch = resnext101_64
sz = 224
bs = 64

# %%
# fast.ai functions to initialize transform and data loader objects
tfms=tfms_from_model(arch, sz)
data = ImageClassifierData.from_paths(PATH, val_name='test', tfms=tfms, bs=bs, num_workers=4)

# %%
#pick first image just for viewing
pic = PATH + data.trn_ds.fnames[0]; pic
# Out:
# 'car_data/train/AM General Hummer SUV 2000/07966.jpg'

# %%
# !ls
# Out:
#  anno_test.csv	  car_data	'kaggle (1).json'   names.csv	  weights
#  anno_train.csv   car_data.zip	 kaggle.json	    sample_data   weights.tgz

# %%
img = PIL.Image.open(pic); img
#img = PIL.Image.open(f'{pic}');
#img = plt.imread(pic)
#plt.imshow(img);
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1200 at 0x7F3B7E744048>

# %%
# create python data dictionary {}, path/file and image size(x,y)
# ps very long processing time
e_d = {k: PIL.Image.open(PATH + k).size for k in data.trn_ds.fnames}

# %%
e_d
# Out:
# {'train/AM General Hummer SUV 2000/07966.jpg': (1600, 1200),
#  'train/AM General Hummer SUV 2000/04669.jpg': (512, 384),
#  'train/AM General Hummer SUV 2000/00462.jpg': (85, 64),
#  'train/AM General Hummer SUV 2000/04874.jpg': (160, 120),
#  'train/AM General Hummer SUV 2000/00707.jpg': (700, 439),
#  'train/AM General Hummer SUV 2000/05030.jpg': (640, 420),
#  'train/AM General Hummer SUV 2000/07290.jpg': (300, 276),
#  'train/AM General Hummer SUV 2000/08011.jpg': (250, 111),
#  'train/AM General Hummer SUV 2000/05657.jpg': (96, 72),
#  'train/AM General Hummer SUV 2000/01952.jpg': (500, 375),
#  'train/AM General Hummer SUV 2000/02050.jpg': (360, 235),
#  'train/AM General Hummer SUV 2000/06833.jpg': (137, 103),
#  'train/AM General Hummer SUV 2000/03393.jpg': (2405, 1600),
#  'train/AM General Hummer SUV 2000/05754.jpg': (96, 96),
#  'train/AM General Hummer SUV 2000/02363.jpg': (300, 183),
#  'train/AM General Hummer SUV 2000/07487.jpg': (400, 295),
#  'train/AM General Hummer SUV 2000/06262.jpg': (124, 93),
#  'train/AM General Hummer SUV 2000/04544.jpg': (339, 200),
#  'train/AM General Hummer SUV 2000/04056.jpg': (720, 303),
#  'train/Acura Integra Type R 2001/05042.jpg': (1119, 713),
#  'train/Acura Integra Type R 2001/07483.jpg': (800, 600),
#  'train/Acura Integra Type R 2001/01010.jpg': (957, 640),
#  'train/Acura Integra Type R 2001/07860.jpg': (600, 449),
#  'train/Acura Integra Type R 2001/07696.jpg': (750, 469),
#  'train/Acura Integra Type R 2001/06196.jpg': (575, 325),
#  'train/Acura Integra Type R 2001/03608.jpg': (600, 440),
#  'train/Acura Integra Type R 2001/06718.jpg': (640, 480),
#  'train/Acura Integra Type R 2001/07666.jpg': (640, 480),
#  'train/Acura Integra Type R 2001/03761.jpg': (600, 450),
#  'train/Acura Integra Type R 2001/01012.jpg': (800, 600),
#  'train/Acura Integra Type R 2001/01255.jpg': (799, 599),
#  'train/Acura Integra Type R 2001/07800.jpg': (700, 500),
#  'train/Acura Integra Type R 2001/00878.jpg': (1024, 768),
#  'train/Acura Integra Type R 2001/07174.jpg': (600, 401),
#  'train/Acura Integra Type R 2001/00308.jpg': (800, 480),
#  'train/Acura Integra Type R 2001/02095.jpg': (1600, 1043),
#  'train/Acura Integra Type R 2001/06538.jpg': (600, 450),
#  'train/Acura Integra Type R 2001/02605.jpg': (640, 334),
#  'train/Acura Integra Type R 2001/03715.jpg': (640, 480),
#  'train/Acura Integra Type R 2001/02911.jpg': (1600, 1196),
#  'train/Acura Integra Type R 2001/03968.jpg': (2048, 1536),
#  'train/Acura Integra Type R 2001/06244.jpg': (1024, 768),
#  'train/Acura Integra Type R 2001/04691.jpg': (800, 534),
#  'train/Acura RL Sedan 2012/02314.jpg': (450, 300),
#  'train/Acura RL Sedan 2012/05930.jpg': (440, 275),
#  'train/Acura RL Sedan 2012/05295.jpg': (450, 225),
#  'train/Acura RL Sedan 2012/03767.jpg': (300, 200),
#  'train/Acura RL Sedan 2012/06839.jpg': (300, 164),
#  'train/Acura RL Sedan 2012/01891.jpg': (640, 480),
#  'train/Acura RL Sedan 2012/07960.jpg': (288, 140),
#  'train/Acura RL Sedan 2012/04244.jpg': (800, 534),
#  'train/Acura RL Sedan 2012/00670.jpg': (550, 366),
#  'train/Acura RL Sedan 2012/02065.jpg': (750, 469),
#  'train/Acura RL Sedan 2012/03875.jpg': (800, 528),
#  'train/Acura RL Sedan 2012/03011.jpg': (1024, 683),
#  'train/Acura RL Sedan 2012/03690.jpg': (1000, 570),
#  'train/Acura RL Sedan 2012/04011.jpg': (480, 360),
#  'train/Acura RL Sedan 2012/05259.jpg': (900, 540),
#  'train/Acura RL Sedan 2012/03267.jpg': (460, 300),
#  'train/Acura RL Sedan 2012/06061.jpg': (2000, 1236),
#  'train/Acura RL Sedan 2012/03537.jpg': (478, 319),
#  'train/Acura RL Sedan 2012/07897.jpg': (628, 420),
#  'train/Acura RL Sedan 2012/04486.jpg': (750, 469),
#  'train/Acura RL Sedan 2012/05261.jpg': (250, 150),
#  'train/Acura RL Sedan 2012/01535.jpg': (450, 225),
#  'train/Acura RL Sedan 2012/02669.jpg': (800, 600),
#  'train/Acura RL Sedan 2012/01031.jpg': (960, 347),
#  'train/Acura TL Sedan 2012/03881.jpg': (620, 400),
#  'train/Acura TL Sedan 2012/05918.jpg': (300, 183),
#  'train/Acura TL Sedan 2012/03169.jpg': (588, 318),
#  'train/Acura TL Type-S 2008/03051.jpg': (490, 250),
#  'train/Acura TL Type-S 2008/05324.jpg': (424, 360),
#  'train/Acura TL Type-S 2008/07445.jpg': (500, 375),
#  'train/Acura TL Type-S 2008/05307.jpg': (588, 441),
#  'train/Acura TL Type-S 2008/03165.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/03795.jpg': (480, 360),
#  'train/Acura TL Type-S 2008/07364.jpg': (630, 473),
#  'train/Acura TL Type-S 2008/03512.jpg': (1600, 900),
#  'train/Acura TL Type-S 2008/04511.jpg': (1024, 681),
#  'train/Acura TL Type-S 2008/00392.jpg': (1024, 768),
#  'train/Acura TL Type-S 2008/03243.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/06099.jpg': (625, 469),
#  'train/Acura TL Type-S 2008/03102.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/06614.jpg': (500, 375),
#  'train/Acura TL Type-S 2008/07916.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/06302.jpg': (1024, 768),
#  'train/Acura TL Type-S 2008/03241.jpg': (800, 600),
#  'train/Acura TL Type-S 2008/03607.jpg': (986, 603),
#  'train/Acura TL Type-S 2008/00697.jpg': (600, 450),
#  'train/Acura TL Type-S 2008/01264.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/07752.jpg': (640, 485),
#  'train/Acura TL Type-S 2008/06422.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/07191.jpg': (480, 360),
#  'train/Acura TL Type-S 2008/03238.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/03467.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/02124.jpg': (500, 315),
#  'train/Acura TL Type-S 2008/05125.jpg': (640, 425),
#  'train/Acura TL Type-S 2008/02240.jpg': (1680, 1050),
#  'train/Acura TL Type-S 2008/04482.jpg': (500, 375),
#  'train/Acura TL Type-S 2008/07214.jpg': (656, 492),
#  'train/Acura TL Type-S 2008/07706.jpg': (1280, 782),
#  'train/Acura TL Type-S 2008/06145.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/05405.jpg': (1024, 768),
#  'train/Acura TL Type-S 2008/05057.jpg': (480, 360),
#  'train/Acura TL Type-S 2008/00920.jpg': (800, 390),
#  'train/Acura TL Type-S 2008/07050.jpg': (1280, 1024),
#  'train/Acura TL Type-S 2008/02274.jpg': (450, 275),
#  'train/Acura TL Type-S 2008/07463.jpg': (500, 287),
#  'train/Acura TL Type-S 2008/04349.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/07661.jpg': (640, 480),
#  'train/Acura TL Type-S 2008/02913.jpg': (496, 312),
#  'train/Acura TL Type-S 2008/05979.jpg': (500, 375),
#  'train/Acura TSX Sedan 2012/06296.jpg': (259, 194),
#  'train/Acura TSX Sedan 2012/00151.jpg': (300, 182),
#  'train/Acura TSX Sedan 2012/06388.jpg': (300, 199),
#  'train/Acura TSX Sedan 2012/07450.jpg': (264, 198),
#  'train/Acura TSX Sedan 2012/03054.jpg': (590, 446),
#  'train/Acura TSX Sedan 2012/00424.jpg': (440, 330),
#  'train/Acura TSX Sedan 2012/00631.jpg': (281, 180),
#  'train/Acura TSX Sedan 2012/00410.jpg': (424, 360),
#  'train/Acura TSX Sedan 2012/05128.jpg': (259, 194),
#  'train/Acura TSX Sedan 2012/03081.jpg': (259, 194),
#  'train/Acura TSX Sedan 2012/06292.jpg': (1024, 768),
#  'train/Acura TSX Sedan 2012/06774.jpg': (2560, 1920),
#  'train/Acura TSX Sedan 2012/04470.jpg': (300, 200),
#  'train/Acura TSX Sedan 2012/02111.jpg': (259, 195),
#  'train/Acura TSX Sedan 2012/03511.jpg': (300, 199),
#  'train/Acura TSX Sedan 2012/06850.jpg': (1024, 768),
#  'train/Acura TSX Sedan 2012/01134.jpg': (300, 187),
#  'train/Acura TSX Sedan 2012/03191.jpg': (300, 152),
#  'train/Acura TSX Sedan 2012/00069.jpg': (800, 533),
#  'train/Acura TSX Sedan 2012/08016.jpg': (259, 194),
#  'train/Acura TSX Sedan 2012/02457.jpg': (1024, 683),
#  'train/Acura TSX Sedan 2012/02670.jpg': (320, 240),
#  'train/Acura TSX Sedan 2012/04651.jpg': (1024, 768),
#  'train/Acura TSX Sedan 2012/04392.jpg': (400, 250),
#  'train/Acura TSX Sedan 2012/03417.jpg': (259, 194),
#  'train/Acura TSX Sedan 2012/01972.jpg': (256, 192),
#  'train/Acura TSX Sedan 2012/01392.jpg': (500, 375),
#  'train/Acura TSX Sedan 2012/06313.jpg': (300, 225),
#  'train/Acura TSX Sedan 2012/03641.jpg': (640, 480),
#  'train/Acura TSX Sedan 2012/03965.jpg': (1920, 1200),
#  'train/Acura TSX Sedan 2012/04484.jpg': (300, 200),
#  'train/Acura TSX Sedan 2012/00742.jpg': (272, 186),
#  'train/Acura TSX Sedan 2012/02843.jpg': (300, 164),
#  'train/Acura TSX Sedan 2012/04338.jpg': (480, 360),
#  'train/Acura TSX Sedan 2012/02897.jpg': (268, 188),
#  'train/Acura TSX Sedan 2012/08127.jpg': (400, 198),
#  'train/Acura TSX Sedan 2012/03127.jpg': (480, 360),
#  'train/Acura TSX Sedan 2012/00700.jpg': (480, 360),
#  'train/Acura TSX Sedan 2012/06183.jpg': (600, 400),
#  'train/Acura TSX Sedan 2012/02004.jpg': (700, 438),
#  'train/Acura TSX Sedan 2012/02739.jpg': (300, 138),
#  'train/Acura ZDX Hatchback 2012/03308.jpg': (630, 418),
#  'train/Acura ZDX Hatchback 2012/07769.jpg': (440, 354),
#  'train/Acura ZDX Hatchback 2012/01468.jpg': (623, 389),
#  'train/Acura ZDX Hatchback 2012/01901.jpg': (480, 360),
#  'train/Acura ZDX Hatchback 2012/04608.jpg': (600, 300),
#  'train/Acura ZDX Hatchback 2012/03316.jpg': (750, 469),
#  'train/Acura ZDX Hatchback 2012/06309.jpg': (480, 320),
#  'train/Acura ZDX Hatchback 2012/06269.jpg': (1200, 845),
#  'train/Acura ZDX Hatchback 2012/00236.jpg': (600, 450),
#  'train/Acura ZDX Hatchback 2012/07061.jpg': (615, 300),
#  'train/Acura ZDX Hatchback 2012/01537.jpg': (640, 426),
#  'train/Acura ZDX Hatchback 2012/07169.jpg': (500, 333),
#  'train/Acura ZDX Hatchback 2012/06158.jpg': (800, 564),
#  'train/Acura ZDX Hatchback 2012/05349.jpg': (1000, 570),
#  'train/Acura ZDX Hatchback 2012/00244.jpg': (480, 360),
#  'train/Acura ZDX Hatchback 2012/02671.jpg': (500, 333),
#  'train/Aston Martin Virage Coupe 2012/00318.jpg': (625, 416),
#  'train/Aston Martin Virage Coupe 2012/03766.jpg': (794, 485),
#  'train/Aston Martin Virage Coupe 2012/06433.jpg': (1333, 885),
#  'train/Aston Martin Virage Coupe 2012/00660.jpg': (640, 426),
#  'train/Aston Martin Virage Coupe 2012/01124.jpg': (600, 450),
#  'train/Aston Martin Virage Coupe 2012/07610.jpg': (1600, 900),
#  'train/Aston Martin Virage Coupe 2012/03458.jpg': (1024, 685),
#  'train/Aston Martin Virage Coupe 2012/07340.jpg': (786, 492),
#  'train/Aston Martin Virage Coupe 2012/04857.jpg': (610, 404),
#  'train/Aston Martin Virage Coupe 2012/05529.jpg': (586, 389),
#  'train/Aston Martin Virage Coupe 2012/03561.jpg': (640, 400),
#  'train/Aston Martin Virage Coupe 2012/00206.jpg': (640, 480),
#  'train/Aston Martin Virage Coupe 2012/01425.jpg': (1024, 576),
#  'train/Aston Martin Virage Coupe 2012/05624.jpg': (550, 413),
#  'train/Aston Martin Virage Coupe 2012/03502.jpg': (1200, 885),
#  'train/Aston Martin Virage Coupe 2012/08051.jpg': (1280, 850),
#  'train/Aston Martin Virage Coupe 2012/03844.jpg': (590, 447),
#  'train/Aston Martin Virage Coupe 2012/06529.jpg': (600, 323),
#  'train/Audi 100 Sedan 1994/06224.jpg': (1600, 1200),
#  'train/Audi 100 Sedan 1994/07566.jpg': (220, 130),
#  'train/Audi 100 Sedan 1994/06568.jpg': (128, 96),
#  'train/Audi 100 Sedan 1994/00266.jpg': (800, 600),
#  'train/Audi 100 Sedan 1994/00402.jpg': (400, 300),
#  'train/Audi 100 Sedan 1994/03717.jpg': (150, 113),
#  'train/Audi 100 Sedan 1994/05326.jpg': (226, 115),
#  'train/Audi 100 Sedan 1994/04949.jpg': (640, 480),
#  'train/Audi 100 Sedan 1994/04447.jpg': (565, 338),
#  'train/Audi 100 Sedan 1994/01782.jpg': (635, 303),
#  'train/Audi 100 Sedan 1994/01072.jpg': (320, 240),
#  'train/Audi 100 Sedan 1994/04549.jpg': (600, 450),
#  'train/Audi 100 Sedan 1994/04758.jpg': (1024, 768),
#  'train/Audi 100 Sedan 1994/07076.jpg': (128, 96),
#  'train/Audi 100 Sedan 1994/05181.jpg': (600, 450),
#  'train/Audi 100 Sedan 1994/03533.jpg': (240, 149),
#  'train/Audi 100 Sedan 1994/05717.jpg': (300, 225),
#  'train/Audi 100 Sedan 1994/05464.jpg': (300, 225),
#  'train/Audi 100 Sedan 1994/03765.jpg': (1440, 1080),
#  'train/Audi 100 Sedan 1994/02600.jpg': (400, 285),
#  'train/Audi 100 Sedan 1994/05968.jpg': (400, 300),
#  'train/Audi 100 Sedan 1994/04380.jpg': (510, 347),
#  'train/Audi 100 Sedan 1994/01502.jpg': (160, 80),
#  'train/Audi 100 Sedan 1994/08043.jpg': (533, 400),
#  'train/Audi 100 Sedan 1994/02176.jpg': (392, 250),
#  'train/Audi 100 Sedan 1994/08144.jpg': (883, 683),
#  'train/Audi 100 Sedan 1994/06947.jpg': (951, 456),
#  'train/Audi 100 Sedan 1994/02887.jpg': (1600, 1200),
#  'train/Audi 100 Sedan 1994/07774.jpg': (300, 225),
#  'train/Audi 100 Sedan 1994/00066.jpg': (259, 194),
#  'train/Audi 100 Sedan 1994/00865.jpg': (400, 274),
#  'train/Audi 100 Sedan 1994/04639.jpg': (259, 194),
#  'train/Audi 100 Sedan 1994/05177.jpg': (600, 307),
#  'train/Audi 100 Sedan 1994/08010.jpg': (400, 300),
#  'train/Audi 100 Sedan 1994/03985.jpg': (160, 120),
#  'train/Audi 100 Sedan 1994/02770.jpg': (300, 225),
#  'train/Audi 100 Sedan 1994/02350.jpg': (666, 500),
#  'train/Audi 100 Sedan 1994/07693.jpg': (600, 297),
#  'train/Audi 100 Sedan 1994/03253.jpg': (259, 194),
#  'train/Audi 100 Sedan 1994/08137.jpg': (1024, 768),
#  'train/Audi 100 Sedan 1994/05594.jpg': (428, 321),
#  'train/Audi 100 Wagon 1994/06362.jpg': (104, 62),
#  'train/Audi 100 Wagon 1994/04176.jpg': (1600, 1200),
#  'train/Audi 100 Wagon 1994/02292.jpg': (89, 66),
#  'train/Audi 100 Wagon 1994/05576.jpg': (300, 189),
#  'train/Audi 100 Wagon 1994/02171.jpg': (1600, 1200),
#  'train/Audi 100 Wagon 1994/01591.jpg': (259, 194),
#  'train/Audi 100 Wagon 1994/06871.jpg': (198, 148),
#  'train/Audi 100 Wagon 1994/02505.jpg': (142, 75),
#  'train/Audi 100 Wagon 1994/04744.jpg': (280, 96),
#  'train/Audi 100 Wagon 1994/05869.jpg': (246, 184),
#  'train/Audi 100 Wagon 1994/02400.jpg': (218, 74),
#  'train/Audi 100 Wagon 1994/05645.jpg': (2172, 1083),
#  'train/Audi 100 Wagon 1994/01609.jpg': (115, 86),
#  'train/Audi 100 Wagon 1994/06291.jpg': (200, 150),
#  'train/Audi 100 Wagon 1994/02341.jpg': (200, 127),
#  'train/Audi 100 Wagon 1994/05713.jpg': (640, 410),
#  'train/Audi 100 Wagon 1994/07649.jpg': (640, 427),
#  'train/Audi 100 Wagon 1994/03435.jpg': (89, 66),
#  'train/Audi 100 Wagon 1994/07383.jpg': (260, 260),
#  'train/Audi 100 Wagon 1994/05271.jpg': (599, 284),
#  'train/Audi 100 Wagon 1994/06664.jpg': (512, 385),
#  'train/Audi 100 Wagon 1994/07028.jpg': (580, 396),
#  'train/Audi 100 Wagon 1994/07384.jpg': (300, 357),
#  'train/Audi 100 Wagon 1994/00219.jpg': (640, 359),
#  'train/Audi 100 Wagon 1994/00083.jpg': (300, 225),
#  'train/Audi 100 Wagon 1994/02214.jpg': (308, 163),
#  'train/Audi 100 Wagon 1994/00154.jpg': (400, 260),
#  'train/Audi 100 Wagon 1994/06873.jpg': (224, 96),
#  'train/Audi 100 Wagon 1994/01097.jpg': (637, 480),
#  'train/Audi 100 Wagon 1994/07213.jpg': (850, 538),
#  'train/Audi 100 Wagon 1994/07002.jpg': (300, 189),
#  'train/Audi 100 Wagon 1994/00217.jpg': (640, 480),
#  'train/Audi 100 Wagon 1994/03439.jpg': (385, 250),
#  'train/Audi R8 Coupe 2012/02632.jpg': (1024, 768),
#  'train/Audi RS 4 Convertible 2008/02885.jpg': (1600, 1200),
#  'train/Audi RS 4 Convertible 2008/05263.jpg': (1280, 853),
#  'train/Audi RS 4 Convertible 2008/01313.jpg': (588, 422),
#  'train/Audi RS 4 Convertible 2008/06515.jpg': (640, 480),
#  'train/Audi RS 4 Convertible 2008/08014.jpg': (400, 267),
#  'train/Audi RS 4 Convertible 2008/00578.jpg': (1280, 949),
#  'train/Audi RS 4 Convertible 2008/06020.jpg': (480, 360),
#  'train/Audi RS 4 Convertible 2008/02584.jpg': (480, 360),
#  'train/Audi RS 4 Convertible 2008/03167.jpg': (450, 225),
#  'train/Audi RS 4 Convertible 2008/02873.jpg': (1280, 905),
#  'train/Audi RS 4 Convertible 2008/06163.jpg': (400, 300),
#  'train/Audi RS 4 Convertible 2008/01640.jpg': (544, 408),
#  'train/Audi RS 4 Convertible 2008/06088.jpg': (250, 188),
#  'train/Audi RS 4 Convertible 2008/00755.jpg': (800, 300),
#  'train/Audi RS 4 Convertible 2008/04818.jpg': (600, 420),
#  'train/Audi RS 4 Convertible 2008/03723.jpg': (432, 216),
#  'train/Audi RS 4 Convertible 2008/08086.jpg': (450, 300),
#  'train/Audi RS 4 Convertible 2008/05002.jpg': (500, 288),
#  'train/Audi RS 4 Convertible 2008/07206.jpg': (285, 214),
#  'train/Audi RS 4 Convertible 2008/07241.jpg': (1280, 960),
#  'train/Audi RS 4 Convertible 2008/06859.jpg': (640, 441),
#  'train/Audi RS 4 Convertible 2008/06904.jpg': (320, 240),
#  'train/Audi RS 4 Convertible 2008/04533.jpg': (1024, 768),
#  'train/Audi RS 4 Convertible 2008/01762.jpg': (1600, 1200),
#  'train/Audi RS 4 Convertible 2008/06708.jpg': (832, 617),
#  'train/Audi RS 4 Convertible 2008/06008.jpg': (1600, 1200),
#  'train/Audi RS 4 Convertible 2008/01297.jpg': (1600, 1200),
#  'train/Audi RS 4 Convertible 2008/04497.jpg': (600, 400),
#  'train/Audi RS 4 Convertible 2008/02773.jpg': (434, 326),
#  'train/Audi RS 4 Convertible 2008/04379.jpg': (240, 160),
#  'train/Audi RS 4 Convertible 2008/02797.jpg': (1238, 788),
#  'train/Audi RS 4 Convertible 2008/02620.jpg': (800, 440),
#  'train/Audi RS 4 Convertible 2008/00690.jpg': (450, 300),
#  'train/Audi RS 4 Convertible 2008/07439.jpg': (500, 261),
#  'train/Audi RS 4 Convertible 2008/00201.jpg': (400, 200),
#  'train/Audi RS 4 Convertible 2008/07008.jpg': (1280, 850),
#  'train/Audi RS 4 Convertible 2008/07307.jpg': (900, 598),
#  'train/Audi S4 Sedan 2007/04480.jpg': (1500, 1000),
#  'train/Audi S4 Sedan 2007/05887.jpg': (800, 531),
#  'train/Audi S4 Sedan 2007/02680.jpg': (1600, 1200),
#  'train/Audi S4 Sedan 2007/02165.jpg': (640, 480),
#  'train/Audi S4 Sedan 2007/04841.jpg': (575, 431),
#  'train/Audi S4 Sedan 2007/05908.jpg': (400, 300),
#  'train/Audi S4 Sedan 2007/07339.jpg': (640, 426),
#  'train/Audi S4 Sedan 2007/03087.jpg': (600, 400),
#  'train/Audi S4 Sedan 2007/00313.jpg': (500, 334),
#  'train/Audi S4 Sedan 2007/05688.jpg': (800, 600),
#  'train/Audi S4 Sedan 2007/03842.jpg': (2048, 1536),
#  'train/Audi S4 Sedan 2007/01600.jpg': (640, 480),
#  'train/Audi S4 Sedan 2007/08026.jpg': (1024, 768),
#  'train/Audi S4 Sedan 2007/00159.jpg': (1024, 768),
#  'train/Audi S4 Sedan 2007/01073.jpg': (555, 370),
#  'train/Audi S4 Sedan 2007/00632.jpg': (1024, 768),
#  'train/Audi S4 Sedan 2007/07553.jpg': (316, 237),
#  'train/Audi S4 Sedan 2007/00770.jpg': (800, 600),
#  'train/Audi S4 Sedan 2007/00689.jpg': (424, 360),
#  'train/Audi S4 Sedan 2007/00793.jpg': (400, 300),
#  'train/Audi S4 Sedan 2007/03269.jpg': (380, 285),
#  'train/Audi S4 Sedan 2007/07889.jpg': (314, 186),
#  'train/Audi S4 Sedan 2007/02056.jpg': (480, 360),
#  'train/Audi S4 Sedan 2007/03119.jpg': (640, 480),
#  'train/Audi S4 Sedan 2007/03892.jpg': (800, 358),
#  'train/Audi S4 Sedan 2007/00803.jpg': (640, 480),
#  'train/Audi S4 Sedan 2007/02561.jpg': (569, 264),
#  'train/Audi S4 Sedan 2007/07938.jpg': (440, 330),
#  'train/Audi S4 Sedan 2007/07258.jpg': (575, 431),
#  'train/Audi S4 Sedan 2007/00446.jpg': (480, 320),
#  'train/Audi S4 Sedan 2007/07590.jpg': (1024, 768),
#  'train/Audi S4 Sedan 2007/02715.jpg': (575, 431),
#  'train/Audi S4 Sedan 2007/06565.jpg': (483, 423),
#  'train/Audi S4 Sedan 2007/08053.jpg': (460, 343),
#  'train/Audi S4 Sedan 2007/07562.jpg': (640, 480),
#  'train/Audi S4 Sedan 2007/05429.jpg': (500, 288),
#  'train/Audi S4 Sedan 2007/04580.jpg': (500, 334),
#  'train/Audi S4 Sedan 2007/00750.jpg': (400, 300),
#  'train/Audi S4 Sedan 2007/01195.jpg': (575, 460),
#  'train/Audi S4 Sedan 2007/06852.jpg': (500, 350),
#  'train/Audi S4 Sedan 2007/07878.jpg': (434, 326),
#  'train/Audi S4 Sedan 2007/03886.jpg': (480, 360),
#  'train/Audi S4 Sedan 2007/00835.jpg': (600, 400),
#  'train/Audi S4 Sedan 2007/03855.jpg': (600, 400),
#  'train/Audi S4 Sedan 2007/00733.jpg': (600, 400),
#  'train/Audi S4 Sedan 2012/03824.jpg': (640, 480),
#  'train/Audi S4 Sedan 2012/06229.jpg': (640, 480),
#  'train/Audi S4 Sedan 2012/05972.jpg': (640, 426),
#  'train/Audi S4 Sedan 2012/02044.jpg': (900, 601),
#  'train/Audi S4 Sedan 2012/04940.jpg': (300, 187),
#  'train/Audi S4 Sedan 2012/02566.jpg': (1024, 768),
#  'train/Audi S4 Sedan 2012/00934.jpg': (941, 714),
#  'train/Audi S4 Sedan 2012/02273.jpg': (1500, 938),
#  'train/Audi S4 Sedan 2012/05644.jpg': (640, 480),
#  'train/Audi S4 Sedan 2012/01160.jpg': (640, 425),
#  'train/Audi S4 Sedan 2012/07295.jpg': (999, 666),
#  'train/Audi S4 Sedan 2012/07503.jpg': (640, 480),
#  'train/Audi S4 Sedan 2012/03206.jpg': (640, 425),
#  'train/Audi S4 Sedan 2012/01308.jpg': (2560, 1920),
#  'train/Audi S4 Sedan 2012/00397.jpg': (300, 225),
#  'train/Audi S4 Sedan 2012/05268.jpg': (555, 371),
#  'train/Audi S4 Sedan 2012/00988.jpg': (1920, 1200),
#  'train/Audi S4 Sedan 2012/06616.jpg': (450, 300),
#  'train/Audi S4 Sedan 2012/05824.jpg': (560, 314),
#  'train/Audi S4 Sedan 2012/02630.jpg': (582, 393),
#  'train/Audi S4 Sedan 2012/02059.jpg': (1024, 724),
#  'train/Audi S4 Sedan 2012/08081.jpg': (300, 225),
#  'train/Audi S4 Sedan 2012/06236.jpg': (640, 480),
#  'train/Audi S4 Sedan 2012/01848.jpg': (480, 360),
#  'train/Audi S4 Sedan 2012/02800.jpg': (1024, 768),
#  'train/Audi S4 Sedan 2012/05085.jpg': (267, 189),
#  'train/Audi S4 Sedan 2012/06475.jpg': (640, 480),
#  'train/Audi S4 Sedan 2012/04075.jpg': (1024, 768),
#  'train/Audi S4 Sedan 2012/03472.jpg': (724, 1023),
#  'train/Audi S4 Sedan 2012/06344.jpg': (640, 480),
#  'train/Audi S4 Sedan 2012/03103.jpg': (300, 225),
#  'train/Audi S4 Sedan 2012/05413.jpg': (2784, 1856),
#  'train/Audi S4 Sedan 2012/02114.jpg': (720, 538),
#  'train/Audi S4 Sedan 2012/01022.jpg': (900, 540),
#  'train/Audi S4 Sedan 2012/04059.jpg': (400, 300),
#  'train/Audi S4 Sedan 2012/05050.jpg': (1600, 1200),
#  'train/Audi S4 Sedan 2012/00825.jpg': (460, 345),
#  'train/Audi S4 Sedan 2012/06956.jpg': (300, 200),
#  'train/Audi S4 Sedan 2012/00205.jpg': (640, 426),
#  'train/Audi S4 Sedan 2012/00642.jpg': (300, 198),
#  'train/Audi S5 Convertible 2012/02253.jpg': (600, 450),
#  'train/Audi S5 Convertible 2012/06793.jpg': (259, 194),
#  'train/Audi S5 Convertible 2012/03738.jpg': (800, 600),
#  'train/Audi S5 Convertible 2012/02395.jpg': (500, 354),
#  'train/Audi S5 Convertible 2012/02335.jpg': (300, 240),
#  'train/Audi S5 Convertible 2012/04689.jpg': (1024, 682),
#  'train/Audi S5 Convertible 2012/05272.jpg': (1024, 768),
#  'train/Audi S5 Convertible 2012/00561.jpg': (640, 480),
#  'train/Audi S5 Convertible 2012/02264.jpg': (620, 400),
#  'train/Audi S5 Convertible 2012/00256.jpg': (986, 603),
#  'train/Audi S5 Convertible 2012/01202.jpg': (800, 600),
#  'train/Audi S5 Convertible 2012/05144.jpg': (1024, 768),
#  'train/Audi S5 Convertible 2012/05150.jpg': (677, 451),
#  'train/Audi S5 Convertible 2012/06230.jpg': (1280, 782),
#  'train/Audi S5 Coupe 2012/07115.jpg': (275, 184),
#  'train/Audi S5 Coupe 2012/03427.jpg': (320, 240),
#  'train/Audi S5 Coupe 2012/01778.jpg': (640, 426),
#  'train/Audi S5 Coupe 2012/05674.jpg': (300, 225),
#  'train/Audi S5 Coupe 2012/03936.jpg': (259, 194),
#  'train/Audi S5 Coupe 2012/03445.jpg': (259, 194),
#  'train/Audi S5 Coupe 2012/06105.jpg': (590, 446),
#  'train/Audi S5 Coupe 2012/03848.jpg': (300, 189),
#  'train/Audi S5 Coupe 2012/02256.jpg': (259, 194),
#  'train/Audi S5 Coupe 2012/01094.jpg': (300, 225),
#  'train/Audi S5 Coupe 2012/03721.jpg': (280, 180),
#  'train/Audi S5 Coupe 2012/00785.jpg': (485, 342),
#  'train/Audi S5 Coupe 2012/01515.jpg': (1024, 768),
#  'train/Audi S5 Coupe 2012/06778.jpg': (300, 212),
#  'train/Audi S5 Coupe 2012/06509.jpg': (275, 183),
#  'train/Audi S5 Coupe 2012/06581.jpg': (640, 480),
#  'train/Audi S5 Coupe 2012/02025.jpg': (320, 200),
#  'train/Audi S5 Coupe 2012/06546.jpg': (800, 600),
#  'train/Audi S5 Coupe 2012/07039.jpg': (800, 521),
#  'train/Audi S5 Coupe 2012/00767.jpg': (900, 600),
#  'train/Audi S5 Coupe 2012/05129.jpg': (636, 384),
#  'train/Audi S5 Coupe 2012/03449.jpg': (300, 199),
#  'train/Audi S5 Coupe 2012/08055.jpg': (1600, 1067),
#  'train/Audi S5 Coupe 2012/02244.jpg': (640, 480),
#  'train/Audi S6 Sedan 2011/05705.jpg': (354, 250),
#  'train/Audi S6 Sedan 2011/00956.jpg': (600, 324),
#  'train/Audi S6 Sedan 2011/03157.jpg': (1024, 768),
#  'train/Audi S6 Sedan 2011/00274.jpg': (500, 334),
#  'train/Audi S6 Sedan 2011/00772.jpg': (640, 480),
#  'train/Audi S6 Sedan 2011/02974.jpg': (771, 454),
#  'train/Audi S6 Sedan 2011/04733.jpg': (584, 328),
#  'train/Audi S6 Sedan 2011/05965.jpg': (450, 336),
#  'train/Audi S6 Sedan 2011/04237.jpg': (2100, 1575),
#  'train/Audi S6 Sedan 2011/03543.jpg': (800, 565),
#  'train/Audi S6 Sedan 2011/06677.jpg': (320, 240),
#  'train/Audi S6 Sedan 2011/05007.jpg': (640, 426),
#  'train/Audi S6 Sedan 2011/04802.jpg': (424, 360),
#  'train/Audi S6 Sedan 2011/02412.jpg': (1300, 867),
#  'train/Audi S6 Sedan 2011/00600.jpg': (400, 200),
#  'train/Audi S6 Sedan 2011/03887.jpg': (2100, 1575),
#  'train/Audi S6 Sedan 2011/05122.jpg': (424, 360),
#  'train/Audi S6 Sedan 2011/00089.jpg': (1024, 768),
#  'train/Audi S6 Sedan 2011/02185.jpg': (1024, 768),
#  'train/Audi S6 Sedan 2011/00602.jpg': (628, 424),
#  'train/Audi S6 Sedan 2011/00918.jpg': (640, 480),
#  'train/Audi S6 Sedan 2011/01643.jpg': (650, 366),
#  'train/Audi S6 Sedan 2011/04195.jpg': (640, 426),
#  'train/Audi S6 Sedan 2011/06830.jpg': (500, 333),
#  'train/Audi S6 Sedan 2011/03367.jpg': (800, 563),
#  'train/Audi S6 Sedan 2011/01298.jpg': (1024, 768),
#  'train/Audi S6 Sedan 2011/06954.jpg': (704, 297),
#  'train/Audi S6 Sedan 2011/03025.jpg': (429, 262),
#  'train/Audi S6 Sedan 2011/01123.jpg': (1024, 768),
#  'train/Audi S6 Sedan 2011/02958.jpg': (640, 480),
#  'train/Audi S6 Sedan 2011/00681.jpg': (590, 365),
#  'train/Audi S6 Sedan 2011/06741.jpg': (600, 407),
#  'train/Audi S6 Sedan 2011/04696.jpg': (640, 480),
#  'train/Audi S6 Sedan 2011/03952.jpg': (1138, 617),
#  'train/Audi S6 Sedan 2011/05162.jpg': (500, 333),
#  'train/Audi S6 Sedan 2011/02441.jpg': (1024, 768),
#  'train/Audi S6 Sedan 2011/05212.jpg': (350, 240),
#  'train/Audi S6 Sedan 2011/06914.jpg': (720, 310),
#  'train/Audi S6 Sedan 2011/02688.jpg': (506, 380),
#  'train/Audi S6 Sedan 2011/04581.jpg': (1600, 1200),
#  'train/Audi S6 Sedan 2011/05986.jpg': (433, 280),
#  'train/Audi S6 Sedan 2011/03412.jpg': (1024, 768),
#  'train/Audi S6 Sedan 2011/03344.jpg': (438, 329),
#  'train/Audi S6 Sedan 2011/00899.jpg': (720, 406),
#  'train/Audi S6 Sedan 2011/01048.jpg': (640, 480),
#  'train/Audi S6 Sedan 2011/06151.jpg': (1024, 768),
#  'train/Audi TT Hatchback 2011/06277.jpg': (278, 181),
#  'train/Audi TT Hatchback 2011/05448.jpg': (278, 181),
#  'train/Audi TT Hatchback 2011/05408.jpg': (300, 211),
#  'train/Audi TT Hatchback 2011/05435.jpg': (283, 178),
#  'train/Audi TT Hatchback 2011/06335.jpg': (275, 183),
#  'train/Audi TT Hatchback 2011/05392.jpg': (259, 194),
#  'train/Audi TT Hatchback 2011/07312.jpg': (300, 198),
#  'train/Audi TT Hatchback 2011/00302.jpg': (300, 189),
#  'train/Audi TT Hatchback 2011/03698.jpg': (800, 600),
#  'train/Audi TT Hatchback 2011/01534.jpg': (1023, 736),
#  'train/Audi TT Hatchback 2011/03758.jpg': (259, 194),
#  'train/Audi TT Hatchback 2011/02267.jpg': (500, 354),
#  'train/Audi TT Hatchback 2011/06094.jpg': (275, 183),
#  'train/Audi TT Hatchback 2011/00408.jpg': (479, 300),
#  'train/Audi TT Hatchback 2011/06553.jpg': (620, 465),
#  'train/Audi TT Hatchback 2011/02539.jpg': (460, 276),
#  'train/Audi TT Hatchback 2011/06011.jpg': (259, 194),
#  'train/Audi TT Hatchback 2011/04883.jpg': (2100, 1575),
#  'train/Audi TT Hatchback 2011/07142.jpg': (600, 400),
#  'train/Audi TT Hatchback 2011/05359.jpg': (275, 183),
#  'train/Audi TT Hatchback 2011/07313.jpg': (612, 405),
#  'train/Audi TT Hatchback 2011/03057.jpg': (1024, 683),
#  'train/Audi TT Hatchback 2011/05067.jpg': (400, 266),
#  'train/Audi TT Hatchback 2011/06432.jpg': (1024, 723),
#  'train/Audi TT Hatchback 2011/05572.jpg': (640, 478),
#  'train/Audi TT Hatchback 2011/02130.jpg': (630, 419),
#  'train/Audi TT Hatchback 2011/04702.jpg': (297, 198),
#  'train/Audi TT Hatchback 2011/04061.jpg': (259, 194),
#  'train/Audi TT Hatchback 2011/00723.jpg': (800, 640),
#  'train/Audi TT Hatchback 2011/00171.jpg': (300, 183),
#  'train/Audi TT Hatchback 2011/01644.jpg': (550, 365),
#  'train/Audi TT Hatchback 2011/03703.jpg': (300, 195),
#  'train/Audi TT Hatchback 2011/07822.jpg': (260, 194),
#  'train/Audi TT Hatchback 2011/04359.jpg': (629, 457),
#  'train/Audi TT Hatchback 2011/07879.jpg': (2100, 1386),
#  'train/Audi TT Hatchback 2011/03383.jpg': (259, 194),
#  'train/Audi TT Hatchback 2011/04944.jpg': (400, 252),
#  'train/Audi TT Hatchback 2011/06071.jpg': (380, 228),
#  'train/Audi TT Hatchback 2011/01245.jpg': (630, 418),
#  'train/Audi TT Hatchback 2011/07059.jpg': (640, 480),
#  'train/Audi TT Hatchback 2011/01954.jpg': (560, 420),
#  'train/Audi TT RS Coupe 2012/02323.jpg': (850, 315),
#  'train/Audi TT RS Coupe 2012/03839.jpg': (300, 204),
#  'train/Audi TT RS Coupe 2012/06249.jpg': (400, 267),
#  'train/Audi TT RS Coupe 2012/04443.jpg': (986, 603),
#  'train/Audi TT RS Coupe 2012/00684.jpg': (750, 469),
#  'train/Audi TT RS Coupe 2012/05183.jpg': (1200, 800),
#  'train/Audi TT RS Coupe 2012/04885.jpg': (1600, 1131),
#  'train/Audi TT RS Coupe 2012/05075.jpg': (276, 183),
#  'train/Audi TT RS Coupe 2012/01415.jpg': (300, 225),
#  'train/Audi TT RS Coupe 2012/02764.jpg': (1680, 1050),
#  'train/Audi TT RS Coupe 2012/02456.jpg': (259, 195),
#  'train/Audi TT RS Coupe 2012/04822.jpg': (300, 183),
#  'train/Audi TT RS Coupe 2012/05902.jpg': (400, 268),
#  'train/Audi TT RS Coupe 2012/04357.jpg': (1920, 1080),
#  'train/Audi TT RS Coupe 2012/05647.jpg': (300, 189),
#  'train/Audi TT RS Coupe 2012/06704.jpg': (680, 368),
#  'train/Audi TT RS Coupe 2012/05425.jpg': (1200, 800),
#  'train/Audi TT RS Coupe 2012/00046.jpg': (786, 492),
#  'train/Audi TT RS Coupe 2012/01948.jpg': (500, 333),
#  'train/Audi TT RS Coupe 2012/05729.jpg': (287, 175),
#  'train/Audi TT RS Coupe 2012/05146.jpg': (626, 382),
#  'train/Audi TT RS Coupe 2012/02334.jpg': (1200, 800),
#  'train/Audi TT RS Coupe 2012/03349.jpg': (650, 460),
#  'train/Audi TT RS Coupe 2012/05886.jpg': (1024, 724),
#  'train/Audi TT RS Coupe 2012/03019.jpg': (569, 355),
#  'train/Audi TT RS Coupe 2012/03121.jpg': (300, 225),
#  'train/Audi TT RS Coupe 2012/01092.jpg': (600, 600),
#  'train/Audi TTS Coupe 2012/01210.jpg': (640, 480),
#  'train/Audi TTS Coupe 2012/03838.jpg': (259, 194),
#  'train/Audi TTS Coupe 2012/05116.jpg': (640, 446),
#  'train/Audi TTS Coupe 2012/01232.jpg': (600, 400),
#  'train/Audi TTS Coupe 2012/02766.jpg': (1500, 1000),
#  'train/Audi TTS Coupe 2012/00017.jpg': (259, 194),
#  'train/Audi TTS Coupe 2012/07423.jpg': (400, 300),
#  'train/Audi TTS Coupe 2012/03750.jpg': (3122, 2079),
#  'train/Audi TTS Coupe 2012/03590.jpg': (264, 165),
#  'train/Audi V8 Sedan 1994/03981.jpg': (475, 329),
#  'train/Audi V8 Sedan 1994/04893.jpg': (291, 173),
#  'train/Audi V8 Sedan 1994/03314.jpg': (618, 418),
#  'train/Audi V8 Sedan 1994/04312.jpg': (485, 210),
#  'train/Audi V8 Sedan 1994/03429.jpg': (480, 360),
#  'train/Audi V8 Sedan 1994/01620.jpg': (500, 315),
#  'train/Audi V8 Sedan 1994/00200.jpg': (340, 255),
#  'train/Audi V8 Sedan 1994/01180.jpg': (300, 225),
#  'train/Audi V8 Sedan 1994/06646.jpg': (200, 150),
#  'train/Audi V8 Sedan 1994/04191.jpg': (576, 369),
#  'train/Audi V8 Sedan 1994/02728.jpg': (300, 225),
#  ...}

# %%
#!pip3 list

# %%
#redefine zip, after ZipFile breaks it
def zip(*iterables):
    # zip('ABCD', 'xy') --> Ax By
    sentinel = object()
    iterators = [iter(it) for it in iterables]
    while iterators:
        result = []
        for it in iterators:
            elem = next(it, sentinel)
            if elem is sentinel:
                return
            result.append(elem)
        yield tuple(result)

# %%
import os
row_sz, col_sz = list(zip(*e_d.values()))

# %%
row_sz[:5]
# Out:
# (1600, 512, 85, 160, 700)

# %%
row_sz = np.array(row_sz); col_sz = np.array(col_sz)

# %%
col_sz[:5]
# Out:
# array([1200,  384,   64,  120,  439])

# %%
# find few row/col ratios
row_sz[:5]/col_sz[:5]
# Out:
# array([1.33333, 1.33333, 1.32812, 1.33333, 1.59453])

# %%
print(min(row_sz), max(row_sz))
# Out:
# 78 5616

# %%
plt.hist(row_sz);

# %%
plt.hist(row_sz[row_sz < 800])
# Out:
# (array([  71.,  129.,  807.,  640.,  452.,  924.,  337., 2085.,  216.,  260.]),
#  array([ 78. , 150.1, 222.2, 294.3, 366.4, 438.5, 510.6, 582.7, 654.8, 726.9, 799. ]),
#  <a list of 10 Patch objects>)

# %%
# again, list total number of classes, and list them all
# os.list dir sorting depends on OS dependent file indexing, so leaving it as it is

classes = os.listdir(f'{PATH}/train')
classes.sort()
print("Class Total Count: ", len(classes))
print(classes)
# Out:
# Class Total Count:  196
ge Durango SUV 2007', 'Dodge Durango SUV 2012', 'Dodge Journey SUV 2012', 'Dodge Magnum Wagon 2008', 'Dodge Ram Pickup 3500 Crew Cab 2010', 'Dodge Ram Pickup 3500 Quad Cab 2009', 'Dodge Sprinter Cargo Van 2009', 'Eagle Talon Hatchback 1998', 'FIAT 500 Abarth 2012', 'FIAT 500 Convertible 2012', 'Ferrari 458 Italia Convertible 2012', 'Ferrari 458 Italia Coupe 2012', 'Ferrari California Convertible 2012', 'Ferrari FF Coupe 2012', 'Fisker Karma Sedan 2012', 'Ford E-Series Wagon Van 2012', 'Ford Edge SUV 2012', 'Ford Expedition EL SUV 2009', 'Ford F-150 Regular Cab 2007', 'Ford F-150 Regular Cab 2012', 'Ford F-450 Super Duty Crew Cab 2012', 'Ford Fiesta Sedan 2012', 'Ford Focus Sedan 2007', 'Ford Freestar Minivan 2007', 'Ford GT Coupe 2006', 'Ford Mustang Convertible 2007', 'Ford Ranger SuperCab 2011', 'GMC Acadia SUV 2012', 'GMC Canyon Extended Cab 2012', 'GMC Savana Van 2012', 'GMC Terrain SUV 2012', 'GMC Yukon Hybrid SUV 2012', 'Geo Metro Convertible 1993', 'HUMMER H2 SUT Crew Cab 2009', 'HUMMER H3T Crew Cab 2010', 'Honda Accord Coupe 2012', 'Honda Accord Sedan 2012', 'Honda Odyssey Minivan 2007', 'Honda Odyssey Minivan 2012', 'Hyundai Accent Sedan 2012', 'Hyundai Azera Sedan 2 ...

# %%
# parse all classes and assemble python list object []
# each list element will contain array of files names of a class

all_images_class = [os.listdir(f'{PATH}/train/'+c) for c in classes]
#int_to_classes = {i:classes[i] for i in range(len(classes))}
#classes_to_int = {classes[i]:i for i in range(len(classes))}
print("Classes: ",len(all_images_class) )
# Out:
# Classes:  196

# %%
# create python data dictionary {}, with key="text", and value as length(of size) of containing list object array (1D)
# gives histogram like file count for each class
dataDict= {"n_images": [len(x) for x in all_images_class]}
print("file count in each class: ",dataDict)
trainFiles = 0
for x in all_images_class:
  trainFiles = trainFiles+len(x)
print(" Total Train Files: ", trainFiles)
# Out:
# file count in each class:  {'n_images': [45, 45, 32, 43, 42, 41, 39, 45, 41, 33, 38, 41, 43, 41, 43, 37, 45, 40, 42, 43, 46, 41, 40, 43, 44, 36, 41, 43, 42, 44, 34, 45, 41, 41, 39, 42, 42, 41, 39, 45, 46, 35, 37, 36, 33, 44, 42, 43, 35, 38, 43, 45, 41, 45, 45, 42, 40, 38, 47, 30, 35, 37, 43, 39, 45, 45, 43, 44, 40, 44, 38, 44, 37, 40, 44, 49, 44, 43, 45, 41, 38, 45, 42, 41, 44, 39, 42, 41, 39, 41, 46, 44, 44, 40, 43, 44, 40, 46, 28, 34, 40, 43, 39, 42, 44, 38, 43, 45, 45, 43, 42, 43, 45, 44, 46, 45, 42, 45, 40, 68, 42, 43, 45, 44, 39, 39, 39, 41, 42, 24, 42, 42, 43, 44, 42, 34, 40, 44, 41, 42, 34, 33, 40, 47, 43, 45, 45, 44, 43, 44, 45, 36, 36, 43, 43, 39, 37, 29, 36, 44, 48, 46, 44, 45, 37, 41, 48, 46, 44, 42, 39, 44, 44, 41, 39, 31, 44, 42, 45, 43, 38, 46, 42, 41, 39, 41, 44, 44, 39, 43, 46, 43, 46, 42, 43, 40]}
#  Total Train Files:  8144

# %%
# assemble panda Dataframe {class pandas.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)}
# Train Data set
df = pd.DataFrame(dataDict, index=classes)
df.index.name = "Cars"

# %%
df.plot(kind="bar", grid=True,figsize=(28,10))

# %% [markdown]
# ##Review: easy steps to train a world-class image classifier
#
#  *   precompute=True
#  *   Use lr_find() to find highest learning rate where loss is still clearly improving
#  *   Train last layer from precomputed activations for 1-2 epochs
#  *   Train last layer with data augmentation (i.e. precompute=False) for 2-3 epochs with cycle_len=1
#  *   Unfreeze all layers
#  *   Set earlier layers to 3x-10x lower learning rate than next higher layer
#  *   Use lr_find() again
#  *   Train full network with cycle_mult=2 until over-fitting

# %% [markdown]
# ## Initial Model

# %%
#arch = vgg16
#arch = resnet34
arch = resnext50
#arch = resnext101_64
sz = 224
bs = 64

# %%
#The transforms downsize the images to 224 or 299. Reading the jpgs and resizing is slow for big images, so resizing them all to 340 first saves time.

def get_data(sz, bs): # sz: image size, bs: batch size
    #tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on, max_zoom=1.1)
    tfms=tfms_from_model(arch, sz)
    data = ImageClassifierData.from_paths(PATH, val_name='test', tfms=tfms, bs=bs, num_workers=4)
    
    # http://forums.fast.ai/t/how-to-train-on-the-full-dataset-using-imageclassifierdata-from-csv/7761/13
    # http://forums.fast.ai/t/how-to-train-on-the-full-dataset-using-imageclassifierdata-from-csv/7761/37
    return data if sz > 300 else data.resize(340, 'tmp') # Reading the jpgs and resizing is slow for big images, so resizing them all to 180 first saves time

#Source:   
    def resize(self, targ, new_path):
        new_ds = []
        dls = [self.trn_dl,self.val_dl,self.fix_dl,self.aug_dl]
        if self.test_dl: dls += [self.test_dl, self.test_aug_dl]
        else: dls += [None,None]
        t = tqdm_notebook(dls)
        for dl in t: new_ds.append(self.resized(dl, targ, new_path))
        t.close()
        return self.__class__(new_ds[0].path, new_ds, self.bs, self.num_workers, self.classes)
#File:      ~/fastai/courses/dl1/fastai/dataset.py

# %%
# Precompute
data = get_data(sz, bs)
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))

# %%
# !wget http://files.fast.ai/models/weights.tgz
# Out:
# --2018-11-12 10:57:12--  http://files.fast.ai/models/weights.tgz
# Resolving files.fast.ai (files.fast.ai)... 67.205.15.147
# Connecting to files.fast.ai (files.fast.ai)|67.205.15.147|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1195411318 (1.1G) [text/plain]
# Saving to: ‘weights.tgz.1’
#
# weights.tgz.1       100%[===================>]   1.11G  41.4MB/s    in 28s
#
# 2018-11-12 10:57:39 (41.4 MB/s) - ‘weights.tgz.1’ saved [1195411318/1195411318]

# %%
# !tar -xvzf weights.tgz
# Out:
# weights/
# weights/wrn_50_2f.pth
# weights/resnext_101_32x4d.pth
# weights/resnext_101_64x4d.pth
# weights/inceptionresnetv2-d579a627.pth
# weights/inceptionv4-97ef9c30.pth
# weights/resnext_50_32x4d.pth

# %%
#!ls '/usr/local/lib/python3.6/dist-packages/fastai'
#!ls
# !cp -R weights '/usr/local/lib/python3.6/dist-packages/fastai/'
# !ls '/usr/local/lib/python3.6/dist-packages/fastai/weights'
# Out:
# inceptionresnetv2-d579a627.pth	resnext_101_32x4d.pth  resnext_50_32x4d.pth
# inceptionv4-97ef9c30.pth	resnext_101_64x4d.pth  wrn_50_2f.pth

# %%
# !ls '/usr/local/lib/python3.6/dist-packages/fastai/weights'
# Out:
# inceptionresnetv2-d579a627.pth	resnext_101_32x4d.pth  resnext_50_32x4d.pth
# inceptionv4-97ef9c30.pth	resnext_101_64x4d.pth  wrn_50_2f.pth

# %%
# Get initial predictions on pre-trained network, just training last layers
# model trained on ImageNet (1.2 million images and 1000 classes) as a starting point.
# resnet34 is a version of the model that won the 2015 ImageNet competition. 
# precompute shall speed up the process

learn = ConvLearner.pretrained(arch, data)
# %time learn.fit(0.01, 5)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=5, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      4.315657   3.570474   0.211914
#     1      3.396879   3.061631   0.297849
#     2      2.907165   2.738328   0.350827
#     3      2.534442   2.527034   0.390872
#     4      2.268014   2.380627   0.416739
#
# CPU times: user 20min 25s, sys: 5min 17s, total: 25min 43s
# Wall time: 17min 35s
# [array([2.38063]), 0.4167392115779161]

# %%
learn.sched.plot_loss()

# %%
data.val_y
# Out:
# array([  0,   0,   0, ..., 195, 195, 195])

# %% [markdown]
# ### Choosing a learning rate
# The *learning rate* determines how quickly or how slowly you want to update the *weights* (or *parameters*). Learning rate is one of the most difficult parameters to set, because it significantly affects model performance.
#
# The method `learn.lr_find()` helps you find an optimal learning rate. It uses the technique developed in the 2015 paper [Cyclical Learning Rates for Training Neural Networks](http://arxiv.org/abs/1506.01186), where we simply keep increasing the learning rate from a very small value, until the loss stops decreasing. We can plot the learning rate across batches to see what this looks like.
#
# We first create a new learner, since we want to know how to set the learning rate for a new (untrained) model.

# %%
learn = ConvLearner.pretrained(arch, data)

# %%
lrf=learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1, style=ProgressStyle(description_width='initial…
#  95%|█████████▌| 122/128 [01:51<00:06,  1.10s/it, loss=23.3]

# %%
# Our learn object contains an attribute sched that contains our learning rate scheduler, and has some convenient plotting functionality including this one:
learn.sched.plot_lr()

# %%
learn.sched.plot()

# %% [markdown]
# The loss is still clearly improving at lr=0.1, so that's what we use. Note that the optimal learning rate can change as we train the model, so you may want to re-run this function from time to time.

# %%
# selecting new learning rate for 5 epochs
# %time learn.fit(0.1, 5)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=5, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      3.0295     2.678233   0.33068
#     1      2.786297   2.501321   0.35717
#     2      2.561732   2.396584   0.386022
#     3      2.375802   2.361299   0.390499
#     4      2.265163   2.25143    0.41761
# CPU times: user 22min 34s, sys: 5min 20s, total: 27min 55s
# Wall time: 18min 45s
# [array([2.25143]), 0.41760975005332845]

# %%
learn.sched.plot_loss()

# %%
# !ls
# Out:
#  anno_test.csv	 'kaggle (1).json'   lr_plot.png   weights.tgz
#  anno_train.csv   kaggle.json	     names.csv	   weights.tgz.1
#  car_data	  losses.npy	     sample_data
#  car_data.zip	  loss_plot.png      weights

# %% [markdown]
# ### Augment data set
# If you try training for more epochs, you'll notice that we start to overfit, which means that our model is learning to recognize the specific images in the training set, rather than generalizing such that we also get good results on the validation set. One way to fix this is to effectively create more data, through data augmentation. This refers to randomly changing the images in ways that shouldn't impact their interpretation, such as horizontal flipping, zooming, and rotating.
#
# We can do this by passing aug_tfms (augmentation transforms) to tfms_from_model, with a list of functions to apply that randomly change the image however we wish. For photos that are largely taken from the side (e.g. most photos of dogs and cats, as opposed to photos taken from the top down, such as satellite imagery) we can use the pre-defined list of functions transforms_side_on. We can also specify random zooming of images up to specified scale by adding the max_zoom parameter.

# %%
from sklearn import metrics

# %%
tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on, max_zoom=1.1)

# %%
def get_augs():
    data = ImageClassifierData.from_paths(PATH,val_name='test', bs=2, tfms=tfms, num_workers=4)
    x,_ = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[1]

# %%
# plot augmented sample image
ims = np.stack([get_augs() for i in range(6)])
plots(ims, rows=2)

# %%
# Let's create a new data object that includes this augmentation in the transforms.
# By default when we create a learner, it sets all but the last layer to frozen. That means that it's still only updating the weights in the last layer when we call fit.
def get_data_transform(sz, bs): # sz: image size, bs: batch size
    tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on, max_zoom=1.1)
    data = ImageClassifierData.from_paths(PATH, val_name='test', tfms=tfms, bs=bs, num_workers=4)
    # http://forums.fast.ai/t/how-to-train-on-the-full-dataset-using-imageclassifierdata-from-csv/7761/13
    # http://forums.fast.ai/t/how-to-train-on-the-full-dataset-using-imageclassifierdata-from-csv/7761/37
    return data if sz > 300 else data.resize(340, 'tmp') # Reading the jpgs and resizing is slow for big images, so resizing them all to 180 first saves time

data = get_data_transform(sz, bs)
learn = ConvLearner.pretrained(arch, data)
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))

# %%
# %time learn.fit(0.1, 5)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=5, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      3.684082   3.115072   0.241388
#     1      3.157148   2.715959   0.315011
#     2      2.786106   2.52973    0.360527
#     3      2.533924   2.381684   0.385275
#     4      2.363611   2.341057   0.391991
# CPU times: user 22min 29s, sys: 5min 24s, total: 27min 53s
# Wall time: 18min 48s
# [array([2.34106]), 0.3919910458082762]

# %%
learn.sched.plot_loss()

# %%
# cycle_len - learning rate annealing used by stochastic gradient descent with restarts (SGDR),
# %time learn.fit(0.1, 3, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      1.992862   2.142085   0.446959
#     1      1.913919   2.118875   0.456411
#     2      1.853037   2.092765   0.458525
# CPU times: user 13min 30s, sys: 3min 14s, total: 16min 44s
# Wall time: 11min 17s
# [array([2.09277]), 0.4585250590426043]

# %%
learn.sched.plot_loss()

# %% [markdown]
# What is that cycle_len parameter? What we've done here is used a technique called stochastic gradient descent with restarts (SGDR), a variant of learning rate annealing, which gradually decreases the learning rate as training progresses. This is helpful because as we get closer to the optimal weights, we want to take smaller steps.
#
# However, we may find ourselves in a part of the weight space that isn't very resilient - that is, small changes to the weights may result in big changes to the loss. We want to encourage our model to find parts of the weight space that are both accurate and stable. Therefore, from time to time we increase the learning rate (this is the 'restarts' in 'SGDR'), which will force the model to jump to a different part of the weight space if the current area is "spikey". Here's a picture of how that might look if we reset the learning rates 3 times (in this paper they call it a "cyclic LR schedule"):
#
# (From the paper [Snapshot Ensembles](https://arxiv.org/abs/1704.00109)).
#
# The number of epochs between resetting the learning rate is set by cycle_len, and the number of times this happens is refered to as the number of cycles, and is what we're actually passing as the 2nd parameter to fit(). So here's what our actual learning rates looked like:

# %%
learn.sched.plot_lr()

# %%
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# if Validation loss is much lower than training loss. This is a sign of underfitting. Cycle_len=1 may be too short. Let's set cycle_mult=2 to find better parameter.
# When you are under fitting, it means cycle_len=1 is too short (learning rate is getting reset before it had the chance to zoom in properly).

# in our case we are skipping this
# learn = ConvLearner.pretrained(arch, data)
# learn.fit(1e-1, 3, cycle_len=1, cycle_mult=2) # 1+2+4 = 7 epochs

# %%
learn.save('224_pre')

# %%
learn.load('224_pre')

# %% [markdown]
# ###Fine-tuning and differential learning rate annealing
# Now that we have a good final layer trained, we can try fine-tuning the other layers. To tell the learner that we want to unfreeze the remaining layers, just call (surprise surprise!) unfreeze().

# %%
learn.unfreeze()
# keep batch normalization moving avg not be updated. Very important!!!
#learn.ns_freeze(True)

# %% [markdown]
# ote that the other layers have already been trained to recognize imagenet photos (whereas our final layers where randomly initialized), so we want to be careful of not destroying the carefully tuned weights that are already there.
#
# Generally speaking, the earlier layers (as we've seen) have more general-purpose features. Therefore we would expect them to need less fine-tuning for new datasets. For this reason we will use different learning rates for different layers: the first few layers will be at 1e-4, the middle layers at 1e-3, and our FC layers we'll leave at 1e-2 as before. We refer to this as differential learning rates, although there's no standard name for this techique in the literature that we're aware of.

# %%
lr=np.array([0.001, 0.01, 0.1])
% time learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      2.334116   1.540786   0.591966
#     1      1.656406   1.080915   0.692824
#     2      0.844575   0.755268   0.784977
#     3      1.134393   1.154705   0.674792
#     4      0.699216   0.751938   0.789454
#     5      0.388825   0.559904   0.839448
#     6      0.244233   0.531882   0.848278
# CPU times: user 47min 23s, sys: 9min 36s, total: 56min 59s
# Wall time: 43min 3s
# [array([0.53188]), 0.8482775774676324]

# %%
#Another trick we've used here is adding the cycle_mult parameter. Take a look at the following chart, and see if you can figure out what the parameter is doing:
learn.sched.plot_lr()

# %% [markdown]
# Note that's what being plotted above is the learning rate of the final layers. The learning rates of the earlier layers are fixed at the same multiples of the final layer rates as we initially requested (i.e. the first layers have 100x smaller, and middle layers 10x smaller learning rates, since we set lr=np.array([1e-4,1e-3,1e-2]).

# %%
learn.sched.plot_loss()

# %%
learn.save('224_all')

# %%
learn.load('224_all')

# %% [markdown]
# ###Increase image size

# %%
sz = 400

# %%
def get_data(sz):
    tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on, max_zoom=1.1)
    return ImageClassifierData.from_paths(PATH, val_name='test', tfms=tfms, bs=bs, num_workers=4)

# %%
#data = get_data(sz)
#data = data.resize(int(sz*1.3), 'tmp')

# %%
learn.set_data(get_data(sz))
learn.freeze()

# %%
lrf=learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1, style=ProgressStyle(description_width='initial…
#  93%|█████████▎| 119/128 [06:36<00:26,  3.00s/it, loss=3.59]

# %%
learn.sched.plot_lr()

# %%
# choose new learning rate, and run fit
lr=0.05
# %time learn.fit(lr, 3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.757109   0.74036    0.794429
#     1      0.63529    0.708128   0.80301
#     2      0.555756   0.680665   0.813083
# CPU times: user 40min 42s, sys: 10min 12s, total: 50min 55s
# Wall time: 35min 26s
# [array([0.68067]), 0.8130829497484289]

# %%
learn.sched.plot_loss()

# %%
learn.unfreeze()

# %%
lr=np.array([0.0005, 0.005, 0.05])
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals=True) # 1+2+4 = 7 epochs

# %%
learn.sched.plot_loss()

# %%
def plot_ep_vals(ep_vals):
    plt.ylabel("loss")
    plt.xlabel("epoch")
    epochs = ep_vals.keys()
    plt.xticks(np.asarray(list(epochs)))
    trn_losses = [item[0] for item in list(ep_vals.values())]
    val_losses = [item[1] for item in list(ep_vals.values())]
    plt.plot(epochs, trn_losses, c='b', label='train')
    plt.plot(epochs, val_losses, c='r', label='validation')
    plt.legend(loc='upper left')

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.save(f'{sz}')

# %% [markdown]
# ###Final Layer fitting with TTA

# %%
# frezzing all early layers, and training few more epochs on last layer
learn.freeze()

# %%
learn.summary()

# %%
#learn.fit(0.1, 3, cycle_len=1)

# %%
# Validation loss is much lower than training loss. This is a sign of underfitting. Cycle_len=1 may be too short. Let's set cycle_mult=2 to find better parameter.
# When you are under fitting, it means cycle_len=1 is too short (learning rate is getting reset before it had the chance to zoom in properly).
#%% time 
#vals_s2s, ep_vals_s2s = learn.fit(0.1, 3, cycle_len=1, cycle_mult=2, get_ep_vals=True) # 1+2+4 = 7 epochs

# %%
#learn.sched.plot_loss()

# %%
# %time log_preds, y = learn.TTA() # (5, 2044, 120), (2044,)
probs = np.mean(np.exp(log_preds),0)
accuracy_np(probs, y), metrics.log_loss(y, probs)

# %%
learn.save('299_pre')

# %%
learn.load('299_pre')

# %% [markdown]
# ## Analyzing Results
# ### Confusion matrix

# %%
preds = np.argmax(probs, axis=1)
probs = probs[:,1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y, preds)

# %%
plot_confusion_matrix(cm, data.classes, figsize=(15,10))

# %% [markdown]
# ## Analyzing results: looking at pictures

# %% [markdown]
# As well as looking at the overall metrics, it's also a good idea to look at examples of each of:
# 1. A few correct labels at random
# 2. A few incorrect labels at random
# 3. The most correct labels of each class (i.e. those with highest probability that are correct)
# 4. The most incorrect labels of each class (i.e. those with highest probability that are incorrect)
# 5. The most uncertain labels (i.e. those with probability closest to 0.5).

# %%
# This is the label for a val data
data.val_y

# %%
# from here we know that 'cats' is label 0 and 'dogs' is label 1.
data.classes

# %%
# this gives prediction for validation set. Predictions are in log scale
log_preds = learn.predict()
log_preds.shape

# %%
log_preds[:10]

# %%
preds = np.argmax(log_preds, axis=1)  # from log probabilities to 0 or 1
probs = np.exp(log_preds[:,1])        # pr(dog)

# %%
def rand_by_mask(mask): return np.random.choice(np.where(mask)[0], min(len(preds), 4), replace=False)
def rand_by_correct(is_correct): return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])

# %%
def load_img_id(ds, idx): return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(idxs, title):
    imgs = [load_img_id(data.val_ds,x) for x in idxs]
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8)) if len(imgs)>0 else print('Not Found.')

# %%
# 1. A few correct labels at random
plot_val_with_title(rand_by_correct(True), "Correctly classified")

# %%
# 2. A few incorrect labels at random
plot_val_with_title(rand_by_correct(False), "Incorrectly classified")

# %%
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)

# %%
plot_val_with_title(most_by_correct(0, True), "Most correct cats")

# %%
plot_val_with_title(most_by_correct(1, True), "Most correct dogs")

# %%
plot_val_with_title(most_by_correct(0, False), "Most incorrect cats")

# %%
plot_val_with_title(most_by_correct(1, False), "Most incorrect dogs")

# %%
most_uncertain = np.argsort(np.abs(probs -0.5))[:4]
plot_val_with_title(most_uncertain, "Most uncertain predictions")

# %% [markdown]
# ## Analyzing results: loss and accuracy

# %% [markdown]
# When we run `learn.fit` we print 3 performance values (see above.) Here 0.03 is the value of the **loss** in the training set, 0.0226 is the value of the loss in the validation set and 0.9927 is the validation accuracy. What is the loss? What is accuracy? Why not to just show accuracy?
#
# **Accuracy** is the ratio of correct prediction to the total number of predictions.
#
# In machine learning the **loss** function or cost function is representing the price paid for inaccuracy of predictions.
#
# The loss associated with one example in binary classification is given by:
# `-(y * log(p) + (1-y) * log (1-p))`
# where `y` is the true label of `x` and `p` is the probability predicted by our model that the label is 1.

# %%
def binary_loss(y, p):
    return np.mean(-(y * np.log(p) + (1-y)*np.log(1-p)))

# %%
acts = np.array([1, 0, 0, 1])
preds = np.array([0.9, 0.1, 0.2, 0.8])
binary_loss(acts, preds)

# %% [markdown]
# Note that in our toy example above our accuracy is 100% and our loss is 0.16. Compare that to a loss of 0.03 that we are getting while predicting cats and dogs. Exercise: play with `preds` to get a lower loss for this example.
#
# **Example:** Here is an example on how to compute the loss for one example of binary classification problem. Suppose for an image x with label 1 and your model gives it a prediction of 0.9. For this case the loss should be small because our model is predicting a label $1$ with high probability.
#
# `loss = -log(0.9) = 0.10`
#
# Now suppose x has label 0 but our model is predicting 0.9. In this case our loss should be much larger.
#
# loss = -log(1-0.9) = 2.30
#
# - Exercise: look at the other cases and convince yourself that this make sense.
# - Exercise: how would you rewrite `binary_loss` using `if` instead of `*` and `+`?
#
# Why not just maximize accuracy? The binary classification loss is an easier function to optimize.
