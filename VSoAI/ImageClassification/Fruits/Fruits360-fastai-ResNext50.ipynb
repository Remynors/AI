# %% [markdown]
# ## Kaggle Fruits 360 Image Classification with Fast.ai

# %% [markdown]
# https://www.kaggle.com/moltean/fruits

# %%
## Check GPU memory availability

# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Requirement already satisfied: gputil in /usr/local/lib/python3.6/dist-packages (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gputil) (1.14.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Gen RAM Free: 12.8 GB  | Proc size: 139.2 MB
# GPU RAM Free: 11441MB | Used: 0MB | Util   0% | Total 11441MB

# %%
## install and setup Fast.ai v.0.7.0, pytorch and dependencies

#!pip uninstall fastai
# !pip install Pillow==4.1.1
# !pip install "fastai==0.7.0"
# !pip install torchtext==0.2.3
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
import cv2
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
# !apt update && apt install -y libsm6 libxext6

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'
# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch
# !pip install image

# %matplotlib inline
from fastai.imports import *
# Out:
# Requirement already satisfied: Pillow==4.1.1 in /usr/local/lib/python3.6/dist-packages (4.1.1)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.1.1) (0.46)
# Requirement already satisfied: fastai==0.7.0 in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.1.7)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.22.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.28.1)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.10)
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.1.0)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (17.0.0)
# Requirement already satisfied: widgetsnbextension in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.4.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (7.4.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.13)
# Requirement already satisfied: feather-format in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.4.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.3.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.1.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (5.5.0)
# Requirement already satisfied: torch<0.4 in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.3.0.post4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.5.3)
# Requirement already satisfied: sklearn-pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.7.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.10.15)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.1)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.5.3)
# Requirement already satisfied: pandas-summary in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.0.5)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.4.2)
# Requirement already satisfied: simplegeneric in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.8.1)
# Requirement already satisfied: bcolz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.2.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.4.3.18)
# Requirement already satisfied: cycler in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.10.0)
# Requirement already satisfied: plotnine in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.3)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.0.1)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.3.3)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.10.1)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.7)
# Requirement already satisfied: torchtext in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.3)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.6.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.14.6)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.1.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.6.1)
# Requirement already satisfied: jedi in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from bleach->fastai==0.7.0) (1.11.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (6.0.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.4.0)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (4.4.3)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.2.2)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: pyarrow>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from feather-format->fastai==0.7.0) (0.11.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (4.6.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (40.6.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (1.0.15)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from sklearn-pandas->fastai==0.7.0) (0.19.2)
# Requirement already satisfied: descartes>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (1.1.0)
# Requirement already satisfied: mizani>=0.5.2 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.5.2)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.5.1)
# Requirement already satisfied: statsmodels>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext->fastai==0.7.0) (2.18.4)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->fastai==0.7.0) (0.46)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel->fastai==0.7.0) (5.2.3)
# Requirement already satisfied: parso>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from jedi->fastai==0.7.0) (0.3.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (1.4.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.5.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: mistune>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.8.4)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->fastai==0.7.0) (0.8.1)
# Requirement already satisfied: palettable in /usr/local/lib/python3.6/dist-packages (from mizani>=0.5.2->plotnine->fastai==0.7.0) (3.1.1)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (1.22)
# Requirement already satisfied: torchtext==0.2.3 in /usr/local/lib/python3.6/dist-packages (0.2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2018.10.15)
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  Release
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [83.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Fetched 247 kB in 2s (119 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 7 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.2-1).
# libxext6 is already the newest version (2:1.3.3-1).
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Requirement already satisfied: image in /usr/local/lib/python3.6/dist-packages (1.5.27)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from image) (4.1.1)
# Requirement already satisfied: django in /usr/local/lib/python3.6/dist-packages (from image) (2.1.3)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->image) (0.46)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from django->image) (2018.7)

# %%
import sys
sys.version
# Out:
# '3.6.7 (default, Oct 22 2018, 11:32:17) \n[GCC 8.2.0]'

# %%
import torch
print(torch.__version__)
# Out:
# 0.3.0.post4

# %% [markdown]
# It's important that you have a working NVidia GPU set up. The programming framework used to behind the scenes to work with NVidia GPUs is called CUDA. Therefore, you need to ensure the following line returns `True` before you proceed. If you have problems with this, please check the FAQ and ask for help on [the forums](http://forums.fast.ai).

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# In addition, NVidia provides special accelerated functions for deep learning in a package called CuDNN. Although not strictly necessary, it will improve training performance significantly, and is included by default in all supported fastai configurations. Therefore, if the following does not return `True`, you may want to look into why.

# %%
torch.backends.cudnn.enabled
# Out:
# True

# %%
import fastai as fai
from fastai.imports import *

# %%
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Loading Dataset

# %%
DATASET_ZIP_FILE = 'fruits.zip'

# %%
from zipfile import ZipFile
files = os.listdir()
if not DATASET_ZIP_FILE in files:
  
#  !curl --header 'Host: storage.googleapis.com' --user-agent 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0' --header 'Accept: text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8' --header 'Accept-Language: en-US,en;q=0.5' --referer 'https://www.kaggle.com/' --cookie '_ga=GA1.3.597929118.1540370868' --header 'Upgrade-Insecure-Requests: 1' 'https://storage.googleapis.com/kaggle-datasets/5857/94583/fruits.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1543353373&Signature=rfXrXBZSWzulX89wVMZDAe94oaVLEUrANf5DzrxnaezszFEgWrtoWzGeDjVDStAn3jdczeSknwH5uS%2BJ8Q6QJLiEqoFcB2iM0LANrl6cc6RWXynmI0NxIUqhFeL%2BngeQF1eFNivl4aCKBZDsqW7%2BtIPAWyfpcBvXKP0ACgmnJt%2Fb%2BUe7NnLWZ9c353YPK4msQAvM5H5c40kXAzYX9er6XpX7HOTUkY%2FXrVhNhmuiorDFERNHhdzmBHepDJRRhY5x34NXw3z0pk6Rn7aToBh9yqNQ8aQDeekNrBDQky9KahJmupA5DpjdK76vA3jKX29Cw%2FnAdj9w7GyKiIZ1iYtm8g%3D%3D' --output 'fruits.zip'  #The first step is install kaggle
#'''
  # !pip install kaggle
  from google.colab import files
  files.upload()
  # !mkdir -p ~/.kaggle
  # !cp kaggle.json ~/.kaggle/
  #this permissions change avoids a warnong on Kaggle tool startup
  # !chmod 600 ~/.kaggle/kaggle.json  
  # !kaggle datasets download -d moltean/fruits
#'''
  # !ls
  with ZipFile(DATASET_ZIP_FILE, 'r') as zipF:
    zipF.extractall()
    print('UnZip Done')

# %%
#lets see the imported files from kaggle dataset
# !ls -l
# Out:
# total 2750240
# drwxr-xr-x 8 root root       4096 Nov 25 12:41 fruits-360
# -rw-r--r-- 1 root root  425299224 Nov 25 12:38 fruits.zip
# -rw-r--r-- 1 root root         62 Nov 25 12:38 kaggle.json
# -rw-r--r-- 1 root root      62040 Nov 25 13:09 losses.npy
# -rw-r--r-- 1 root root       8943 Nov 25 13:09 loss_plot.png
# -rw-r--r-- 1 root root      14725 Nov 25 13:12 lr_plot.png
# drwxr-xr-x 2 root root       4096 Nov 20 18:17 sample_data
# drwxrwxr-x 2 1001 1001       4096 Nov  4  2017 weights
# -rw-r--r-- 1 root root 1195411318 Nov  4  2017 weights.tgz
# -rw-r--r-- 1 root root 1195411318 Nov  4  2017 weights.tgz.1

# %%
data_dir = 'fruits-360/'
PATH = data_dir

train_dir = 'Training'
val_dir = 'Test'

# %%
# !ls '{data_dir}'
# Out:
# LICENSE  models  papers  readme.md  Test  test-multiple_fruits	tmp  Training

# %% [markdown]
# # Model Architecture Selection

# %% [markdown]
# ## First look at pictures

# %%
## CHOOSE ARCHITECTURE AND IMAGE SIZE

#arch = vgg16
#arch = resnet34
arch = resnext50
#arch = resnext101_64
#arch = inceptionresnetv2
#arch = inceptionv4
sz = 100
bs = 16

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Our library will assume that you have *train* and *valid* directories. It also assumes that each dir will have subdirs for each class you wish to recognize

# %%
files = os.listdir(f'{data_dir}{train_dir}/Banana')[:5]
files
# Out:
# ['91_100.jpg', '0_100.jpg', '155_100.jpg', 'r_190_100.jpg', 'r_22_100.jpg']

# %%
img = plt.imread(f'{data_dir}{train_dir}/Banana/{files[3]}')
plt.imshow(img);

# %% [markdown]
# Here is how the raw data looks like

# %%
# fast.ai functions to initialize transform and data loader objects

tfms=tfms_from_model(arch, sz)
data = ImageClassifierData.from_paths(PATH, trn_name = train_dir, val_name=val_dir, tfms=tfms, bs=bs)

# %%
#pick first image just for viewing
pic = PATH + data.trn_ds.fnames[0]; pic
# Out:
# 'fruits-360/Training/Apple Braeburn/0_100.jpg'

# %%
img = PIL.Image.open(pic); img
#img = PIL.Image.open(f'{pic}');
#img = plt.imread(pic)
#plt.imshow(img);
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7FBEA81FEDA0>

# %%
# create python data dictionary {}, path/file and image size(x,y)
# ps very long processing time
e_d = {k: PIL.Image.open(PATH + k).size for k in data.trn_ds.fnames}

# %%
#e_d

# %%
#!pip3 list

# %%
'''
#redefine zip, after ZipFile breaks it
def zip(*iterables):
    # zip('ABCD', 'xy') --> Ax By
    sentinel = object()
    iterators = [iter(it) for it in iterables]
    while iterators:
        result = []
        for it in iterators:
            elem = next(it, sentinel)
            if elem is sentinel:
                return
            result.append(elem)
        yield tuple(result)
'''
# Out:
# "\n#redefine zip, after ZipFile breaks it\ndef zip(*iterables):\n    # zip('ABCD', 'xy') --> Ax By\n    sentinel = object()\n    iterators = [iter(it) for it in iterables]\n    while iterators:\n        result = []\n        for it in iterators:\n            elem = next(it, sentinel)\n            if elem is sentinel:\n                return\n            result.append(elem)\n        yield tuple(result)\n"

# %%
import os
row_sz, col_sz = list(zip(*e_d.values()))

# %%
row_sz[:5]
# Out:
# (100, 100, 100, 100, 100)

# %%
row_sz = np.array(row_sz); col_sz = np.array(col_sz)

# %%
col_sz[:5]
# Out:
# array([100, 100, 100, 100, 100])

# %%
# find few row/col ratios
row_sz[:5]/col_sz[:5]
# Out:
# array([1., 1., 1., 1., 1.])

# %%
print(min(row_sz), max(row_sz))
# Out:
# 100 100

# %%
plt.hist(row_sz);

# %%
#plt.hist(row_sz[row_sz < 800])

# %%
# again, list total number of classes, and list them all
# os.list dir sorting depends on OS dependent file indexing, so leaving it as it is

classes = os.listdir(f'{data_dir}{train_dir}')
classes.sort()
print("Class Total Count: ", len(classes))
print(classes)
# Out:
# Class Total Count:  81
# ['Apple Braeburn', 'Apple Golden 1', 'Apple Golden 2', 'Apple Golden 3', 'Apple Granny Smith', 'Apple Red 1', 'Apple Red 2', 'Apple Red 3', 'Apple Red Delicious', 'Apple Red Yellow', 'Apricot', 'Avocado', 'Avocado ripe', 'Banana', 'Banana Red', 'Cactus fruit', 'Cantaloupe 1', 'Cantaloupe 2', 'Carambula', 'Cherry 1', 'Cherry 2', 'Cherry Rainier', 'Cherry Wax Black', 'Cherry Wax Red', 'Cherry Wax Yellow', 'Clementine', 'Cocos', 'Dates', 'Granadilla', 'Grape Pink', 'Grape White', 'Grape White 2', 'Grapefruit Pink', 'Grapefruit White', 'Guava', 'Huckleberry', 'Kaki', 'Kiwi', 'Kumquats', 'Lemon', 'Lemon Meyer', 'Limes', 'Lychee', 'Mandarine', 'Mango', 'Maracuja', 'Melon Piel de Sapo', 'Mulberry', 'Nectarine', 'Orange', 'Papaya', 'Passion Fruit', 'Peach', 'Peach Flat', 'Pear', 'Pear Abate', 'Pear Monster', 'Pear Williams', 'Pepino', 'Physalis', 'Physalis with Husk', 'Pineapple', 'Pineapple Mini', 'Pitahaya Red', 'Plum', 'Pomegranate', 'Quince', 'Rambutan', 'Raspberry', 'Salak', 'Strawberry', 'Strawberry Wedge', 'Tamarillo', 'Tangelo', 'Tomato 1', 'Tomato 2', 'Tomato 3', 'Tomato 4', 'Tomato Cherry Red', 'Tomato Maroon', 'Walnut']

# %%
# parse all classes and assemble python list object []
# each list element will contain array of files names of a class

all_images_class = [os.listdir(f'{data_dir}{train_dir}/'+c) for c in classes]
#int_to_classes = {i:classes[i] for i in range(len(classes))}
#classes_to_int = {classes[i]:i for i in range(len(classes))}
print("Classes: ",len(all_images_class) )
# Out:
# Classes:  81

# %%
# create python data dictionary {}, with key="text", and value as length(of size) of containing list object array (1D)
# gives histogram like file count for each class
dataDict= {"n_images": [len(x) for x in all_images_class]}
print("file count in each class: ",dataDict)
trainFiles = 0
for x in all_images_class:
  trainFiles = trainFiles+len(x)
print(" Total Train Files: ", trainFiles)
# Out:
# file count in each class:  {'n_images': [492, 492, 492, 481, 492, 492, 492, 429, 490, 492, 492, 427, 491, 490, 490, 490, 492, 492, 490, 492, 738, 738, 492, 492, 492, 490, 490, 490, 490, 492, 490, 490, 490, 492, 490, 490, 490, 466, 490, 492, 490, 490, 490, 490, 490, 490, 738, 492, 492, 479, 492, 490, 492, 492, 492, 490, 490, 490, 490, 492, 492, 490, 493, 490, 447, 492, 490, 492, 490, 490, 492, 738, 490, 490, 738, 672, 738, 479, 492, 367, 735]}
#  Total Train Files:  41322

# %%
# assemble panda Dataframe {class pandas.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)}
# Train Data set
df = pd.DataFrame(dataDict, index=classes)
df.index.name = "Fruits"

# %%
df.plot(kind="bar", grid=True,figsize=(20,8))

# %% [markdown]
# ##Review: easy steps to train a world-class image classifier
#
#  *   precompute=True
#  *   Use lr_find() to find highest learning rate where loss is still clearly improving
#  *   Train last layer from precomputed activations for 1-2 epochs
#  *   Train last layer with data augmentation (i.e. precompute=False) for 2-3 epochs with cycle_len=1
#  *   Unfreeze all layers
#  *   Set earlier layers to 3x-10x lower learning rate than next higher layer
#  *   Use lr_find() again
#  *   Train full network with cycle_mult=2 until over-fitting

# %%
#function to plot training and validation loss
def plot_ep_vals(ep_vals):
    plt.ylabel("loss")
    plt.xlabel("epoch")
    epochs = ep_vals.keys()
    plt.xticks(np.asarray(list(epochs)))
    trn_losses = [item[0] for item in list(ep_vals.values())]
    val_losses = [item[1] for item in list(ep_vals.values())]
    plt.plot(epochs, trn_losses, c='b', label='train')
    plt.plot(epochs, val_losses, c='r', label='validation')
    plt.legend(loc='upper left')

# %% [markdown]
# ## Initial Model

# %%
## download fast.ai pretrained network weigths, and copy to local directory

# !wget http://files.fast.ai/models/weights.tgz
# !tar -xvzf weights.tgz
# Out:
# --2018-11-25 13:42:02--  http://files.fast.ai/models/weights.tgz
# Resolving files.fast.ai (files.fast.ai)... 67.205.15.147
# Connecting to files.fast.ai (files.fast.ai)|67.205.15.147|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1195411318 (1.1G) [text/plain]
# Saving to: ‘weights.tgz.2’
#
# weights.tgz.2       100%[===================>]   1.11G  15.6MB/s    in 74s
#
# 2018-11-25 13:43:17 (15.4 MB/s) - ‘weights.tgz.2’ saved [1195411318/1195411318]
#
# weights/
# weights/wrn_50_2f.pth
# weights/resnext_101_32x4d.pth
# weights/resnext_101_64x4d.pth
# weights/inceptionresnetv2-d579a627.pth
# weights/inceptionv4-97ef9c30.pth
# weights/resnext_50_32x4d.pth

# %%
# !ls '/usr/local/lib/python3.6/dist-packages/fastai'
# !cp -R weights '/usr/local/lib/python3.6/dist-packages/fastai/'
# Out:
# adaptive_softmax.py  initializers.py	  metrics.py	sgdr.py
# column_data.py	     __init__.py	  model.py	structured.py
# conv_learner.py      io.py		  models	swa.py
# core.py		     layer_optimizer.py   nlp.py	text.py
# dataloader.py	     layers.py		  plots.py	torch_imports.py
# dataset.py	     learner.py		  __pycache__	transforms_pil.py
# executors.py	     lm_rnn.py		  rnn_reg.py	transforms.py
# fp16.py		     losses.py		  rnn_train.py	utils.py
# imports.py	     lsuv_initializer.py  set_spawn.py	weights

# %%
# Get initial predictions on pre-trained network, just training last layers
# model trained on ImageNet (1.2 million images and 1000 classes) as a starting point.
'''
## Fast.ai ConvLearner
As we can see the ConvLearner.pretrained method changes the last few layers of the input model.
Specifically it changes the AvgPool2d with AdaptiveConcatPool2d, Flattens it, 
Adds to linear layers with batch norms and relu, adds dropout, and finally puts a LogSoftmax layer.

The reason for using Adaptive Pooling layers is that it allows the model to use any image size 
rather than being restricted to a constant size of say 224 x 224. 
What Adaptive Pooling layer does is it to specify the output size rather than the kernel size.
'''

learn = ConvLearner.pretrained(arch, data)
# %time learn.fit(0.001, 3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.13282    0.114544   0.975355
#     1      0.077858   0.077249   0.979967
#     2      0.048453   0.064046   0.979751
#
# CPU times: user 10min 10s, sys: 2min 51s, total: 13min 1s
# Wall time: 11min 38s
# [array([0.06405]), 0.9797506665705844]

# %%
#?ConvLearner   # ? short function description
#??ConvLearner   # ?? full function source

# %%
#??ConvLearner.pretrained

# %%
#??ConvLearner.from_model_data

# %%
learn.model
# Out:
# Sequential(
#   (0): Conv2d (3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (2): ReLU()
#   (3): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#   (4): Sequential(
#     (0): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Sequential(
#           (0): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#   )
#   (5): Sequential(
#     (0): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Sequential(
#           (0): Conv2d (256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (3): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#   )
#   (6): Sequential(
#     (0): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Sequential(
#           (0): Conv2d (512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (3): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (4): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (5): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#   )
#   (7): Sequential(
#     (0): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Sequential(
#           (0): Conv2d (1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#   )
#   (8): AdaptiveConcatPool2d(
#     (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#     (mp): AdaptiveMaxPool2d(output_size=(1, 1))
#   )
#   (9): Flatten(
#   )
#   (10): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True)
#   (11): Dropout(p=0.25)
#   (12): Linear(in_features=4096, out_features=512)
#   (13): ReLU()
#   (14): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True)
#   (15): Dropout(p=0.5)
#   (16): Linear(in_features=512, out_features=81)
#   (17): LogSoftmax()
# )

# %%
learn.sched.plot_loss()

# %%
# error for some reason ???
'''
fig,ax = plt.subplots(2,1,figsize=(8,12))
ax[0].plot(list(range(95)),learn.sched.val_losses, label='Validation loss')
ax[0].plot(list(range(95)),[learn.sched.losses[i] for i in range(97,95*98,98)], label='Training loss')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].legend(loc='upper right')
ax[1].plot(list(range(95)),learn.sched.rec_metrics)
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
'''
# Out:
# "\nfig,ax = plt.subplots(2,1,figsize=(8,12))\nax[0].plot(list(range(95)),learn.sched.val_losses, label='Validation loss')\nax[0].plot(list(range(95)),[learn.sched.losses[i] for i in range(97,95*98,98)], label='Training loss')\nax[0].set_xlabel('Epoch')\nax[0].set_ylabel('Loss')\nax[0].legend(loc='upper right')\nax[1].plot(list(range(95)),learn.sched.rec_metrics)\nax[1].set_xlabel('Epoch')\nax[1].set_ylabel('Accuracy')\n"

# %% [markdown]
# ### Choosing a learning rate
# The *learning rate* determines how quickly or how slowly you want to update the *weights* (or *parameters*). Learning rate is one of the most difficult parameters to set, because it significantly affects model performance.
#
# The method `learn.lr_find()` helps you find an optimal learning rate. It uses the technique developed in the 2015 paper [Cyclical Learning Rates for Training Neural Networks](http://arxiv.org/abs/1506.01186), where we simply keep increasing the learning rate from a very small value, until the loss stops decreasing. We can plot the learning rate across batches to see what this looks like.
#
# We first create a new learner, since we want to know how to set the learning rate for a new (untrained) model.

# %%
lrf=learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1, style=ProgressStyle(description_width='initial…
#  56%|█████▌    | 1434/2583 [01:39<01:07, 16.99it/s, loss=0.143]

# %%
# Our learn object contains an attribute sched that contains our learning rate scheduler, and has some convenient plotting functionality including this one:
learn.sched.plot_lr()

# %%
learn.sched.plot()

# %%
lrate = 0.002

# %% [markdown]
# The loss is still clearly improving at lr=0.002, so that's what we use. Note that the optimal learning rate can change as we train the model, so you may want to re-run this function from time to time.

# %% [markdown]
# ### Augment data set
# If you try training for more epochs, you'll notice that we start to overfit, which means that our model is learning to recognize the specific images in the training set, rather than generalizing such that we also get good results on the validation set. One way to fix this is to effectively create more data, through data augmentation. This refers to randomly changing the images in ways that shouldn't impact their interpretation, such as horizontal flipping, zooming, and rotating.
#
# We can do this by passing aug_tfms (augmentation transforms) to tfms_from_model, with a list of functions to apply that randomly change the image however we wish. For photos that are largely taken from the side (e.g. most photos of dogs and cats, as opposed to photos taken from the top down, such as satellite imagery) we can use the pre-defined list of functions transforms_side_on. We can also specify random zooming of images up to specified scale by adding the max_zoom parameter.

# %%
from sklearn import metrics

# %%
def get_data(arch, sz, bs):
    tfms = tfms_from_model(arch, sz, aug_tfms=transforms_top_down, max_zoom=1.05)
    data = ImageClassifierData.from_paths(PATH, trn_name = train_dir, val_name=val_dir, tfms=tfms, bs=bs)
    return data

# %%
#??tfms_from_model
#??ConvLearner

# %%
# start with smaller image size (larger batch), e.g. 32, 64,  100
sz = 32
bs = 32

# %%
data = get_data(arch, sz, bs)

# %%
def get_augs():
    x,_ = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[1]

# %%
# plot augmented sample image
ims = np.stack([get_augs() for i in range(6)])
plots(ims, rows=2)

# %%
learn = ConvLearner.pretrained(arch, data)

# %%
# cycle_len - learning rate annealing used by stochastic gradient descent with restarts (SGDR),
# %time vals_s2s, ep_vals_s2s = learn.fit(lrate, 3, cycle_len=1, cycle_mult=2, get_ep_vals = True )
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.774404   0.549832   0.86892
#     1      0.372923   0.281427   0.918642
#     2      0.319218   0.263144   0.923543
#     3      0.255443   0.226888   0.929524
#     4      0.189083   0.19155    0.938387
#     5      0.201125   0.174678   0.942351
#     6      0.187997   0.18541    0.940837
# CPU times: user 15min 13s, sys: 4min 38s, total: 19min 52s
# Wall time: 15min 47s

# %% [markdown]
# What is that cycle_len parameter? What we've done here is used a technique called stochastic gradient descent with restarts (SGDR), a variant of learning rate annealing, which gradually decreases the learning rate as training progresses. This is helpful because as we get closer to the optimal weights, we want to take smaller steps.
#
# However, we may find ourselves in a part of the weight space that isn't very resilient - that is, small changes to the weights may result in big changes to the loss. We want to encourage our model to find parts of the weight space that are both accurate and stable. Therefore, from time to time we increase the learning rate (this is the 'restarts' in 'SGDR'), which will force the model to jump to a different part of the weight space if the current area is "spikey". Here's a picture of how that might look if we reset the learning rates 3 times (in this paper they call it a "cyclic LR schedule"):
#
# (From the paper [Snapshot Ensembles](https://arxiv.org/abs/1704.00109)).
#
# The number of epochs between resetting the learning rate is set by cycle_len, and the number of times this happens is refered to as the number of cycles, and is what we're actually passing as the 2nd parameter to fit(). So here's what our actual learning rates looked like:

# %%
# if Validation loss is much lower than training loss. This is a sign of underfitting. Cycle_len=1 may be too short. Let's set cycle_mult=2 to find better parameter.
# When you are under fitting, it means cycle_len=1 is too short (learning rate is getting reset before it had the chance to zoom in properly).

# in our case we are skipping this
# learn = ConvLearner.pretrained(arch, data)
# learn.fit(1e-1, 3, cycle_len=1, cycle_mult=2) # 1+2+4 = 7 epochs

# %%
learn.sched.plot_loss()

# %%
# plot training and validation loss
plot_ep_vals(ep_vals_s2s)

# %%
learn.sched.plot_lr()

# %%
learn.save('32_pre')

# %%
learn.load('32_pre')

# %% [markdown]
# ###Fine-tuning and differential learning rate annealing
# Now that we have a good final layer trained, we can try fine-tuning the other layers. To tell the learner that we want to unfreeze the remaining layers, just call (surprise surprise!) unfreeze().

# %%
learn.unfreeze()
# keep batch normalization moving avg not be updated. Very important!!!
#learn.ns_freeze(True)

# %% [markdown]
# ote that the other layers have already been trained to recognize imagenet photos (whereas our final layers where randomly initialized), so we want to be careful of not destroying the carefully tuned weights that are already there.
#
# Generally speaking, the earlier layers (as we've seen) have more general-purpose features. Therefore we would expect them to need less fine-tuning for new datasets. For this reason we will use different learning rates for different layers: the first few layers will be at 1e-4, the middle layers at 1e-3, and our FC layers we'll leave at 1e-2 as before. We refer to this as differential learning rates, although there's no standard name for this techique in the literature that we're aware of.

# %%
lr=np.array([lrate/100, lrate/10, lrate])
% time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals = True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.508824   0.22156    0.927722
#     1      0.220965   0.107735   0.963321
#     2      0.163291   0.097944   0.964906
#     3      0.126885   0.079147   0.972112
#     4      0.084462   0.058671   0.975355
#     5      0.084485   0.060218   0.975427
#     6      0.073707   0.068656   0.970455
# CPU times: user 26min 56s, sys: 8min 35s, total: 35min 32s
# Wall time: 31min 59s

# %%
#Another trick we've used here is adding the cycle_mult parameter. Take a look at the following chart, and see if you can figure out what the parameter is doing:
learn.sched.plot_lr()

# %% [markdown]
# Note that's what being plotted above is the learning rate of the final layers. The learning rates of the earlier layers are fixed at the same multiples of the final layer rates as we initially requested (i.e. the first layers have 100x smaller, and middle layers 10x smaller learning rates, since we set lr=np.array([1e-4,1e-3,1e-2]).

# %%
learn.sched.plot_loss()

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.save('32f_all')

# %%
learn.load('32f_all')

# %% [markdown]
# ###Increase image size

# %%
sz = 64
bs = 16

# %%
data = get_data(arch, sz, bs)
learn.set_data(data)

# %%
learn.freeze()
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals = True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.423587   0.241578   0.933271
#     1      0.275163   0.153409   0.951142
#     2      0.262769   0.142033   0.956619
#     3      0.231454   0.131239   0.960222
#     4      0.17222    0.11853    0.960654
#     5      0.1704     0.116039   0.963753
#     6      0.148092   0.110747   0.965338
# CPU times: user 24min 43s, sys: 6min 55s, total: 31min 38s
# Wall time: 26min 42s

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.unfreeze()
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals = True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.13403    0.040788   0.982849
#     1      0.089219   0.022256   0.992001
#     2      0.06331    0.02088    0.990488
#     3      0.063079   0.025297   0.988182
#     4      0.027947   0.020604   0.989191
#     5      0.037283   0.022236   0.988686
#     6      0.033178   0.022647   0.98883
# CPU times: user 49min 3s, sys: 15min 8s, total: 1h 4min 12s
# Wall time: 1h 41s

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.save(f'{sz}')

# %%
learn.load(f'{sz}')

# %%
sz = 100
bs = 16

# %%
data = get_data(arch, sz, bs)
learn.set_data(data)

# %%
learn.freeze()
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals = True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.059766   0.042153   0.984795
#     1      0.045595   0.036213   0.987822
#     2      0.032516   0.035389   0.98775
#     3      0.029995   0.028213   0.989335
#     4      0.035557   0.027363   0.989911
#     5      0.028653   0.030938   0.988038
#     6      0.02748    0.02807    0.989047
# CPU times: user 28min 8s, sys: 7min 20s, total: 35min 29s
# Wall time: 30min 11s

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.unfreeze()
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals = True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.041157   0.020502   0.991569
#     1      0.029408   0.019489   0.988542
#     2      0.021732   0.019919   0.991064
#     3      0.013911   0.019991   0.989119
#     4      0.016862   0.018792   0.989839
#     5      0.018317   0.019497   0.989839
#     6      0.016352   0.019819   0.99056
# CPU times: user 58min 36s, sys: 17min 58s, total: 1h 16min 35s
# Wall time: 1h 17min 58s

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.save(f'{sz}')

# %%
learn.load(f'{sz}')

# %% [markdown]
# ###Final Layer fitting with TTA

# %%
# frezzing all early layers, and training few more epochs on last layer
#learn.freeze()

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 100, 100]),
#                            ('output_shape', [-1, 64, 50, 50]),
#                            ('trainable', True),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 50, 50]),
#                            ('output_shape', [-1, 64, 50, 50]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 50, 50]),
#                            ('output_shape', [-1, 64, 50, 50]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 50, 50]),
#                            ('output_shape', [-1, 64, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-11',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-12',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('Conv2d-13',
#               OrderedDict([('input_shape', [-1, 64, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 16384)])),
#              ('BatchNorm2d-14',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-15',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-16',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-17',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-18',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-24',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-25',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-26',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-27',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 128, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-34',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-35',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-36',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-37',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-38',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-39',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Conv2d-42',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-43',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-44',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-45',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-46',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-47',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-48',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-49',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-50',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-56',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-57',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-58',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-59',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-66',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-67',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-68',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 256, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-69',
#               OrderedDict([('input_shape', [-1, 256, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-70',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-71',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-72',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-73',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-75',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-76',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-77',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-78',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-79',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('Conv2d-80',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-81',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-82',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-83',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-84',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-85',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-86',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-87',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-88',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-89',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-90',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-91',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-92',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-93',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-94',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-95',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-96',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-97',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-98',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-99',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-100',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-101',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-102',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-103',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-104',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-105',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-106',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-107',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-108',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-109',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-110',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-111',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-112',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-113',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-114',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-115',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-116',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-117',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-118',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-119',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-120',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-121',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-122',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-123',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-124',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-125',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-126',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-127',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-128',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-129',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-130',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-131',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-132',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-133',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-134',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-135',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('Conv2d-136',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-137',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-138',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-139',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-140',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-141',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-142',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-143',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-144',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-145',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-146',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-147',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-148',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-149',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-150',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-151',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-152',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-153',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 1024, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-154',
#               OrderedDict([('input_shape', [-1, 1024, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-155',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-156',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('AdaptiveMaxPool2d-157',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveAvgPool2d-158',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveConcatPool2d-159',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 4096, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Flatten-160',
#               OrderedDict([('input_shape', [-1, 4096, 1, 1]),
#                            ('output_shape', [-1, 4096]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-161',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 4096]),
#                            ('trainable', True),
#                            ('nb_params', 8192)])),
#              ('Dropout-162',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 4096]),
#                            ('nb_params', 0)])),
#              ('Linear-163',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 2097664)])),
#              ('ReLU-164',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-165',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Dropout-166',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('Linear-167',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 81]),
#                            ('trainable', True),
#                            ('nb_params', 41553)])),
#              ('LogSoftmax-168',
#               OrderedDict([('input_shape', [-1, 81]),
#                            ('output_shape', [-1, 81]),
#                            ('nb_params', 0)]))])

# %%
# %time log_preds, y = learn.TTA() # (5, 2044, 120), (2044,)
probs = np.mean(np.exp(log_preds),0)
accuracy_np(probs, y), metrics.log_loss(y, probs)
# Out:
# CPU times: user 4min 55s, sys: 1min 12s, total: 6min 7s
# Wall time: 5min 41s
# (0.9915687828781437, 0.01799883377298646)

# %%
learn.save('final')

# %%
learn.load('final')

# %% [markdown]
# ## Analyzing Results
# ### Confusion matrix

# %%
preds = np.argmax(probs, axis=1)
probs = probs[:,1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y, preds)

# %%
plot_confusion_matrix(cm, data.classes, figsize=(15,10))
# Out:
# [[164   0   0 ...   0   0   0]
#  [  0 164   0 ...   0   0   0]
#  [  0   0 164 ...   0   0   0]
#  ...
#  [  0   0   0 ... 164   0   0]
#  [  0   0   0 ...   0 127   0]
#  [  0   0   0 ...   0   0 249]]

# %% [markdown]
# ## Analyzing results: looking at pictures - needs chamnge for multi-class classification !!!

# %% [markdown]
# As well as looking at the overall metrics, it's also a good idea to look at examples of each of:
# 1. A few correct labels at random
# 2. A few incorrect labels at random
# 3. The most correct labels of each class (i.e. those with highest probability that are correct)
# 4. The most incorrect labels of each class (i.e. those with highest probability that are incorrect)
# 5. The most uncertain labels (i.e. those with probability closest to 0.5).

# %%
# This is the label for a val data
data.val_y
# Out:
# array([ 0,  0,  0, ..., 80, 80, 80])

# %%
# from here we know that 'cats' is label 0 and 'dogs' is label 1.
data.classes
# Out:
# ['Apple Braeburn',
#  'Apple Golden 1',
#  'Apple Golden 2',
#  'Apple Golden 3',
#  'Apple Granny Smith',
#  'Apple Red 1',
#  'Apple Red 2',
#  'Apple Red 3',
#  'Apple Red Delicious',
#  'Apple Red Yellow',
#  'Apricot',
#  'Avocado',
#  'Avocado ripe',
#  'Banana',
#  'Banana Red',
#  'Cactus fruit',
#  'Cantaloupe 1',
#  'Cantaloupe 2',
#  'Carambula',
#  'Cherry 1',
#  'Cherry 2',
#  'Cherry Rainier',
#  'Cherry Wax Black',
#  'Cherry Wax Red',
#  'Cherry Wax Yellow',
#  'Clementine',
#  'Cocos',
#  'Dates',
#  'Granadilla',
#  'Grape Pink',
#  'Grape White',
#  'Grape White 2',
#  'Grapefruit Pink',
#  'Grapefruit White',
#  'Guava',
#  'Huckleberry',
#  'Kaki',
#  'Kiwi',
#  'Kumquats',
#  'Lemon',
#  'Lemon Meyer',
#  'Limes',
#  'Lychee',
#  'Mandarine',
#  'Mango',
#  'Maracuja',
#  'Melon Piel de Sapo',
#  'Mulberry',
#  'Nectarine',
#  'Orange',
#  'Papaya',
#  'Passion Fruit',
#  'Peach',
#  'Peach Flat',
#  'Pear',
#  'Pear Abate',
#  'Pear Monster',
#  'Pear Williams',
#  'Pepino',
#  'Physalis',
#  'Physalis with Husk',
#  'Pineapple',
#  'Pineapple Mini',
#  'Pitahaya Red',
#  'Plum',
#  'Pomegranate',
#  'Quince',
#  'Rambutan',
#  'Raspberry',
#  'Salak',
#  'Strawberry',
#  'Strawberry Wedge',
#  'Tamarillo',
#  'Tangelo',
#  'Tomato 1',
#  'Tomato 2',
#  'Tomato 3',
#  'Tomato 4',
#  'Tomato Cherry Red',
#  'Tomato Maroon',
#  'Walnut']

# %%
# this gives prediction for validation set. Predictions are in log scale
log_preds = learn.predict()
log_preds.shape
# Out:
# (13877, 81)

# %%
log_preds[:10]
# Out:
# array([[  0.     , -29.10049, -24.60152, -20.06256, -19.82554, -21.49227, -17.69122, -19.29462, -25.03193,
#         -24.86691, -23.24722, -22.80022, -28.1881 , -29.20416, -25.79212, -27.76098, -30.46218, -34.03637,
#         -30.40435, -18.56312, -18.91047, -30.75306, -22.28787, -20.22838, -28.04598, -26.02109, -27.88529,
#         -31.81856, -22.22111, -26.25791, -31.82851, -28.36923, -23.00796, -24.67913, -33.01192, -30.14097,
#         -23.1659 , -30.46944, -25.04228, -30.18025, -31.59696, -27.77373, -29.18774, -33.19788, -24.97722,
#         -27.82586, -30.16396, -30.00869, -14.61543, -24.02632, -25.6012 , -25.49149, -21.20908, -24.90524,
#         -25.98551, -29.56276, -26.13548, -32.25095, -32.91782, -34.5422 , -30.1937 , -29.66351, -33.80288,
#         -26.6595 , -19.36047, -22.56683, -26.77477, -30.04078, -30.94315, -29.57328, -24.07738, -30.46316,
#         -24.62961, -28.5366 , -22.64137, -26.75757, -25.21447, -22.01975, -23.95547, -24.80668, -26.74158],
#        [ -0.00007, -25.34507, -22.39435, -19.5704 , -19.92249, -17.98083,  -9.63412, -17.62563, -24.48426,
#         -22.61191, -20.85263, -21.88288, -27.5288 , -25.59799, -24.79437, -25.25842, -27.51932, -28.12977,
