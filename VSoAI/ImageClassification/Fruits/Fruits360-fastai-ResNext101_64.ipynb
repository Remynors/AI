# %% [markdown]
# ## Kaggle Fruits 360 Image Classification with Fast.ai

# %% [markdown]
# https://www.kaggle.com/moltean/fruits

# %%
## Check GPU memory availability

# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/45/99/837428d26b47ebd6b66d6e1b180e98ec4a557767a93a81a02ea9d6242611/GPUtil-1.3.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gputil) (1.14.6)
# Building wheels for collected packages: gputil
# done
#   Stored in directory: /root/.cache/pip/wheels/17/0f/04/b79c006972335e35472c0b835ed52bfc0815258d409f560108
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.3.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Collecting humanize
#   Downloading https://files.pythonhosted.org/packages/8c/e0/e512e4ac6d091fc990bbe13f9e0378f34cf6eecd1c6c268c9e598dcf5bb9/humanize-0.5.1.tar.gz
# Building wheels for collected packages: humanize
# done
#   Stored in directory: /root/.cache/pip/wheels/69/86/6c/f8b8593bc273ec4b0c653d3827f7482bb2001a2781a73b7f44
# Successfully built humanize
# Installing collected packages: humanize
# Successfully installed humanize-0.5.1
# Gen RAM Free: 13.0 GB  | Proc size: 139.3 MB
# GPU RAM Free: 11441MB | Used: 0MB | Util   0% | Total 11441MB

# %%
## install and setup Fast.ai v.0.7.0, pytorch and dependencies

#!pip uninstall fastai
# !pip install Pillow==4.1.1
# !pip install "fastai==0.7.0"
# !pip install torchtext==0.2.3
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
import cv2
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
# !apt update && apt install -y libsm6 libxext6

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'
# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch
# !pip install image

# %matplotlib inline
from fastai.imports import *
# Out:
# Collecting Pillow==4.1.1
#   Downloading https://files.pythonhosted.org/packages/36/e5/88b3d60924a3f8476fa74ec086f5fbaba56dd6cee0d82845f883b6b6dd18/Pillow-4.1.1-cp36-cp36m-manylinux1_x86_64.whl (5.7MB)
#     100% |████████████████████████████████| 5.7MB 8.1MB/s
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.1.1) (0.46)
# Installing collected packages: Pillow
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# Successfully installed Pillow-4.1.1
# Collecting fastai==0.7.0
#   Downloading https://files.pythonhosted.org/packages/50/6d/9d0d6e17a78b0598d5e8c49a0d03ffc7ff265ae62eca3e2345fab14edb9b/fastai-0.7.0-py3-none-any.whl (112kB)
#     100% |████████████████████████████████| 122kB 3.7MB/s
# Collecting bcolz (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/5c/4e/23942de9d5c0fb16f10335fa83e52b431bcb8c0d4a8419c9ac206268c279/bcolz-1.2.1.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 15.0MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.22.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.14.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.1.7)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.3)
# Collecting jupyter (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.3.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (5.5.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.4.3.18)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.1.0)
# Collecting isoweek (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/c2/d4/fe7e2637975c476734fcbf53776e650a29680194eb0dd21dbdc020ca92de/isoweek-1.3.3-py2.py3-none-any.whl
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.0.2)
# Collecting html5lib (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/a5/62/bbd2be0e7943ec8504b517e62bab011b4946e1258842bc159e5dfde15b96/html5lib-1.0.1-py2.py3-none-any.whl (117kB)
#     100% |████████████████████████████████| 122kB 28.1MB/s
# Collecting torchtext (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/c6/bc/b28b9efb4653c03e597ed207264eea45862b5260f48e9f010b5068d64db1/torchtext-0.3.1-py3-none-any.whl (62kB)
#     100% |████████████████████████████████| 71kB 24.9MB/s
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.5.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.4.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.13)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.5.3)
# Collecting jedi (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/7a/1a/9bd24a185873b998611c2d8d4fb15cd5e8a879ead36355df7ee53e9111bf/jedi-0.13.1-py2.py3-none-any.whl (177kB)
#     100% |████████████████████████████████| 184kB 28.3MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.1.0)
# Collecting plotnine (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/84/02/b171c828560aea3a5da1efda464230dac3ef4f4834b88e0bd52ad14a08f0/plotnine-0.5.1-py2.py3-none-any.whl (3.6MB)
#     100% |████████████████████████████████| 3.6MB 1.3MB/s
# Collecting graphviz (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/1f/e2/ef2581b5b86625657afd32030f90cf2717456c1d2b711ba074bf007c0f1a/graphviz-0.10.1-py2.py3-none-any.whl
# Collecting sklearn-pandas (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/7e/9c/c94f46b40b86d2c77c46c4c1b858fc66c117b4390665eca28f2e0812db45/sklearn_pandas-1.7.0-py2.py3-none-any.whl
# Collecting widgetsnbextension (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/8a/81/35789a3952afb48238289171728072d26d6e76649ddc8b3588657a2d78c1/widgetsnbextension-3.4.2-py2.py3-none-any.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 16.5MB/s
# Requirement already satisfied: cycler in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.10.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.6.0)
# Collecting torch<0.4 (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/5b/a5/e8b50b55b1abac9f1e3346c4242f1e42a82d368a8442cbd50c532922f6c4/torch-0.3.1-cp36-cp36m-manylinux1_x86_64.whl (496.4MB)
#     100% |████████████████████████████████| 496.4MB 31kB/s
# Requirement already satisfied: Pygments in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.28.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.10.15)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.1.1)
# Collecting feather-format (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/08/55/940b97cc6f19a19f5dab9efef2f68a0ce43a7632f858b272391f0b851a7e/feather-format-0.4.0.tar.gz
# Requirement already satisfied: simplegeneric in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.8.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.2)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.10)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.6.0)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (17.0.0)
# Collecting torchvision (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/ca/0d/f00b2885711e08bd71242ebe7b96561e6f6d01fdb4b9dcf4d37e2e13c5e1/torchvision-0.2.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 23.7MB/s
# Collecting ipywidgets (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/30/9a/a008c7b1183fac9e52066d80a379b3c64eab535bd9d86cdc29a0b766fd82/ipywidgets-7.4.2-py2.py3-none-any.whl (111kB)
#     100% |████████████████████████████████| 112kB 15.5MB/s
# Collecting pandas-summary (from fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/97/55/ea54109a4e7a8e7342bdf23e9382c858224263d984b0d95610568e564f59/pandas_summary-0.0.5-py2.py3-none-any.whl
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.2)
# Collecting qtconsole (from jupyter->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/e0/7a/8aefbc0ed078dec7951ac9a06dcd1869243ecd7bcbce26fa47bf5e469a8f/qtconsole-4.4.3-py2.py3-none-any.whl (113kB)
#     100% |████████████████████████████████| 122kB 30.2MB/s
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.2.2)
# Collecting jupyter-console (from jupyter->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/cb/ee/6374ae8c21b7d0847f9c3722dcdfac986b8e54fa9ad9ea66e1eb6320d2b8/jupyter_console-6.0.0-py2.py3-none-any.whl
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.4.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (40.6.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (4.6.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (1.0.15)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from bleach->fastai==0.7.0) (1.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext->fastai==0.7.0) (2.18.4)
# Collecting parso>=0.3.0 (from jedi->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/09/51/9c48a46334be50c13d25a3afe55fa05c445699304c5ad32619de953a2305/parso-0.3.1-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 28.3MB/s
# Collecting mizani>=0.5.2 (from plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/10/3a/1d1c5563b6aeb5fffda694b70d649a0f728a112b79a66b85a6af4814a643/mizani-0.5.2-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 21.2MB/s
# Collecting descartes>=1.1.0 (from plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/e5/b6/1ed2eb03989ae574584664985367ba70cd9cf8b32ee8cad0e8aaeac819f3/descartes-1.1.0-py3-none-any.whl
# Requirement already satisfied: statsmodels>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.8.0)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.5.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from sklearn-pandas->fastai==0.7.0) (0.19.2)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->fastai==0.7.0) (0.46)
# Collecting pyarrow>=0.4.0 (from feather-format->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/36/94/23135312f97b20d6457294606fb70fad43ef93b7bffe567088ebe3623703/pyarrow-0.11.1-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#     100% |████████████████████████████████| 11.6MB 2.6MB/s
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel->fastai==0.7.0) (5.2.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->fastai==0.7.0) (0.8.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (1.4.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.5.0)
# Requirement already satisfied: mistune>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.8.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (3.0.4)
# Collecting palettable (from mizani>=0.5.2->plotnine->fastai==0.7.0)
#   Downloading https://files.pythonhosted.org/packages/56/8a/84537c0354f0d1f03bf644b71bf8e0a50db9c1294181905721a5f3efbf66/palettable-3.1.1-py2.py3-none-any.whl (77kB)
#     100% |████████████████████████████████| 81kB 22.6MB/s
# Building wheels for collected packages: bcolz, feather-format
# done
#   Stored in directory: /root/.cache/pip/wheels/9f/78/26/fb8c0acb91a100dc8914bf236c4eaa4b207cb876893c40b745
# done
#   Stored in directory: /root/.cache/pip/wheels/85/7d/12/2dfa5c0195f921ac935f5e8f27deada74972edc0ae9988a9c1
# Successfully built bcolz feather-format
# jupyter-console 6.0.0 has requirement prompt-toolkit<2.1.0,>=2.0.0, but you'll have prompt-toolkit 1.0.15 which is incompatible.
# mizani 0.5.2 has requirement pandas>=0.23.4, but you'll have pandas 0.22.0 which is incompatible.
# plotnine 0.5.1 has requirement matplotlib>=3.0.0, but you'll have matplotlib 2.1.2 which is incompatible.
# plotnine 0.5.1 has requirement pandas>=0.23.4, but you'll have pandas 0.22.0 which is incompatible.
# Installing collected packages: bcolz, qtconsole, jupyter-console, widgetsnbextension, ipywidgets, jupyter, isoweek, html5lib, torch, torchtext, parso, jedi, palettable, mizani, descartes, plotnine, graphviz, sklearn-pandas, pyarrow, feather-format, torchvision, pandas-summary, fastai
# Successfully installed bcolz-1.2.1 descartes-1.1.0 fastai-0.7.0 feather-format-0.4.0 graphviz-0.10.1 html5lib-1.0.1 ipywidgets-7.4.2 isoweek-1.3.3 jedi-0.13.1 jupyter-1.0.0 jupyter-console-6.0.0 mizani-0.5.2 palettable-3.1.1 pandas-summary-0.0.5 parso-0.3.1 plotnine-0.5.1 pyarrow-0.11.1 qtconsole-4.4.3 sklearn-pandas-1.7.0 torch-0.3.1 torchtext-0.3.1 torchvision-0.2.1 widgetsnbextension-3.4.2
# Collecting torchtext==0.2.3
#   Downloading https://files.pythonhosted.org/packages/78/90/474d5944d43001a6e72b9aaed5c3e4f77516fbef2317002da2096fd8b5ea/torchtext-0.2.3.tar.gz (42kB)
#     100% |████████████████████████████████| 51kB 1.9MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2018.10.15)
# Building wheels for collected packages: torchtext
# done
#   Stored in directory: /root/.cache/pip/wheels/42/a6/f4/b267328bde6bb680094a0c173e8e5627ccc99543abded97204
# Successfully built torchtext
# Installing collected packages: torchtext
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
# Successfully installed torchtext-0.2.3
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [83.2 kB]
# Hit:2 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  InRelease
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [1,364 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [264 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [6,138 B]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [734 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [119 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [574 kB]
# Fetched 1,944 kB in 3s (605 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 7 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.2-1).
# libxext6 is already the newest version (2:1.3.3-1).
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Collecting image
#   Downloading https://files.pythonhosted.org/packages/0c/ec/51969468a8b87f631cc0e60a6bf1e5f6eec8ef3fd2ee45dc760d5a93b82a/image-1.5.27-py2.py3-none-any.whl
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from image) (4.1.1)
# Collecting django (from image)
#   Downloading https://files.pythonhosted.org/packages/d1/e5/2676be45ea49cfd09a663f289376b3888accd57ff06c953297bfdee1fb08/Django-2.1.3-py3-none-any.whl (7.3MB)
#     100% |████████████████████████████████| 7.3MB 6.1MB/s
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->image) (0.46)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from django->image) (2018.7)
# Installing collected packages: django, image
# Successfully installed django-2.1.3 image-1.5.27

# %%
import sys
sys.version
# Out:
# '3.6.7 (default, Oct 22 2018, 11:32:17) \n[GCC 8.2.0]'

# %%
import torch
print(torch.__version__)
# Out:
# 0.3.0.post4

# %% [markdown]
# It's important that you have a working NVidia GPU set up. The programming framework used to behind the scenes to work with NVidia GPUs is called CUDA. Therefore, you need to ensure the following line returns `True` before you proceed. If you have problems with this, please check the FAQ and ask for help on [the forums](http://forums.fast.ai).

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# In addition, NVidia provides special accelerated functions for deep learning in a package called CuDNN. Although not strictly necessary, it will improve training performance significantly, and is included by default in all supported fastai configurations. Therefore, if the following does not return `True`, you may want to look into why.

# %%
torch.backends.cudnn.enabled
# Out:
# True

# %%
import fastai as fai
from fastai.imports import *

# %%
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Loading Dataset

# %%
DATASET_ZIP_FILE = 'fruits.zip'

# %%
from zipfile import ZipFile
files = os.listdir()
if not DATASET_ZIP_FILE in files:
  
#  !curl --header 'Host: storage.googleapis.com' --user-agent 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:63.0) Gecko/20100101 Firefox/63.0' --header 'Accept: text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8' --header 'Accept-Language: en-US,en;q=0.5' --referer 'https://www.kaggle.com/' --cookie '_ga=GA1.3.597929118.1540370868' --header 'Upgrade-Insecure-Requests: 1' 'https://storage.googleapis.com/kaggle-datasets/5857/94583/fruits.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1543353373&Signature=rfXrXBZSWzulX89wVMZDAe94oaVLEUrANf5DzrxnaezszFEgWrtoWzGeDjVDStAn3jdczeSknwH5uS%2BJ8Q6QJLiEqoFcB2iM0LANrl6cc6RWXynmI0NxIUqhFeL%2BngeQF1eFNivl4aCKBZDsqW7%2BtIPAWyfpcBvXKP0ACgmnJt%2Fb%2BUe7NnLWZ9c353YPK4msQAvM5H5c40kXAzYX9er6XpX7HOTUkY%2FXrVhNhmuiorDFERNHhdzmBHepDJRRhY5x34NXw3z0pk6Rn7aToBh9yqNQ8aQDeekNrBDQky9KahJmupA5DpjdK76vA3jKX29Cw%2FnAdj9w7GyKiIZ1iYtm8g%3D%3D' --output 'fruits.zip'  #The first step is install kaggle
#'''
  # !pip install kaggle
  from google.colab import files
  files.upload()
  # !mkdir -p ~/.kaggle
  # !cp kaggle.json ~/.kaggle/
  #this permissions change avoids a warnong on Kaggle tool startup
  # !chmod 600 ~/.kaggle/kaggle.json  
  # !kaggle datasets download -d moltean/fruits
#'''
  # !ls
  with ZipFile(DATASET_ZIP_FILE, 'r') as zipF:
    zipF.extractall()
    print('UnZip Done')
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.18.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2018.10.15)
# Requirement already satisfied: urllib3<1.23.0,>=1.15 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.2.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.5.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.11.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.6)
# Requirement already satisfied: Unidecode>=0.04.16 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.0.23)
#      <input type="file" id="files-e28879f2-6ff8-4be4-89d5-f0550e1291ad" name="files[]" multiple disabled />
#      <output id="result-e28879f2-6ff8-4be4-89d5-f0550e1291ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading fruits.zip to /content
#  98% 398M/406M [00:09<00:00, 51.5MB/s]
# 100% 406M/406M [00:10<00:00, 42.5MB/s]
# fruits.zip  kaggle.json  sample_data
# UnZip Done

# %%
#lets see the imported files from kaggle dataset
# !ls -l
# Out:
# total 415344
# drwxr-xr-x 6 root root      4096 Nov 25 13:32 fruits-360
# -rw-r--r-- 1 root root 425299224 Nov 25 13:31 fruits.zip
# -rw-r--r-- 1 root root        62 Nov 25 13:31 kaggle.json
# drwxr-xr-x 2 root root      4096 Nov 20 18:17 sample_data

# %%
data_dir = 'fruits-360/'
PATH = data_dir

train_dir = 'Training'
val_dir = 'Test'

# %%
# !ls '{data_dir}'
# Out:
# LICENSE  papers  readme.md  Test  test-multiple_fruits	Training

# %% [markdown]
# # Model Architecture Selection

# %%
## CHOOSE ARCHITECTURE AND IMAGE SIZE

#arch = vgg16
#arch = resnet34
#arch = resnext50
arch = resnext101_64
#arch = inceptionresnetv2
#arch = inceptionv4
sz = 100
bs = 16

# %% [markdown]
# ## First look at pictures

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Our library will assume that you have *train* and *valid* directories. It also assumes that each dir will have subdirs for each class you wish to recognize

# %%
files = os.listdir(f'{data_dir}{train_dir}/Banana')[:5]
files
# Out:
# ['91_100.jpg', '0_100.jpg', '155_100.jpg', 'r_190_100.jpg', 'r_22_100.jpg']

# %%
img = plt.imread(f'{data_dir}{train_dir}/Banana/{files[3]}')
plt.imshow(img);

# %% [markdown]
# Here is how the raw data looks like

# %%
# fast.ai functions to initialize transform and data loader objects

tfms=tfms_from_model(arch, sz)
data = ImageClassifierData.from_paths(PATH, trn_name = train_dir, val_name=val_dir, tfms=tfms, bs=bs)

# %%
#pick first image just for viewing
pic = PATH + data.trn_ds.fnames[0]; pic
# Out:
# 'fruits-360/Training/Apple Braeburn/0_100.jpg'

# %%
img = PIL.Image.open(pic); img
#img = PIL.Image.open(f'{pic}');
#img = plt.imread(pic)
#plt.imshow(img);
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F3C5EE4AB38>

# %%
# create python data dictionary {}, path/file and image size(x,y)
# ps very long processing time
e_d = {k: PIL.Image.open(PATH + k).size for k in data.trn_ds.fnames}

# %%
e_d
# Out:
# {'Training/Apple Braeburn/0_100.jpg': (100, 100),
#  'Training/Apple Braeburn/155_100.jpg': (100, 100),
#  'Training/Apple Braeburn/r
100.jpg': (100, 100),
#  'Training/Apple Golden 1/r_178_100.jpg': (100, 100),
#  'Training/Apple Golden 1/197_100.jpg': (100, 100),
#  'Training/Apple Golden 1/163_100.jpg': (100, 100),
#  'Training/Apple Golden 1/131_100.jpg': (100, 100),
#  'Training/Apple Golden 1/183_100.jpg': (100, 100),
#  'Training/Apple Golden 1/r_233_100.jpg': (100, 100),
#  'Training/Apple Golden 1/r_183_100.jpg': (100, 100),
#  'Training/Apple Golden 2/0_100.jpg': (100, 100),
#  'Training/Apple Golden 2/155_100.jpg': (100, 100),
#  'Training/Apple Golden 2/r_190_100.jpg': (100, 100),
#  'Training/Apple Golden 2/r_22_100.jpg': (100, 100),
#  'Training/Apple Golden 2/r_198_100.jpg': (100, 100),
#  'Training/Apple Golden 2/237_100.jpg': (100, 100),
#  'Training/Apple Golden 2/r_116_100.jpg': (100, 100),
#  'Training/Apple Golden 2/160_100.jpg': (100, 100),
#  'Training/Apple Golden 2/291_100.jpg': (100, 100),
#  'Training/Apple Golden 2/217_100.jpg': (100, 100),
#  'Training/Apple Golden 2/211_100.jpg': (100, 100),
#  'Training/Apple Golden 2/124_100.jpg': (100, 100),
#  'Training/Apple Golden 2/252_100.jpg': (100, 100),
#  'Training/Apple Golden 2/r_179_100.jpg': (100, 100),
#  'Training/Apple Golden 2/r_272_100.jpg': (100, 100),
#  'Training/Apple Golden 2/r_167_100.jpg': (100, 100),
#  ...}

# %%
#!pip3 list

# %%
'''
#redefine zip, after ZipFile breaks it
def zip(*iterables):
    # zip('ABCD', 'xy') --> Ax By
    sentinel = object()
    iterators = [iter(it) for it in iterables]
    while iterators:
        result = []
        for it in iterators:
            elem = next(it, sentinel)
            if elem is sentinel:
                return
            result.append(elem)
        yield tuple(result)
'''

# %%
import os
row_sz, col_sz = list(zip(*e_d.values()))

# %%
row_sz[:5]
# Out:
# (100, 100, 100, 100, 100)

# %%
row_sz = np.array(row_sz); col_sz = np.array(col_sz)

# %%
col_sz[:5]
# Out:
# array([100, 100, 100, 100, 100])

# %%
# find few row/col ratios
row_sz[:5]/col_sz[:5]
# Out:
# array([1., 1., 1., 1., 1.])

# %%
print(min(row_sz), max(row_sz))
# Out:
# 100 100

# %%
plt.hist(row_sz);

# %%
#plt.hist(row_sz[row_sz < 800])

# %%
# again, list total number of classes, and list them all
# os.list dir sorting depends on OS dependent file indexing, so leaving it as it is

classes = os.listdir(f'{data_dir}{train_dir}')
classes.sort()
print("Class Total Count: ", len(classes))
print(classes)
# Out:
# Class Total Count:  81
# ['Apple Braeburn', 'Apple Golden 1', 'Apple Golden 2', 'Apple Golden 3', 'Apple Granny Smith', 'Apple Red 1', 'Apple Red 2', 'Apple Red 3', 'Apple Red Delicious', 'Apple Red Yellow', 'Apricot', 'Avocado', 'Avocado ripe', 'Banana', 'Banana Red', 'Cactus fruit', 'Cantaloupe 1', 'Cantaloupe 2', 'Carambula', 'Cherry 1', 'Cherry 2', 'Cherry Rainier', 'Cherry Wax Black', 'Cherry Wax Red', 'Cherry Wax Yellow', 'Clementine', 'Cocos', 'Dates', 'Granadilla', 'Grape Pink', 'Grape White', 'Grape White 2', 'Grapefruit Pink', 'Grapefruit White', 'Guava', 'Huckleberry', 'Kaki', 'Kiwi', 'Kumquats', 'Lemon', 'Lemon Meyer', 'Limes', 'Lychee', 'Mandarine', 'Mango', 'Maracuja', 'Melon Piel de Sapo', 'Mulberry', 'Nectarine', 'Orange', 'Papaya', 'Passion Fruit', 'Peach', 'Peach Flat', 'Pear', 'Pear Abate', 'Pear Monster', 'Pear Williams', 'Pepino', 'Physalis', 'Physalis with Husk', 'Pineapple', 'Pineapple Mini', 'Pitahaya Red', 'Plum', 'Pomegranate', 'Quince', 'Rambutan', 'Raspberry', 'Salak', 'Strawberry', 'Strawberry Wedge', 'Tamarillo', 'Tangelo', 'Tomato 1', 'Tomato 2', 'Tomato 3', 'Tomato 4', 'Tomato Cherry Red', 'Tomato Maroon', 'Walnut']

# %%
# parse all classes and assemble python list object []
# each list element will contain array of files names of a class

all_images_class = [os.listdir(f'{data_dir}{train_dir}/'+c) for c in classes]
#int_to_classes = {i:classes[i] for i in range(len(classes))}
#classes_to_int = {classes[i]:i for i in range(len(classes))}
print("Classes: ",len(all_images_class) )
# Out:
# Classes:  81

# %%
# create python data dictionary {}, with key="text", and value as length(of size) of containing list object array (1D)
# gives histogram like file count for each class
dataDict= {"n_images": [len(x) for x in all_images_class]}
print("file count in each class: ",dataDict)
trainFiles = 0
for x in all_images_class:
  trainFiles = trainFiles+len(x)
print(" Total Train Files: ", trainFiles)
# Out:
# file count in each class:  {'n_images': [492, 492, 492, 481, 492, 492, 492, 429, 490, 492, 492, 427, 491, 490, 490, 490, 492, 492, 490, 492, 738, 738, 492, 492, 492, 490, 490, 490, 490, 492, 490, 490, 490, 492, 490, 490, 490, 466, 490, 492, 490, 490, 490, 490, 490, 490, 738, 492, 492, 479, 492, 490, 492, 492, 492, 490, 490, 490, 490, 492, 492, 490, 493, 490, 447, 492, 490, 492, 490, 490, 492, 738, 490, 490, 738, 672, 738, 479, 492, 367, 735]}
#  Total Train Files:  41322

# %%
# assemble panda Dataframe {class pandas.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)}
# Train Data set
df = pd.DataFrame(dataDict, index=classes)
df.index.name = "Fruits"

# %%
df.plot(kind="bar", grid=True,figsize=(20,8))

# %% [markdown]
# ##Review: easy steps to train a world-class image classifier
#
#  *   precompute=True
#  *   Use lr_find() to find highest learning rate where loss is still clearly improving
#  *   Train last layer from precomputed activations for 1-2 epochs
#  *   Train last layer with data augmentation (i.e. precompute=False) for 2-3 epochs with cycle_len=1
#  *   Unfreeze all layers
#  *   Set earlier layers to 3x-10x lower learning rate than next higher layer
#  *   Use lr_find() again
#  *   Train full network with cycle_mult=2 until over-fitting

# %%
#function to plot training and validation loss
def plot_ep_vals(ep_vals):
    plt.ylabel("loss")
    plt.xlabel("epoch")
    epochs = ep_vals.keys()
    plt.xticks(np.asarray(list(epochs)))
    trn_losses = [item[0] for item in list(ep_vals.values())]
    val_losses = [item[1] for item in list(ep_vals.values())]
    plt.plot(epochs, trn_losses, c='b', label='train')
    plt.plot(epochs, val_losses, c='r', label='validation')
    plt.legend(loc='upper left')

# %% [markdown]
# ## Initial Model

# %%
## download fast.ai pretrained network weigths, and copy to local directory

# !wget http://files.fast.ai/models/weights.tgz
# !tar -xvzf weights.tgz
# Out:
# --2018-11-25 13:33:03--  http://files.fast.ai/models/weights.tgz
# Resolving files.fast.ai (files.fast.ai)... 67.205.15.147
# Connecting to files.fast.ai (files.fast.ai)|67.205.15.147|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1195411318 (1.1G) [text/plain]
# Saving to: ‘weights.tgz’
#
# weights.tgz         100%[===================>]   1.11G  15.9MB/s    in 74s
#
# 2018-11-25 13:34:17 (15.5 MB/s) - ‘weights.tgz’ saved [1195411318/1195411318]
#
# weights/
# weights/wrn_50_2f.pth
# weights/resnext_101_32x4d.pth
# weights/resnext_101_64x4d.pth
# weights/inceptionresnetv2-d579a627.pth
# weights/inceptionv4-97ef9c30.pth
# weights/resnext_50_32x4d.pth

# %%
# !ls '/usr/local/lib/python3.6/dist-packages/fastai'
# !cp -R weights '/usr/local/lib/python3.6/dist-packages/fastai/'
# Out:
# adaptive_softmax.py  initializers.py	  metrics.py	sgdr.py
# column_data.py	     __init__.py	  model.py	structured.py
# conv_learner.py      io.py		  models	swa.py
# core.py		     layer_optimizer.py   nlp.py	text.py
# dataloader.py	     layers.py		  plots.py	torch_imports.py
# dataset.py	     learner.py		  __pycache__	transforms_pil.py
# executors.py	     lm_rnn.py		  rnn_reg.py	transforms.py
# fp16.py		     losses.py		  rnn_train.py	utils.py
# imports.py	     lsuv_initializer.py  set_spawn.py

# %%
# Get initial predictions on pre-trained network, just training last layers
# model trained on ImageNet (1.2 million images and 1000 classes) as a starting point.
'''
## Fast.ai ConvLearner
As we can see the ConvLearner.pretrained method changes the last few layers of the input model.
Specifically it changes the AvgPool2d with AdaptiveConcatPool2d, Flattens it, 
Adds to linear layers with batch norms and relu, adds dropout, and finally puts a LogSoftmax layer.

The reason for using Adaptive Pooling layers is that it allows the model to use any image size 
rather than being restricted to a constant size of say 224 x 224. 
What Adaptive Pooling layer does is it to specify the output size rather than the kernel size.
'''

learn = ConvLearner.pretrained(arch, data)
# %time learn.fit(0.001, 3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.139446   0.128024   0.973265
#     1      0.066914   0.080624   0.978381
#     2      0.048407   0.067787   0.980471
#
# CPU times: user 21min 35s, sys: 7min, total: 28min 35s
# Wall time: 27min 24s
# [array([0.06779]), 0.9804712834186063]

# %%
#?ConvLearner   # ? short function description
#??ConvLearner   # ?? full function source

# %%
#??ConvLearner.pretrained

# %%
#??ConvLearner.from_model_data

# %%
learn.model
# Out:
# Sequential(
#   (0): Conv2d (3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (2): ReLU()
#   (3): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#   (4): Sequential(
#     (0): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Sequential(
#           (0): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#   )
#   (5): Sequential(
#     (0): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Sequential(
#           (0): Conv2d (256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (3): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#   )
#   (6): Sequential(
#     (0): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Sequential(
#           (0): Conv2d (512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (3): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (4): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (5): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (6): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (7): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (8): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (9): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (10): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (11): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (12): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (13): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (14): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (15): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (16): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (17): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (18): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (19): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (20): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (21): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (22): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#   )
#   (7): Sequential(
#     (0): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Sequential(
#           (0): Conv2d (1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): LambdaMap(
#         (0): Sequential(
#           (0): Sequential(
#             (0): Conv2d (2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#             (2): ReLU()
#             (3): Conv2d (2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#             (5): ReLU()
#           )
#           (1): Conv2d (2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#         )
#         (1): Lambda(
#         )
#       )
#       (1): LambdaReduce(
#       )
#       (2): ReLU()
#     )
#   )
#   (8): AdaptiveConcatPool2d(
#     (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#     (mp): AdaptiveMaxPool2d(output_size=(1, 1))
#   )
#   (9): Flatten(
#   )
#   (10): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True)
#   (11): Dropout(p=0.25)
#   (12): Linear(in_features=4096, out_features=512)
#   (13): ReLU()
#   (14): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True)
#   (15): Dropout(p=0.5)
#   (16): Linear(in_features=512, out_features=81)
#   (17): LogSoftmax()
# )

# %%
learn.sched.plot_loss()

# %%
# error for some reason ???
'''
fig,ax = plt.subplots(2,1,figsize=(8,12))
ax[0].plot(list(range(95)),learn.sched.val_losses, label='Validation loss')
ax[0].plot(list(range(95)),[learn.sched.losses[i] for i in range(97,95*98,98)], label='Training loss')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].legend(loc='upper right')
ax[1].plot(list(range(95)),learn.sched.rec_metrics)
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
'''
# Out:
# "\nfig,ax = plt.subplots(2,1,figsize=(8,12))\nax[0].plot(list(range(95)),learn.sched.val_losses, label='Validation loss')\nax[0].plot(list(range(95)),[learn.sched.losses[i] for i in range(97,95*98,98)], label='Training loss')\nax[0].set_xlabel('Epoch')\nax[0].set_ylabel('Loss')\nax[0].legend(loc='upper right')\nax[1].plot(list(range(95)),learn.sched.rec_metrics)\nax[1].set_xlabel('Epoch')\nax[1].set_ylabel('Accuracy')\n"

# %% [markdown]
# ### Choosing a learning rate
# The *learning rate* determines how quickly or how slowly you want to update the *weights* (or *parameters*). Learning rate is one of the most difficult parameters to set, because it significantly affects model performance.
#
# The method `learn.lr_find()` helps you find an optimal learning rate. It uses the technique developed in the 2015 paper [Cyclical Learning Rates for Training Neural Networks](http://arxiv.org/abs/1506.01186), where we simply keep increasing the learning rate from a very small value, until the loss stops decreasing. We can plot the learning rate across batches to see what this looks like.
#
# We first create a new learner, since we want to know how to set the learning rate for a new (untrained) model.

# %%
lrf=learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1, style=ProgressStyle(description_width='initial…
#  55%|█████▌    | 1432/2583 [03:50<02:53,  6.62it/s, loss=0.158]

# %%
# Our learn object contains an attribute sched that contains our learning rate scheduler, and has some convenient plotting functionality including this one:
learn.sched.plot_lr()

# %%
learn.sched.plot()

# %%
lrate = 0.002

# %% [markdown]
# The loss is still clearly improving at lr=0.002, so that's what we use. Note that the optimal learning rate can change as we train the model, so you may want to re-run this function from time to time.

# %% [markdown]
# ### Augment data set
# If you try training for more epochs, you'll notice that we start to overfit, which means that our model is learning to recognize the specific images in the training set, rather than generalizing such that we also get good results on the validation set. One way to fix this is to effectively create more data, through data augmentation. This refers to randomly changing the images in ways that shouldn't impact their interpretation, such as horizontal flipping, zooming, and rotating.
#
# We can do this by passing aug_tfms (augmentation transforms) to tfms_from_model, with a list of functions to apply that randomly change the image however we wish. For photos that are largely taken from the side (e.g. most photos of dogs and cats, as opposed to photos taken from the top down, such as satellite imagery) we can use the pre-defined list of functions transforms_side_on. We can also specify random zooming of images up to specified scale by adding the max_zoom parameter.

# %%
from sklearn import metrics

# %%
def get_data(arch, sz, bs):
    tfms = tfms_from_model(arch, sz, aug_tfms=transforms_top_down, max_zoom=1.05)
    data = ImageClassifierData.from_paths(PATH, trn_name = train_dir, val_name=val_dir, tfms=tfms, bs=bs)
    return data

# %%
#??tfms_from_model
#??ConvLearner

# %%
# start with smaller image size (larger batch), e.g. 32, 64,  100
sz = 32
bs = 32

# %%
data = get_data(arch, sz, bs)

# %%
def get_augs():
    x,_ = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[1]

# %%
# plot augmented sample image
ims = np.stack([get_augs() for i in range(6)])
plots(ims, rows=2)

# %%
learn = ConvLearner.pretrained(arch, data)

# %%
# cycle_len - learning rate annealing used by stochastic gradient descent with restarts (SGDR),
# %time vals_s2s, ep_vals_s2s = learn.fit(lrate, 3, cycle_len=1, cycle_mult=2, get_ep_vals=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.565212   0.367422   0.911508
#     1      0.301415   0.192304   0.94127
#     2      0.24229    0.171655   0.947683
#     3      0.20538    0.126074   0.960871
#     4      0.146803   0.113141   0.961879
#     5      0.137365   0.102193   0.964906
#     6      0.137735   0.102385   0.965122
# CPU times: user 25min 14s, sys: 7min 38s, total: 32min 53s
# Wall time: 29min 2s

# %% [markdown]
# What is that cycle_len parameter? What we've done here is used a technique called stochastic gradient descent with restarts (SGDR), a variant of learning rate annealing, which gradually decreases the learning rate as training progresses. This is helpful because as we get closer to the optimal weights, we want to take smaller steps.
#
# However, we may find ourselves in a part of the weight space that isn't very resilient - that is, small changes to the weights may result in big changes to the loss. We want to encourage our model to find parts of the weight space that are both accurate and stable. Therefore, from time to time we increase the learning rate (this is the 'restarts' in 'SGDR'), which will force the model to jump to a different part of the weight space if the current area is "spikey". Here's a picture of how that might look if we reset the learning rates 3 times (in this paper they call it a "cyclic LR schedule"):
#
# (From the paper [Snapshot Ensembles](https://arxiv.org/abs/1704.00109)).
#
# The number of epochs between resetting the learning rate is set by cycle_len, and the number of times this happens is refered to as the number of cycles, and is what we're actually passing as the 2nd parameter to fit(). So here's what our actual learning rates looked like:

# %%
# if Validation loss is much lower than training loss. This is a sign of underfitting. Cycle_len=1 may be too short. Let's set cycle_mult=2 to find better parameter.
# When you are under fitting, it means cycle_len=1 is too short (learning rate is getting reset before it had the chance to zoom in properly).

# in our case we are skipping this
# learn = ConvLearner.pretrained(arch, data)
# learn.fit(1e-1, 3, cycle_len=1, cycle_mult=2) # 1+2+4 = 7 epochs

# %%
learn.sched.plot_loss()

# %%
# plot training and validation loss
plot_ep_vals(ep_vals_s2s)

# %%
learn.sched.plot_lr()

# %%
learn.save('32_pre')

# %%
learn.load('32_pre')

# %% [markdown]
# ###Fine-tuning and differential learning rate annealing
# Now that we have a good final layer trained, we can try fine-tuning the other layers. To tell the learner that we want to unfreeze the remaining layers, just call (surprise surprise!) unfreeze().

# %%
learn.unfreeze()
# keep batch normalization moving avg not be updated. Very important!!!
#learn.ns_freeze(True)

# %% [markdown]
# ote that the other layers have already been trained to recognize imagenet photos (whereas our final layers where randomly initialized), so we want to be careful of not destroying the carefully tuned weights that are already there.
#
# Generally speaking, the earlier layers (as we've seen) have more general-purpose features. Therefore we would expect them to need less fine-tuning for new datasets. For this reason we will use different learning rates for different layers: the first few layers will be at 1e-4, the middle layers at 1e-3, and our FC layers we'll leave at 1e-2 as before. We refer to this as differential learning rates, although there's no standard name for this techique in the literature that we're aware of.

# %%
lr=np.array([lrate/100, lrate/10, lrate])
% time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.384133   0.242044   0.927146
#     1      0.248266   0.123055   0.953664
#     2      0.177898   0.134048   0.942999
#     3      0.170239   0.157058   0.940909
#     4      0.158699   0.105688   0.959501
#     5      0.170935   0.157827   0.94372
#     6      0.119793   0.088744   0.965843
# CPU times: user 56min 11s, sys: 19min 10s, total: 1h 15min 21s
# Wall time: 1h 11min 36s

# %%
#Another trick we've used here is adding the cycle_mult parameter. Take a look at the following chart, and see if you can figure out what the parameter is doing:
learn.sched.plot_lr()

# %% [markdown]
# Note that's what being plotted above is the learning rate of the final layers. The learning rates of the earlier layers are fixed at the same multiples of the final layer rates as we initially requested (i.e. the first layers have 100x smaller, and middle layers 10x smaller learning rates, since we set lr=np.array([1e-4,1e-3,1e-2]).

# %%
learn.sched.plot_loss()

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.save('32f_all')

# %%
learn.load('32f_all')

# %% [markdown]
# ###Increase image size

# %%
sz = 64
bs = 16

# %%
data = get_data(arch, sz, bs)
learn.set_data(data)

# %%
learn.freeze()
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.475243   0.351585   0.912949
#     1      0.329737   0.275333   0.922894
#     2      0.27033    0.262694   0.927506
#     3      0.283111   0.213966   0.936153
#     4      0.22338    0.194702   0.940621
#     5      0.18876    0.181171   0.949341
#     6      0.168886   0.186727   0.942783
# CPU times: user 47min, sys: 13min 51s, total: 1h 51s
# Wall time: 56min 28s

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.unfreeze()
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.121934   1.42277    0.937811
#     1      0.060184   0.578142   0.959285
#     2      0.045303   0.792402   0.944296
#     3      0.028924   2.566347   0.936153
#     4      0.036298   1.810977   0.954313
#     5      0.020526   3.320951   0.934568
#     6      0.023042   0.897751   0.958276
# CPU times: user 1h 58min 25s, sys: 40min 36s, total: 2h 39min 2s
# Wall time: 2h 35min 19s

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.save(f'{sz}')

# %%
learn.load(f'{sz}')

# %%
sz = 100
bs = 16

# %%
data = get_data(arch, sz, bs)
learn.set_data(data)

# %%
learn.freeze()
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.063988   0.120852   0.976148
#     1      0.059908   0.102764   0.982057
#     2      0.040643   0.07973    0.985804
#     3      0.031645   0.083438   0.980615
#     4      0.029495   0.062259   0.986452
#     5      0.026645   0.05297    0.988398
#     6      0.024792   0.057085   0.987822
# CPU times: user 55min 30s, sys: 16min 25s, total: 1h 11min 55s
# Wall time: 1h 6min 57s

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.unfreeze()
# %time vals_s2s, ep_vals_s2s = learn.fit(lr, 3, cycle_len=1, cycle_mult=2, get_ep_vals=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.021813   0.100119   0.982993
#     1      0.023707   0.186073   0.974995
#     2      0.017317   0.085017   0.984218
#     3      0.016736   0.435839   0.965482
#     4      0.017717   0.135023   0.978454
#     5      0.008754   0.282293   0.973409
#     6      0.012194   0.024457   0.991281
# CPU times: user 2h 31min 43s, sys: 45min 24s, total: 3h 17min 7s
# Wall time: 3h 12min 38s

# %%
plot_ep_vals(ep_vals_s2s)

# %%
learn.save(f'{sz}')

# %%
learn.load(f'{sz}')

# %% [markdown]
# ###Final Layer fitting with TTA

# %%
# frezzing all early layers, and training few more epochs on last layer
learn.freeze()

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 100, 100]),
#                            ('output_shape', [-1, 64, 50, 50]),
#                            ('trainable', True),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 50, 50]),
#                            ('output_shape', [-1, 64, 50, 50]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 50, 50]),
#                            ('output_shape', [-1, 64, 50, 50]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 50, 50]),
#                            ('output_shape', [-1, 64, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 16384)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 9216)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-11',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-12',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('Conv2d-13',
#               OrderedDict([('input_shape', [-1, 64, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 16384)])),
#              ('BatchNorm2d-14',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-15',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-16',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-17',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-18',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 9216)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-24',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-25',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-26',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-27',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 9216)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 256, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-34',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 512, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-35',
#               OrderedDict([('input_shape', [-1, 512, 25, 25]),
#                            ('output_shape', [-1, 512, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-36',
#               OrderedDict([('input_shape', [-1, 512, 25, 25]),
#                            ('output_shape', [-1, 512, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-37',
#               OrderedDict([('input_shape', [-1, 512, 25, 25]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-38',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-39',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Conv2d-42',
#               OrderedDict([('input_shape', [-1, 256, 25, 25]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-43',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-44',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-45',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-46',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-47',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-48',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-49',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-50',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-56',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-57',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-58',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-59',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-66',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-67',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-68',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-69',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-70',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-71',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 512, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-72',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 1024, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-73',
#               OrderedDict([('input_shape', [-1, 1024, 13, 13]),
#                            ('output_shape', [-1, 1024, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 1024, 13, 13]),
#                            ('output_shape', [-1, 1024, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-75',
#               OrderedDict([('input_shape', [-1, 1024, 13, 13]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-76',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-77',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-78',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-79',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('Conv2d-80',
#               OrderedDict([('input_shape', [-1, 512, 13, 13]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-81',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-82',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-83',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-84',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-85',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-86',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-87',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-88',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-89',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-90',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-91',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-92',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-93',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-94',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-95',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-96',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-97',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-98',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-99',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-100',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-101',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-102',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-103',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-104',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-105',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-106',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-107',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-108',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-109',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-110',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-111',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-112',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-113',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-114',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-115',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-116',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-117',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-118',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-119',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-120',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-121',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-122',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-123',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-124',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-125',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-126',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-127',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-128',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-129',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-130',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-131',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-132',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-133',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-134',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-135',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-136',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-137',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-138',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-139',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-140',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-141',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-142',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-143',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-144',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-145',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-146',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-147',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-148',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-149',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-150',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-151',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-152',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-153',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-154',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-155',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-156',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-157',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-158',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-159',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-160',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-161',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-162',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-163',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-164',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-165',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-166',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-167',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-168',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-169',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-170',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-171',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-172',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-173',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-174',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-175',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-176',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-177',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-178',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-179',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-180',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-181',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-182',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-183',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-184',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-185',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-186',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-187',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-188',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-189',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-190',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-191',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-192',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-193',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-194',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-195',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-196',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-197',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-198',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-199',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-200',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-201',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-202',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-203',
# ...
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-254',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-255',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-256',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-257',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-258',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-259',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-260',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-261',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-262',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-263',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-264',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-265',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-266',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-267',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-268',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-269',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-270',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-271',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-272',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-273',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-274',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-275',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-276',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-277',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-278',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-279',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-280',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 1024, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-281',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 2048, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-282',
#               OrderedDict([('input_shape', [-1, 2048, 7, 7]),
#                            ('output_shape', [-1, 2048, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-283',
#               OrderedDict([('input_shape', [-1, 2048, 7, 7]),
#                            ('output_shape', [-1, 2048, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-284',
#               OrderedDict([('input_shape', [-1, 2048, 7, 7]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-285',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-286',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-287',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4194304)])),
#              ('BatchNorm2d-288',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('Conv2d-289',
#               OrderedDict([('input_shape', [-1, 1024, 7, 7]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-290',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-291',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-292',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4194304)])),
#              ('BatchNorm2d-293',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-294',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-295',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-296',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-297',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-298',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4194304)])),
#              ('BatchNorm2d-299',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-300',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-301',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4194304)])),
#              ('BatchNorm2d-302',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-303',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-304',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-305',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-306',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-307',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4194304)])),
#              ('BatchNorm2d-308',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-309',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 4, 4]),
#                            ('nb_params', 0)])),
#              ('AdaptiveMaxPool2d-310',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveAvgPool2d-311',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveConcatPool2d-312',
#               OrderedDict([('input_shape', [-1, 2048, 4, 4]),
#                            ('output_shape', [-1, 4096, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Flatten-313',
#               OrderedDict([('input_shape', [-1, 4096, 1, 1]),
#                            ('output_shape', [-1, 4096]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-314',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 4096]),
#                            ('trainable', True),
#                            ('nb_params', 8192)])),
#              ('Dropout-315',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 4096]),
#                            ('nb_params', 0)])),
#              ('Linear-316',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 2097664)])),
#              ('ReLU-317',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-318',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Dropout-319',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('Linear-320',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 81]),
#                            ('trainable', True),
#                            ('nb_params', 41553)])),
#              ('LogSoftmax-321',
#               OrderedDict([('input_shape', [-1, 81]),
#                            ('output_shape', [-1, 81]),
#                            ('nb_params', 0)]))])

# %%
# %time log_preds, y = learn.TTA() # (5, 2044, 120), (2044,)
probs = np.mean(np.exp(log_preds),0)
accuracy_np(probs, y), metrics.log_loss(y, probs)
# Out:
# CPU times: user 9min 36s, sys: 3min 1s, total: 12min 37s
# Wall time: 11min 28s
# (0.9914246595085393, 0.019654419359387457)

# %%
learn.save('final')

# %%
learn.load('final')

# %% [markdown]
# ## Analyzing Results
# ### Confusion matrix

# %%
preds = np.argmax(probs, axis=1)
probs = probs[:,1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y, preds)

# %%
plot_confusion_matrix(cm, data.classes, figsize=(15,10))
# Out:
# [[164   0   0 ...   0   0   0]
#  [  0 163   0 ...   0   0   0]
#  [  0   0 164 ...   0   0   0]
#  ...
#  [  0   0   0 ... 164   0   0]
#  [  0   0   0 ...   0 127   0]
#  [  0   0   0 ...   0   0 249]]

# %% [markdown]
# ## Analyzing results: looking at pictures - needs chamnge for multi-class classification !!!

# %% [markdown]
# As well as looking at the overall metrics, it's also a good idea to look at examples of each of:
# 1. A few correct labels at random
# 2. A few incorrect labels at random
# 3. The most correct labels of each class (i.e. those with highest probability that are correct)
# 4. The most incorrect labels of each class (i.e. those with highest probability that are incorrect)
# 5. The most uncertain labels (i.e. those with probability closest to 0.5).

# %%
# This is the label for a val data
data.val_y
# Out:
# array([ 0,  0,  0, ..., 80, 80, 80])

# %%
# from here we know that 'cats' is label 0 and 'dogs' is label 1.
data.classes
# Out:
# ['Apple Braeburn',
#  'Apple Golden 1',
#  'Apple Golden 2',
#  'Apple Golden 3',
#  'Apple Granny Smith',
#  'Apple Red 1',
#  'Apple Red 2',
#  'Apple Red 3',
#  'Apple Red Delicious',
#  'Apple Red Yellow',
#  'Apricot',
#  'Avocado',
#  'Avocado ripe',
#  'Banana',
#  'Banana Red',
#  'Cactus fruit',
#  'Cantaloupe 1',
#  'Cantaloupe 2',
#  'Carambula',
#  'Cherry 1',
#  'Cherry 2',
#  'Cherry Rainier',
#  'Cherry Wax Black',
#  'Cherry Wax Red',
#  'Cherry Wax Yellow',
#  'Clementine',
#  'Cocos',
#  'Dates',
#  'Granadilla',
#  'Grape Pink',
#  'Grape White',
#  'Grape White 2',
#  'Grapefruit Pink',
#  'Grapefruit White',
#  'Guava',
#  'Huckleberry',
#  'Kaki',
#  'Kiwi',
#  'Kumquats',
#  'Lemon',
#  'Lemon Meyer',
#  'Limes',
#  'Lychee',
#  'Mandarine',
#  'Mango',
#  'Maracuja',
#  'Melon Piel de Sapo',
#  'Mulberry',
#  'Nectarine',
#  'Orange',
#  'Papaya',
#  'Passion Fruit',
#  'Peach',
#  'Peach Flat',
#  'Pear',
#  'Pear Abate',
#  'Pear Monster',
#  'Pear Williams',
#  'Pepino',
#  'Physalis',
#  'Physalis with Husk',
#  'Pineapple',
#  'Pineapple Mini',
#  'Pitahaya Red',
#  'Plum',
#  'Pomegranate',
#  'Quince',
#  'Rambutan',
#  'Raspberry',
#  'Salak',
#  'Strawberry',
#  'Strawberry Wedge',
#  'Tamarillo',
#  'Tangelo',
#  'Tomato 1',
#  'Tomato 2',
#  'Tomato 3',
#  'Tomato 4',
#  'Tomato Cherry Red',
#  'Tomato Maroon',
#  'Walnut']

# %%
# this gives prediction for validation set. Predictions are in log scale
log_preds = learn.predict()
log_preds.shape
# Out:
# (13877, 81)

# %%
log_preds[:10]
# Out:
# array([[ -0.00001, -27.06276, -24.88347, -19.01495, -18.57803, -15.71215, -14.84485, -15.04257, -22.03933,
#         -20.81606, -19.53082, -19.75203, -25.89498, -27.44152, -22.302  , -22.15962, -30.15969, -31.22543,
#         -28.34405, -14.18097, -13.24461, -26.11352, -22.66618, -15.56036, -22.52958, -22.50083, -21.26328,
#        [ -0.00004, -27.92164, -25.75997, -17.7839 , -18.45166, -16.64734, -14.24527, -11.79162, -21.44584,
#         -18.69398, -18.49439, -17.82339, -23.91618, -25.66088, -24.73222, -21.88662, -27.19032, -29.50776,
#         -27.44152, -15.6259 , -13.55695, -23.99337, -21.35456, -15.29231, -21.43232, -20.77112, -21.72019,
#         -26.82964, -19.63102, -20.39057, -27.75179, -25.38715, -19.786  , -23.9217 , -28.18137, -24.97149,
#         -20.09089, -24.84565, -23.77829, -25.22254, -25.18236, -25.37146, -23.42529, -26.86939, -18.45893,
#         -27.00026, -24.44268, -25.3536 , -10.48717, -18.98798, -20.70244, -26.70837, -20.09023, -19.26791,
#         -24.14567, -23.69595, -22.69629, -26.46177, -25.87282, -25.98942, -27.94088, -22.59143, -26.21687,
#         -24.79823, -21.42129, -16.10554, -23.5722 , -22.32674, -26.9921 , -23.4465 , -20.46888, -24.67679,
#         -21.46299, -23.25323, -19.47353, -21.23788, -21.59407, -17.75341, -18.52496, -24.21735, -21.89126]],
#       dtype=float32)

# %%
preds = np.argmax(log_preds, axis=1)  # from log probabilities to 0 or 1
probs = np.exp(log_preds[:,1])        # pr(dog)

# %%
def rand_by_mask(mask): return np.random.choice(np.where(mask)[0], min(len(preds), 4), replace=False)
def rand_by_correct(is_correct): return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])

# %%
def load_img_id(ds, idx): return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(idxs, title):
    imgs = [load_img_id(data.val_ds,x) for x in idxs]
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8)) if len(imgs)>0 else print('Not Found.')

# %%
# 1. A few correct labels at random
plot_val_with_title(rand_by_correct(True), "Correctly classified")
# Out:
# Correctly classified

# %%
# 2. A few incorrect labels at random
plot_val_with_title(rand_by_correct(False), "Incorrectly classified")
# Out:
# Incorrectly classified

# %%
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)

# %%
plot_val_with_title(most_by_correct(0, True), "Most correct cats")
# Out:
# Most correct cats

# %%
plot_val_with_title(most_by_correct(1, True), "Most correct dogs")
# Out:
# Most correct dogs

# %%
plot_val_with_title(most_by_correct(0, False), "Most incorrect cats")
# Out:
# Most incorrect cats
# Not Found.

# %%
plot_val_with_title(most_by_correct(1, False), "Most incorrect dogs")
# Out:
# Most incorrect dogs

# %%
most_uncertain = np.argsort(np.abs(probs -0.5))[:4]
plot_val_with_title(most_uncertain, "Most uncertain predictions")
# Out:
# Most uncertain predictions
